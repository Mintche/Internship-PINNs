# %% [markdown]
# ## PINN for the Helmholtz inverse problem

# %%
import jax
import jax.numpy as jnp
import functools
import numpy as np
import optax
import matplotlib.pyplot as plt
from data_load import WaveguideBoundaryData

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# **Data loading**

# %%
#Domain Omega : [-1,1]x[0,0.6]
#conditions de neuman en y=0 et y=0.6
H = 0.6
L = 1

data_loader_left = WaveguideBoundaryData('data/pinn_boundary_left_circle_contrast20percent.csv')
data_loader_right = WaveguideBoundaryData('data/pinn_boundary_right_circle_contrast20percent.csv')

X_left, Y_left, U_re_left, U_im_left, freq = data_loader_left.get_training_data()
X_right, Y_right, U_re_right, U_im_right, _ = data_loader_right.get_training_data()

Y_left = Y_left[freq[0]]
Y_right = Y_right[freq[0]]

# %% [markdown]
# **Normalisation**

# %%
# x is already in [-1,1]
#y and u [-1,1]

Y_norm = jnp.max(Y_left)
Y_left=2*Y_left/Y_norm - 1
Y_right=2*Y_right/Y_norm - 1

U_norm = {}
U_left_norm = {}
U_right_norm = {}

for f in freq:
    U_norm[f] = np.sqrt(jnp.max(np.concatenate((U_re_left[f]**2 + U_im_left[f]**2,U_re_right[f]**2 + U_im_right[f]**2))))
    U_re_left[f]/=U_norm[f]
    U_im_left[f]/=U_norm[f]
    U_re_right[f]/=U_norm[f]
    U_im_right[f]/=U_norm[f]
    U_left_norm[f] = jnp.stack([U_re_left[f],U_im_left[f]], axis=1)
    U_right_norm[f] = jnp.stack([U_re_right[f],U_im_right[f]], axis=1)

# %% [markdown]
# **Initialization**

# %%
key = jax.random.key(0)

f_test = 200.0
#Fouriers Features init
fmax = f_test
c0 = 340
cmax = 1.5 * c0
cmin = 0.5 * c0
contrast = 1
N_modes = int(jnp.round(2*H*fmax/c0)) + 5
kmax = 2*jnp.pi*fmax/(contrast*340)
m = 64

msq_min = 1.0 / (cmax**2)
msq_max = 1.0 / (cmin**2)

key, subkey = jax.random.split(key)

B_base = jax.random.normal(subkey, (m, 2))

def gamma(x, y, sigma):
    x_phys = x * L 
    y_phys = (y + 1.0) * H / 2.0
    v_phys = jnp.array([x_phys, y_phys])
    B = B_base * sigma
    return jnp.concatenate([jnp.cos(B@v_phys),jnp.sin(B@v_phys)])

n_gauss_legendre = 20

y_gauss_legendre, w_gauss_legendre = np.polynomial.legendre.leggauss(n_gauss_legendre)

n_input = 2
n_layers_uv = [2*m, 64, 64, 64, 64, 2]
n_layers_m = [n_input, 64, 64, 1]

#Xavier init

def init_layers(key, n_layers):
    layers = []
    for i in range(len(n_layers)-1):
        key, subkey = jax.random.split(key)
        W = jax.random.normal(subkey, (n_layers[i], n_layers[i+1])) * jnp.sqrt(2/(n_layers[i] + n_layers[i+1]))
        b = jnp.zeros(n_layers[i+1])
        layers.append({"W": W, "b": b})
    return layers, key


key, subkey_uv, subkey_m = jax.random.split(key, 3)
layers_uv, key = init_layers(subkey_uv, n_layers_uv)
layers_m, key = init_layers(subkey_m, n_layers_m)

layers_m[-1]["b"] = -jnp.log(27/5)

params_uv = {
    'layers': layers_uv,
    'sigma': jnp.array([kmax, 0.5*kmax])
}

# %% [markdown]
# **The Forward pass**

# %%
def forward_func(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = Z @ layers[-1]["W"] + layers[-1]["b"]
    return Z
 
def forward_params(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = msq_min + (msq_max-msq_min) * jax.nn.sigmoid(Z @ layers[-1]["W"] + layers[-1]["b"])
    return Z.squeeze()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# **The loss function**

# %%
y_quad = (y_gauss_legendre + 1.0) * H / 2.0
w_quad = w_gauss_legendre * H / 2.0
n_modes = jnp.arange(N_modes)
a_n = jnp.sqrt(2/H) * jnp.ones(N_modes)
a_n = a_n.at[0].set(jnp.sqrt(1/H))
C_quad = a_n[:, None] * jnp.cos(n_modes[:, None] * jnp.pi * y_quad[None, :] / H)

def loss_fn(params_uv, layers_m, x, y, f, target_u_left, target_u_right, y_bnd_left, y_bnd_right, u_norm_val, weights, phase1=False):

    def uv(x,y):
        features = gamma(x, y, params_uv['sigma'])
        return forward_func(params_uv['layers'], features)
    
    def m(x,y):
        return forward_params(layers_m, jnp.array([x, y]))
    
    def k2(x,y):
        if phase1:
            return (2*jnp.pi*f/c0)**2
        else:
            return (2*jnp.pi*f)**2*m(x,y)
    
    def uv_x(x, y):
        return jax.jacfwd(uv, argnums=0)(x, y)/L
    
    def uv_y(x, y):
        return jax.jacfwd(uv, argnums=1)(x, y)*(2/H)
    
    def m_x(x,y):
        return jax.grad(m, argnums=0)(x, y)/L
    
    def m_y(x,y):
        return jax.grad(m, argnums=1)(x, y)*(2/H)

    def pde_residual(x, y):
        uv_xx = jax.jacfwd(jax.jacfwd(uv, argnums=0), argnums=0)(x, y) / L**2
        uv_yy = jax.jacfwd(jax.jacfwd(uv, argnums=1), argnums=1)(x, y)*(2/H)**2
        return uv_xx + uv_yy + k2(x,y)*uv(x,y)
    
    k0 = 2*jnp.pi*f/c0
    beta_n = jnp.sqrt(k0**2 - (n_modes*jnp.pi/H)**2 +0j)
    
    def compute_dtn_loss(x_bnd, y_data, sign, A_inc=None):
        uv_quad = jax.vmap(uv, in_axes=(None, 0))(x_bnd, y_gauss_legendre)
        U_quad_complex = uv_quad[:, 0] + 1j * uv_quad[:, 1]
        
        u_n = C_quad @ (w_quad * U_quad_complex)
        
        dtn_n = sign * 1j * beta_n * u_n
        if A_inc is not None:
            dtn_n = dtn_n + 2j * beta_n * A_inc
        
        def DtN_eval(y_eval):
            C_y = a_n * jnp.cos(n_modes * jnp.pi * (y_eval+1)/2)
            return C_y @ dtn_n
            
        dtn_pred_complex = jax.vmap(DtN_eval)(y_data)
        
        dtn_actual = jax.vmap(uv_x, in_axes=(None, 0))(x_bnd, y_data)
        dtn_actual_complex = dtn_actual[:, 0] + 1j * dtn_actual[:, 1]
        
        return jnp.mean(jnp.abs(dtn_pred_complex - dtn_actual_complex)**2)

    A_inc_left = jnp.zeros(N_modes, dtype=jnp.complex64)
    amplitude_incidente = jnp.exp(-1j * beta_n[0] * L) / u_norm_val
    A_inc_left = A_inc_left.at[0].set(amplitude_incidente)
    #residual
    vmap_pde_residual = jax.vmap(pde_residual, in_axes=(0, 0))
    pde_loss = jnp.mean(vmap_pde_residual(x, y)**2)
    #boundary conditions
    dtn_loss_left = compute_dtn_loss(-1.0, y, sign=-1, A_inc=A_inc_left)
    dtn_loss_right = compute_dtn_loss(1.0, y, sign=1, A_inc=None)
    neum_loss = jnp.mean(jax.vmap(uv_y, in_axes=(0, None))(x, 1.0)**2 + jax.vmap(uv_y, in_axes=(0, None))(x, -1.0)**2)
    bc_loss = neum_loss + dtn_loss_left + dtn_loss_right
    #data + TV
    if phase1:
        data_loss = 0.0
        TV_loss = 0.0
    else:
        vmap_uv_y = jax.vmap(uv, (None,0))
        data_loss = jnp.mean((vmap_uv_y(-1.0,y_bnd_left) - target_u_left)**2)+jnp.mean((vmap_uv_y(1.0,y_bnd_right) - target_u_right)**2)
        vmap_m_x = jax.vmap(m_x, (0,0))
        vmap_m_y = jax.vmap(m_y, (0,0))
        TV_loss = jnp.mean(jnp.sqrt(c0**2*vmap_m_x(x,y)**2 + c0**2*vmap_m_y(x,y)**2 + 10**-8))
        

    total_loss = weights[0]*pde_loss + weights[1]*bc_loss + weights[2]*data_loss + weights[3]*TV_loss
    
    return total_loss, (pde_loss, bc_loss, data_loss, TV_loss)

# %% [markdown]
# **Le training**

# %%
lr_uv = 1e-3
lr_m = 3e-5

def make_train_step_forward(adam_opt, lbfgs_opt):

    @functools.partial(jax.jit, static_argnames=('N', 'use_lbfgs'))
    def train_step_forward(params_uv, layers_m, opt_state_uv, N, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, key, use_lbfgs=False):
        key, subkey1, subkey2 = jax.random.split(key, 3)
        x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
        y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

        def loss_uv(p_uv):
            return loss_fn(p_uv, layers_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, phase1=True)

        (loss, aux), grads_uv = jax.value_and_grad(loss_uv, has_aux=True)(params_uv)

        if use_lbfgs:
            def value_fn(p_uv):
                v, _ = loss_uv(p_uv)
                return v
            updates_uv, opt_state_uv = lbfgs_opt.update(
                grads_uv, opt_state_uv, params_uv,
                value=loss, grad=grads_uv, value_fn=value_fn)
        else:
            updates_uv, opt_state_uv = adam_opt.update(grads_uv, opt_state_uv, params_uv)

        params_uv = optax.apply_updates(params_uv, updates_uv)
        return params_uv, opt_state_uv, loss, aux, key

    return train_step_forward


def make_train_step_inverse(adam_opt_uv, adam_opt_m, lbfgs_opt_packed):

    @functools.partial(jax.jit, static_argnames=('N', 'use_lbfgs'))
    def train_step_inverse(params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, N, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, key, use_lbfgs=False):
        key, subkey1, subkey2 = jax.random.split(key, 3)
        x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
        y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

        def loss_full(p_uv, l_m):
            return loss_fn(p_uv, l_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, phase1=False)

        (loss, aux), (grads_uv, grads_m) = jax.value_and_grad(loss_full, argnums=(0,1), has_aux=True)(params_uv, layers_m)

        if use_lbfgs:
            params_packed = {'uv': params_uv, 'm': layers_m}
            grads_packed = {'uv': grads_uv, 'm': grads_m}
            
            def value_fn_packed(p_packed):
                v, _ = loss_full(p_packed['uv'], p_packed['m'])
                return v

            updates_packed, opt_state_lbfgs = lbfgs_opt_packed.update(
                grads_packed, opt_state_lbfgs, params_packed,
                value=loss, grad=grads_packed, value_fn=value_fn_packed)
            
            params_packed = optax.apply_updates(params_packed, updates_packed)
            params_uv = params_packed['uv']
            layers_m = params_packed['m']
        else:
            updates_uv, opt_state_uv = adam_opt_uv.update(grads_uv, opt_state_uv, params_uv)
            params_uv = optax.apply_updates(params_uv, updates_uv)

            updates_m, opt_state_m = adam_opt_m.update(grads_m, opt_state_m, layers_m)
            layers_m = optax.apply_updates(layers_m, updates_m)

        return params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux, key

    return train_step_inverse


# --- Convergence criterion ---

def check_switch_criterion(loss_history, window=10, threshold=1e-3):
    """Returns True if the relative slope of the loss is below threshold."""
    if len(loss_history) < window:
        return False
    old_loss = loss_history[-window]
    new_loss = loss_history[-1]
    relative_slope = abs(new_loss - old_loss) / max(abs(old_loss), 1e-12)
    return relative_slope < threshold and jnp.mean(old_loss) < 1e-1


# --- Main training function ---

def train(params_uv, layers_m, N,
          max_steps_adam_phase1, max_steps_lbfgs_phase1,
          max_steps_adam_phase2, max_steps_lbfgs_phase2,
          freqs, eval_interval, switch_threshold, switch_window, key):

    loss_forward = []
    loss_inverse = []

    weights_phase1 = jnp.array([1.0, 10.0, 0.0, 0.0])

    for freq in freqs:
        print(f"\n{'='*60}")
        print(f"--- f = {freq} Hz ---")
        print(f"{'='*60}")

        best_params_uv = params_uv
        best_params_m = layers_m
        best_loss = float('inf')

        # ============================================================
        # PHASE 1: Forward (only params_uv)
        # ============================================================

        # --- Phase 1: Adam with cosine decay ---
        print(f"\n--- Phase 1: Adam (max {max_steps_adam_phase1} steps) ---")

        cosine_p1 = optax.schedules.cosine_decay_schedule(
            init_value=lr_uv, decay_steps=max_steps_adam_phase1, alpha=0.1)
        adam_uv_p1 = optax.chain(
            optax.clip_by_global_norm(1.0),
            optax.scale_by_adam(),
            optax.scale_by_schedule(cosine_p1),
            optax.scale(-1.0))
        lbfgs_uv_p1 = optax.lbfgs()

        step_forward = make_train_step_forward(adam_uv_p1, lbfgs_uv_p1)
        opt_state_uv = adam_uv_p1.init(params_uv)

        loss_history_p1 = []
        switched_to_lbfgs = False

        for step in range(max_steps_adam_phase1):
            params_uv, opt_state_uv, loss, aux, key = step_forward(
                params_uv, layers_m, opt_state_uv, N, freq,
                U_left_norm[freq], U_right_norm[freq],
                Y_left, Y_right, U_norm[freq], weights_phase1, key,
                use_lbfgs=False)

            loss_history_p1.append(float(loss))

            if step % eval_interval == 0:
                pde_loss, bc_loss, _, _ = aux
                loss_forward.append((pde_loss, bc_loss))
                print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {params_uv['sigma']}")
                if loss < best_loss:
                    best_loss = loss
                    best_params_uv = params_uv

            if check_switch_criterion(loss_history_p1, window=switch_window, threshold=switch_threshold):
                print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                switched_to_lbfgs = True
                params_uv = best_params_uv
                break

        # --- Phase 1: L-BFGS ---
        if switched_to_lbfgs or max_steps_lbfgs_phase1 > 0:
            print(f"\n--- Phase 1: L-BFGS (max {max_steps_lbfgs_phase1} steps) ---")
            opt_state_uv = lbfgs_uv_p1.init(params_uv)

            for step in range(max_steps_lbfgs_phase1):
                params_uv, opt_state_uv, loss, aux, key = step_forward(
                    params_uv, layers_m, opt_state_uv, N, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase1, key,
                    use_lbfgs=True)

                if step % eval_interval == 0:
                    pde_loss, bc_loss, _, _ = aux
                    loss_forward.append((pde_loss, bc_loss))
                    print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {params_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv = params_uv

        # ============================================================
        # PHASE 2: Inverse (params_uv + layers_m)
        # ============================================================

        best_loss = float('inf')
        
        if max_steps_adam_phase2 > 0 or max_steps_lbfgs_phase2 > 0:

            # --- Phase 2: Adam with cosine decay ---
            print(f"\n--- Phase 2: Adam (max {max_steps_adam_phase2} steps) ---")

            cosine_uv_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_uv, decay_steps=max_steps_adam_phase2, alpha=0.1)
            cosine_m_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_m, decay_steps=max_steps_adam_phase2, alpha=0.1)
            adam_uv_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_uv_p2),
                optax.scale(-1.0))
            adam_m_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_m_p2),
                optax.scale(-1.0))
            
            lbfgs_packed_p2 = optax.lbfgs()

            step_inverse = make_train_step_inverse(adam_uv_p2, adam_m_p2, lbfgs_packed_p2)

            opt_state_uv = adam_uv_p2.init(params_uv)
            opt_state_m = adam_m_p2.init(layers_m)
            opt_state_lbfgs = None

            data_weight_schedule = optax.linear_schedule(
                init_value=1.0, end_value=100,
                transition_steps=max(max_steps_adam_phase2 // 10, 1))

            loss_history_p2 = []
            switched_to_lbfgs_p2 = False

            for step in range(max_steps_adam_phase2):
                weights_phase2 = jnp.array([1.0, 10.0, data_weight_schedule(step), 1.0])
                params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux, key = step_inverse(
                    params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, N, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase2, key,
                    use_lbfgs=False)

                loss_history_p2.append(float(loss))

                if step % eval_interval == 0:
                    pde_loss, bc_loss, data_loss, TV_loss = aux
                    loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                    print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {params_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv = params_uv
                        best_params_m = layers_m

                if check_switch_criterion(loss_history_p2, window=switch_window, threshold=switch_threshold):
                    print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                    switched_to_lbfgs_p2 = True
                    params_uv = best_params_uv
                    layers_m = best_params_m
                    break

            # --- Phase 2: L-BFGS ---
            if switched_to_lbfgs_p2 or max_steps_lbfgs_phase2 > 0:
                print(f"\n--- Phase 2: L-BFGS (max {max_steps_lbfgs_phase2} steps) ---")
                opt_state_lbfgs = lbfgs_packed_p2.init({'uv': params_uv, 'm': layers_m})
                weights_phase2_lbfgs = jnp.array([1.0, 10.0, 100.0, 1.0])

                for step in range(max_steps_lbfgs_phase2):
                    params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux, key = step_inverse(
                        params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, N, freq,
                        U_left_norm[freq], U_right_norm[freq],
                        Y_left, Y_right, U_norm[freq], weights_phase2_lbfgs, key,
                        use_lbfgs=True)

                    if step % eval_interval == 0:
                        pde_loss, bc_loss, data_loss, TV_loss = aux
                        loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                        print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {params_uv['sigma']}")
                        if loss < best_loss:
                            best_loss = loss
                            best_params_uv = params_uv
                            best_params_m = layers_m

    return best_params_uv, best_params_m, key, loss_forward, loss_inverse

# %% [markdown]
# **La phase d'entrainement**

# %%
N = 1000
eval_interval = 200
switch_threshold = 1e-5
switch_window = 10

max_steps_adam_phase1 = 1
max_steps_lbfgs_phase1 = 0
max_steps_adam_phase2 = 50001
max_steps_lbfgs_phase2 = 0

freq = np.array([f_test])

key, subkey = jax.random.split(key)
params_uv, layers_m, key, loss_forward, loss_inverse = train(
    params_uv, layers_m, N,
    max_steps_adam_phase1, max_steps_lbfgs_phase1,
    max_steps_adam_phase2, max_steps_lbfgs_phase2,
    freq, eval_interval, switch_threshold, switch_window, key)
# Out:
# ============================================================
# --- f = 800.0 Hz ---
# ============================================================
#
# --- Phase 1: Adam (max 1 steps) ---
# [Adam] Step 0 | pde 4.89e+04 | bc 5.34e+02 | total 5.42e+04 | scales [14.782965   7.3909826]
#
# --- Phase 2: Adam (max 50001 steps) ---
# [Adam] Step 0 | pde 3.50e+04 | bc 3.96e+02 | data 4.06e-01 | TV loss 1.54e-03 | total 3.89e+04 | scales [14.781964   7.3899827]
# [Adam] Step 200 | pde 4.74e+01 | bc 9.80e-01 | data 1.99e-01 | TV loss 3.05e-04 | total 5.82e+01 | scales [14.7071905  7.259157 ]
# [Adam] Step 400 | pde 1.17e+01 | bc 4.16e-01 | data 1.20e-01 | TV loss 3.12e-04 | total 1.69e+01 | scales [14.697963  7.180923]
# [Adam] Step 600 | pde 5.38e+00 | bc 2.12e-01 | data 8.74e-02 | TV loss 3.40e-04 | total 8.63e+00 | scales [14.701865  7.130166]
# [Adam] Step 800 | pde 4.06e+00 | bc 6.20e-02 | data 5.58e-02 | TV loss 3.59e-04 | total 5.62e+00 | scales [14.709891   7.0943584]
# [Adam] Step 1000 | pde 2.32e+00 | bc 2.05e-01 | data 3.81e-02 | TV loss 3.83e-04 | total 5.16e+00 | scales [14.715998   7.0726805]
# [Adam] Step 1200 | pde 2.22e+00 | bc 1.09e-01 | data 2.78e-02 | TV loss 3.99e-04 | total 4.00e+00 | scales [14.719484  7.057571]
# [Adam] Step 1400 | pde 2.20e+00 | bc 1.66e-01 | data 2.18e-02 | TV loss 4.15e-04 | total 4.49e+00 | scales [14.721642  7.041635]
# [Adam] Step 1600 | pde 1.83e+00 | bc 2.40e-01 | data 1.73e-02 | TV loss 4.14e-04 | total 4.79e+00 | scales [14.7221155  7.0258994]
# [Adam] Step 1800 | pde 1.45e+00 | bc 2.21e-01 | data 1.50e-02 | TV loss 4.17e-04 | total 4.21e+00 | scales [14.722654   7.0156884]
# [Adam] Step 2000 | pde 1.51e+00 | bc 1.29e-01 | data 1.38e-02 | TV loss 4.12e-04 | total 3.36e+00 | scales [14.722976   7.0011644]
# [Adam] Step 2200 | pde 2.48e+00 | bc 4.23e-02 | data 1.20e-02 | TV loss 4.10e-04 | total 3.44e+00 | scales [14.7226095  6.9869514]
# [Adam] Step 2400 | pde 2.15e+00 | bc 7.64e-02 | data 1.11e-02 | TV loss 4.05e-04 | total 3.45e+00 | scales [14.722027  6.963957]
# [Adam] Step 2600 | pde 9.94e-01 | bc 1.26e-01 | data 9.95e-03 | TV loss 3.96e-04 | total 2.77e+00 | scales [14.721635   6.9498262]
# [Adam] Step 2800 | pde 9.28e-01 | bc 9.94e-02 | data 8.79e-03 | TV loss 4.00e-04 | total 2.42e+00 | scales [14.721658   6.9459147]
# [Adam] Step 3000 | pde 1.45e+00 | bc 9.08e-02 | data 8.08e-03 | TV loss 3.88e-04 | total 2.85e+00 | scales [14.721255   6.9364777]
# [Adam] Step 3200 | pde 2.13e+00 | bc 9.49e-02 | data 7.48e-03 | TV loss 3.85e-04 | total 3.56e+00 | scales [14.721022   6.9258103]
# [Adam] Step 3400 | pde 2.43e+00 | bc 3.97e-02 | data 6.90e-03 | TV loss 3.83e-04 | total 3.30e+00 | scales [14.720332  6.904307]
# [Adam] Step 3600 | pde 2.72e+00 | bc 4.07e-02 | data 6.27e-03 | TV loss 3.76e-04 | total 3.58e+00 | scales [14.719926   6.8845444]
# [Adam] Step 3800 | pde 2.69e+00 | bc 5.01e-02 | data 5.93e-03 | TV loss 3.70e-04 | total 3.65e+00 | scales [14.719464  6.866628]
# [Adam] Step 4000 | pde 9.39e-01 | bc 9.70e-02 | data 5.34e-03 | TV loss 3.66e-04 | total 2.34e+00 | scales [14.718949  6.853173]
# [Adam] Step 4200 | pde 9.27e-01 | bc 1.66e-01 | data 4.89e-03 | TV loss 3.59e-04 | total 3.00e+00 | scales [14.719032  6.852393]
# [Adam] Step 4400 | pde 1.05e+00 | bc 1.49e-01 | data 4.57e-03 | TV loss 3.54e-04 | total 2.94e+00 | scales [14.719197   6.8492517]
# [Adam] Step 4600 | pde 1.10e+00 | bc 1.08e-01 | data 4.49e-03 | TV loss 3.58e-04 | total 2.59e+00 | scales [14.718972   6.8438745]
# [Adam] Step 4800 | pde 1.06e+00 | bc 8.64e-02 | data 4.17e-03 | TV loss 3.61e-04 | total 2.32e+00 | scales [14.718364  6.847778]
# [Adam] Step 5000 | pde 1.05e+00 | bc 1.23e-01 | data 3.98e-03 | TV loss 3.69e-04 | total 2.68e+00 | scales [14.718462  6.848066]
# [Adam] Step 5200 | pde 1.54e+00 | bc 8.02e-02 | data 3.87e-03 | TV loss 3.70e-04 | total 2.73e+00 | scales [14.7183275  6.8401213]
# [Adam] Step 5400 | pde 1.61e+00 | bc 5.92e-02 | data 3.71e-03 | TV loss 3.65e-04 | total 2.57e+00 | scales [14.718079  6.81545 ]
# [Adam] Step 5600 | pde 1.81e+00 | bc 5.48e-02 | data 3.70e-03 | TV loss 3.66e-04 | total 2.73e+00 | scales [14.717816   6.7933583]
# [Adam] Step 5800 | pde 1.42e+00 | bc 5.89e-02 | data 3.81e-03 | TV loss 3.66e-04 | total 2.39e+00 | scales [14.71742    6.7796416]
# [Adam] Step 6000 | pde 8.86e-01 | bc 1.30e-01 | data 3.47e-03 | TV loss 3.70e-04 | total 2.54e+00 | scales [14.717164   6.7784824]
# [Adam] Step 6200 | pde 1.49e+00 | bc 4.18e-02 | data 3.48e-03 | TV loss 3.71e-04 | total 2.26e+00 | scales [14.717123   6.7772126]
# [Adam] Step 6400 | pde 1.53e+00 | bc 6.81e-02 | data 3.70e-03 | TV loss 3.70e-04 | total 2.58e+00 | scales [14.716661  6.764139]
# [Adam] Step 6600 | pde 1.96e+00 | bc 4.69e-02 | data 3.31e-03 | TV loss 3.78e-04 | total 2.76e+00 | scales [14.716433   6.7521534]
# [Adam] Step 6800 | pde 8.89e-01 | bc 1.24e-01 | data 3.71e-03 | TV loss 3.76e-04 | total 2.50e+00 | scales [14.71624    6.7520404]
# [Adam] Step 7000 | pde 8.56e-01 | bc 9.83e-02 | data 3.56e-03 | TV loss 3.79e-04 | total 2.19e+00 | scales [14.716014   6.7526665]
# [Adam] Step 7200 | pde 1.14e+00 | bc 7.18e-02 | data 3.54e-03 | TV loss 3.83e-04 | total 2.22e+00 | scales [14.715407   6.7395525]
# [Adam] Step 7400 | pde 6.64e-01 | bc 1.53e-01 | data 3.61e-03 | TV loss 3.87e-04 | total 2.55e+00 | scales [14.715582   6.7455945]
# [Adam] Step 7600 | pde 8.16e-01 | bc 1.06e-01 | data 3.37e-03 | TV loss 3.93e-04 | total 2.22e+00 | scales [14.715734  6.74903 ]
# [Adam] Step 7800 | pde 7.45e-01 | bc 8.67e-02 | data 3.27e-03 | TV loss 4.04e-04 | total 1.94e+00 | scales [14.715644  6.754091]
# [Adam] Step 8000 | pde 1.44e+00 | bc 3.38e-02 | data 3.17e-03 | TV loss 4.08e-04 | total 2.10e+00 | scales [14.715398   6.7406983]
# [Adam] Step 8200 | pde 1.40e+00 | bc 3.64e-02 | data 3.32e-03 | TV loss 4.28e-04 | total 2.09e+00 | scales [14.715171   6.7253833]
# [Adam] Step 8400 | pde 1.20e+00 | bc 8.68e-02 | data 3.04e-03 | TV loss 4.37e-04 | total 2.37e+00 | scales [14.714716   6.7114453]
# [Adam] Step 8600 | pde 1.16e+00 | bc 9.46e-02 | data 3.20e-03 | TV loss 4.50e-04 | total 2.42e+00 | scales [14.714291   6.7108426]
# [Adam] Step 8800 | pde 6.97e-01 | bc 7.78e-02 | data 2.98e-03 | TV loss 4.64e-04 | total 1.77e+00 | scales [14.714395  6.710642]
# [Adam] Step 9000 | pde 6.13e-01 | bc 8.21e-02 | data 2.82e-03 | TV loss 4.81e-04 | total 1.72e+00 | scales [14.714018   6.7113285]
# [Adam] Step 9200 | pde 5.86e-01 | bc 1.17e-01 | data 2.74e-03 | TV loss 4.99e-04 | total 2.03e+00 | scales [14.714202  6.717993]
# [Adam] Step 9400 | pde 8.11e-01 | bc 8.40e-02 | data 2.64e-03 | TV loss 5.11e-04 | total 1.91e+00 | scales [14.71434   6.722871]
# [Adam] Step 9600 | pde 8.98e-01 | bc 7.44e-02 | data 2.69e-03 | TV loss 5.42e-04 | total 1.91e+00 | scales [14.714106  6.714775]
# [Adam] Step 9800 | pde 8.88e-01 | bc 6.97e-02 | data 2.61e-03 | TV loss 5.54e-04 | total 1.85e+00 | scales [14.713901   6.7157316]
# [Adam] Step 10000 | pde 4.87e-01 | bc 1.02e-01 | data 2.40e-03 | TV loss 5.79e-04 | total 1.75e+00 | scales [14.714083   6.7167525]
# [Adam] Step 10200 | pde 5.54e-01 | bc 6.89e-02 | data 2.37e-03 | TV loss 5.89e-04 | total 1.48e+00 | scales [14.714111   6.7204494]
# [Adam] Step 10400 | pde 1.02e+00 | bc 3.46e-02 | data 2.51e-03 | TV loss 6.09e-04 | total 1.62e+00 | scales [14.714063   6.7201166]
# [Adam] Step 10600 | pde 1.07e+00 | bc 5.90e-02 | data 2.23e-03 | TV loss 6.57e-04 | total 1.88e+00 | scales [14.713998   6.7094545]
# [Adam] Step 10800 | pde 6.23e-01 | bc 7.97e-02 | data 2.25e-03 | TV loss 6.71e-04 | total 1.65e+00 | scales [14.713966  6.718959]
# [Adam] Step 11000 | pde 8.31e-01 | bc 9.15e-02 | data 2.28e-03 | TV loss 7.09e-04 | total 1.98e+00 | scales [14.713977   6.7156425]
# [Adam] Step 11200 | pde 5.93e-01 | bc 5.70e-02 | data 2.11e-03 | TV loss 7.57e-04 | total 1.37e+00 | scales [14.713951   6.7188187]
# [Adam] Step 11400 | pde 5.71e-01 | bc 9.37e-02 | data 2.05e-03 | TV loss 7.82e-04 | total 1.71e+00 | scales [14.713935  6.716224]
# [Adam] Step 11600 | pde 6.47e-01 | bc 3.39e-02 | data 1.91e-03 | TV loss 8.31e-04 | total 1.18e+00 | scales [14.713978   6.7167854]
# [Adam] Step 11800 | pde 8.29e-01 | bc 4.40e-02 | data 1.83e-03 | TV loss 8.48e-04 | total 1.45e+00 | scales [14.713912  6.710545]
# [Adam] Step 12000 | pde 6.00e-01 | bc 5.25e-02 | data 1.57e-03 | TV loss 9.05e-04 | total 1.28e+00 | scales [14.713874   6.7076764]
# [Adam] Step 12200 | pde 4.29e-01 | bc 3.81e-02 | data 1.66e-03 | TV loss 9.55e-04 | total 9.78e-01 | scales [14.713887   6.7092996]
# [Adam] Step 12400 | pde 4.21e-01 | bc 8.83e-02 | data 1.67e-03 | TV loss 9.43e-04 | total 1.47e+00 | scales [14.714076  6.715607]
# [Adam] Step 12600 | pde 3.84e-01 | bc 7.22e-02 | data 1.55e-03 | TV loss 9.99e-04 | total 1.26e+00 | scales [14.714031   6.7228656]
# [Adam] Step 12800 | pde 6.72e-01 | bc 2.11e-02 | data 1.50e-03 | TV loss 1.04e-03 | total 1.03e+00 | scales [14.713808  6.720031]
# [Adam] Step 13000 | pde 6.68e-01 | bc 4.90e-02 | data 1.53e-03 | TV loss 1.08e-03 | total 1.31e+00 | scales [14.713837   6.7154713]
# [Adam] Step 13200 | pde 4.45e-01 | bc 6.06e-02 | data 1.23e-03 | TV loss 1.10e-03 | total 1.18e+00 | scales [14.713628  6.715614]
# [Adam] Step 13400 | pde 6.26e-01 | bc 3.03e-02 | data 1.20e-03 | TV loss 1.18e-03 | total 1.05e+00 | scales [14.713443  6.71443 ]
# [Adam] Step 13600 | pde 6.08e-01 | bc 2.51e-02 | data 1.22e-03 | TV loss 1.18e-03 | total 9.82e-01 | scales [14.71342   6.708086]
# [Adam] Step 13800 | pde 6.48e-01 | bc 3.25e-02 | data 1.16e-03 | TV loss 1.22e-03 | total 1.09e+00 | scales [14.713342  6.70373 ]
# [Adam] Step 14000 | pde 6.95e-01 | bc 2.47e-02 | data 9.58e-04 | TV loss 1.29e-03 | total 1.04e+00 | scales [14.713022   6.6989403]
# [Adam] Step 14200 | pde 2.91e-01 | bc 5.67e-02 | data 1.08e-03 | TV loss 1.33e-03 | total 9.67e-01 | scales [14.713096  6.702774]
# [Adam] Step 14400 | pde 5.97e-01 | bc 4.12e-02 | data 1.05e-03 | TV loss 1.34e-03 | total 1.12e+00 | scales [14.712841   6.7039866]
# [Adam] Step 14600 | pde 2.64e-01 | bc 4.16e-02 | data 9.55e-04 | TV loss 1.40e-03 | total 7.76e-01 | scales [14.712954   6.7084703]
# [Adam] Step 14800 | pde 5.77e-01 | bc 4.66e-02 | data 9.26e-04 | TV loss 1.42e-03 | total 1.14e+00 | scales [14.713103  6.707328]
# [Adam] Step 15000 | pde 1.09e+00 | bc 2.47e-02 | data 7.71e-04 | TV loss 1.43e-03 | total 1.42e+00 | scales [14.712916   6.7072573]
# [Adam] Step 15200 | pde 5.88e-01 | bc 1.55e-02 | data 8.58e-04 | TV loss 1.46e-03 | total 8.31e-01 | scales [14.712738  6.703191]
# [Adam] Step 15400 | pde 4.59e-01 | bc 2.06e-02 | data 7.96e-04 | TV loss 1.50e-03 | total 7.46e-01 | scales [14.712708   6.7002335]
# [Adam] Step 15600 | pde 3.23e-01 | bc 4.86e-02 | data 7.27e-04 | TV loss 1.48e-03 | total 8.84e-01 | scales [14.712526  6.702763]
# [Adam] Step 15800 | pde 4.02e-01 | bc 5.44e-02 | data 5.96e-04 | TV loss 1.57e-03 | total 1.01e+00 | scales [14.712478  6.707143]
# [Adam] Step 16000 | pde 2.81e-01 | bc 3.24e-02 | data 6.79e-04 | TV loss 1.57e-03 | total 6.74e-01 | scales [14.712555   6.7073374]
# [Adam] Step 16200 | pde 5.71e-01 | bc 2.56e-02 | data 6.42e-04 | TV loss 1.59e-03 | total 8.93e-01 | scales [14.712287  6.707151]
# [Adam] Step 16400 | pde 5.44e-01 | bc 1.17e-02 | data 6.23e-04 | TV loss 1.61e-03 | total 7.25e-01 | scales [14.711967   6.7031894]
# [Adam] Step 16600 | pde 6.20e-01 | bc 1.01e-02 | data 6.30e-04 | TV loss 1.62e-03 | total 7.86e-01 | scales [14.71178   6.701023]
# [Adam] Step 16800 | pde 2.77e-01 | bc 5.44e-02 | data 5.61e-04 | TV loss 1.69e-03 | total 8.78e-01 | scales [14.711862  6.700669]
# [Adam] Step 17000 | pde 2.87e-01 | bc 3.83e-02 | data 5.56e-04 | TV loss 1.70e-03 | total 7.27e-01 | scales [14.711917   6.7042375]
# [Adam] Step 17200 | pde 2.42e-01 | bc 4.90e-02 | data 6.20e-04 | TV loss 1.72e-03 | total 7.95e-01 | scales [14.711898   6.7085037]
# [Adam] Step 17400 | pde 2.70e-01 | bc 4.39e-02 | data 6.09e-04 | TV loss 1.80e-03 | total 7.72e-01 | scales [14.711826  6.708977]
# [Adam] Step 17600 | pde 5.97e-01 | bc 1.26e-02 | data 4.98e-04 | TV loss 1.73e-03 | total 7.74e-01 | scales [14.711715   6.7090244]
# [Adam] Step 17800 | pde 4.69e-01 | bc 1.21e-02 | data 4.81e-04 | TV loss 1.81e-03 | total 6.40e-01 | scales [14.711559   6.7058716]
# [Adam] Step 18000 | pde 2.23e-01 | bc 3.46e-02 | data 4.64e-04 | TV loss 1.76e-03 | total 6.17e-01 | scales [14.711514   6.7052054]
# [Adam] Step 18200 | pde 3.05e-01 | bc 5.69e-02 | data 4.89e-04 | TV loss 1.78e-03 | total 9.25e-01 | scales [14.711386   6.7050366]
# [Adam] Step 18400 | pde 3.43e-01 | bc 2.72e-02 | data 4.65e-04 | TV loss 1.84e-03 | total 6.63e-01 | scales [14.7114105  6.7068896]
# [Adam] Step 18600 | pde 3.99e-01 | bc 1.05e-02 | data 4.53e-04 | TV loss 1.84e-03 | total 5.51e-01 | scales [14.711274   6.7032332]
# [Adam] Step 18800 | pde 4.65e-01 | bc 1.32e-02 | data 4.29e-04 | TV loss 1.83e-03 | total 6.41e-01 | scales [14.71114   6.702266]
# [Adam] Step 19000 | pde 3.91e-01 | bc 1.06e-02 | data 4.95e-04 | TV loss 1.86e-03 | total 5.48e-01 | scales [14.711059   6.7001176]
# [Adam] Step 19200 | pde 2.98e-01 | bc 9.53e-03 | data 4.34e-04 | TV loss 1.88e-03 | total 4.38e-01 | scales [14.710886  6.695712]
# [Adam] Step 19400 | pde 2.12e-01 | bc 3.81e-02 | data 4.74e-04 | TV loss 1.88e-03 | total 6.42e-01 | scales [14.710991  6.697183]
# [Adam] Step 19600 | pde 2.00e-01 | bc 2.85e-02 | data 4.49e-04 | TV loss 1.89e-03 | total 5.32e-01 | scales [14.710921  6.698352]
# [Adam] Step 19800 | pde 4.28e-01 | bc 3.01e-02 | data 4.42e-04 | TV loss 1.88e-03 | total 7.75e-01 | scales [14.710671   6.6976113]
# [Adam] Step 20000 | pde 2.73e-01 | bc 2.67e-02 | data 4.25e-04 | TV loss 1.85e-03 | total 5.84e-01 | scales [14.710632  6.698364]
# [Adam] Step 20200 | pde 1.28e-01 | bc 2.84e-02 | data 3.67e-04 | TV loss 1.93e-03 | total 4.51e-01 | scales [14.7105665  6.6980495]
# [Adam] Step 20400 | pde 1.36e-01 | bc 3.28e-02 | data 3.78e-04 | TV loss 1.91e-03 | total 5.04e-01 | scales [14.710531  6.699045]
# [Adam] Step 20600 | pde 2.66e-01 | bc 1.65e-02 | data 4.22e-04 | TV loss 1.88e-03 | total 4.75e-01 | scales [14.710424   6.6977844]
# [Adam] Step 20800 | pde 5.11e-01 | bc 1.16e-02 | data 3.76e-04 | TV loss 1.92e-03 | total 6.67e-01 | scales [14.710302   6.6957293]
# [Adam] Step 21000 | pde 3.95e-01 | bc 1.72e-02 | data 4.35e-04 | TV loss 1.91e-03 | total 6.13e-01 | scales [14.710195  6.692762]
# [Adam] Step 21200 | pde 2.22e-01 | bc 2.22e-02 | data 4.43e-04 | TV loss 1.94e-03 | total 4.90e-01 | scales [14.710105  6.693289]
# [Adam] Step 21400 | pde 1.62e-01 | bc 4.05e-02 | data 5.07e-04 | TV loss 1.93e-03 | total 6.19e-01 | scales [14.709986  6.693212]
# [Adam] Step 21600 | pde 3.55e-01 | bc 7.86e-03 | data 4.45e-04 | TV loss 1.96e-03 | total 4.80e-01 | scales [14.709923  6.694028]
# [Adam] Step 21800 | pde 1.50e-01 | bc 4.94e-02 | data 3.80e-04 | TV loss 1.93e-03 | total 6.85e-01 | scales [14.709845   6.6940694]
# [Adam] Step 22000 | pde 1.10e-01 | bc 3.28e-02 | data 3.75e-04 | TV loss 1.89e-03 | total 4.77e-01 | scales [14.709862  6.695724]
# [Adam] Step 22200 | pde 2.23e-01 | bc 4.20e-02 | data 3.60e-04 | TV loss 1.98e-03 | total 6.81e-01 | scales [14.709932   6.6960263]
# [Adam] Step 22400 | pde 1.26e-01 | bc 2.34e-02 | data 3.60e-04 | TV loss 1.97e-03 | total 3.97e-01 | scales [14.70992    6.6960607]
# [Adam] Step 22600 | pde 3.21e-01 | bc 9.07e-03 | data 3.94e-04 | TV loss 1.99e-03 | total 4.53e-01 | scales [14.709856   6.6959357]
# [Adam] Step 22800 | pde 3.50e-01 | bc 2.51e-02 | data 3.98e-04 | TV loss 1.92e-03 | total 6.43e-01 | scales [14.70973    6.6923637]
# [Adam] Step 23000 | pde 1.17e-01 | bc 2.34e-02 | data 3.76e-04 | TV loss 2.01e-03 | total 3.90e-01 | scales [14.709748   6.6913276]
# [Adam] Step 23200 | pde 2.40e-01 | bc 2.48e-02 | data 4.57e-04 | TV loss 2.00e-03 | total 5.36e-01 | scales [14.709714  6.691606]
# [Adam] Step 23400 | pde 1.76e-01 | bc 1.81e-02 | data 4.43e-04 | TV loss 1.95e-03 | total 4.03e-01 | scales [14.709693  6.690772]
# [Adam] Step 23600 | pde 2.19e-01 | bc 3.56e-02 | data 4.06e-04 | TV loss 1.97e-03 | total 6.17e-01 | scales [14.709695   6.6908646]
# [Adam] Step 23800 | pde 1.77e-01 | bc 1.68e-02 | data 4.06e-04 | TV loss 2.03e-03 | total 3.88e-01 | scales [14.709677   6.6923733]
# [Adam] Step 24000 | pde 2.18e-01 | bc 1.19e-02 | data 4.38e-04 | TV loss 2.02e-03 | total 3.83e-01 | scales [14.709614  6.690921]
# [Adam] Step 24200 | pde 1.87e-01 | bc 5.38e-03 | data 4.19e-04 | TV loss 2.02e-03 | total 2.85e-01 | scales [14.709616  6.688866]
# [Adam] Step 24400 | pde 1.91e-01 | bc 2.30e-02 | data 4.64e-04 | TV loss 1.98e-03 | total 4.70e-01 | scales [14.709581  6.687655]
# [Adam] Step 24600 | pde 2.65e-01 | bc 1.81e-02 | data 4.87e-04 | TV loss 1.98e-03 | total 4.97e-01 | scales [14.709461   6.6876903]
# [Adam] Step 24800 | pde 2.87e-01 | bc 7.85e-03 | data 3.79e-04 | TV loss 2.02e-03 | total 4.05e-01 | scales [14.709476  6.686488]
# [Adam] Step 25000 | pde 1.38e-01 | bc 1.63e-02 | data 4.13e-04 | TV loss 2.00e-03 | total 3.44e-01 | scales [14.709399   6.6848307]
# [Adam] Step 25200 | pde 2.08e-01 | bc 3.59e-02 | data 4.30e-04 | TV loss 2.00e-03 | total 6.12e-01 | scales [14.7092495  6.6846704]
# [Adam] Step 25400 | pde 9.99e-02 | bc 1.92e-02 | data 3.65e-04 | TV loss 1.97e-03 | total 3.30e-01 | scales [14.709289   6.6856775]
# [Adam] Step 25600 | pde 1.60e-01 | bc 1.61e-02 | data 4.16e-04 | TV loss 2.04e-03 | total 3.65e-01 | scales [14.709293  6.686301]
# [Adam] Step 25800 | pde 1.35e-01 | bc 1.89e-02 | data 4.42e-04 | TV loss 1.93e-03 | total 3.70e-01 | scales [14.709234   6.6856785]
# [Adam] Step 26000 | pde 1.33e-01 | bc 1.88e-02 | data 4.57e-04 | TV loss 1.99e-03 | total 3.68e-01 | scales [14.709157  6.68499 ]
# [Adam] Step 26200 | pde 1.98e-01 | bc 5.46e-03 | data 4.09e-04 | TV loss 1.98e-03 | total 2.95e-01 | scales [14.709099  6.684882]
# [Adam] Step 26400 | pde 1.65e-01 | bc 2.18e-02 | data 3.82e-04 | TV loss 2.04e-03 | total 4.23e-01 | scales [14.709007  6.684923]
# [Adam] Step 26600 | pde 3.01e-01 | bc 1.40e-02 | data 3.81e-04 | TV loss 2.01e-03 | total 4.81e-01 | scales [14.708984   6.6839705]
# [Adam] Step 26800 | pde 1.56e-01 | bc 1.48e-02 | data 3.95e-04 | TV loss 2.03e-03 | total 3.46e-01 | scales [14.708883  6.683966]
# [Adam] Step 27000 | pde 3.03e-01 | bc 8.88e-03 | data 4.72e-04 | TV loss 2.02e-03 | total 4.41e-01 | scales [14.708858  6.682608]
# [Adam] Step 27200 | pde 1.33e-01 | bc 3.20e-02 | data 3.46e-04 | TV loss 2.04e-03 | total 4.90e-01 | scales [14.708744  6.680892]
# [Adam] Step 27400 | pde 1.09e-01 | bc 2.69e-02 | data 3.40e-04 | TV loss 1.99e-03 | total 4.13e-01 | scales [14.708713   6.6808186]
# [Adam] Step 27600 | pde 1.17e-01 | bc 2.78e-02 | data 3.63e-04 | TV loss 2.02e-03 | total 4.33e-01 | scales [14.708672   6.6807923]
# [Adam] Step 27800 | pde 1.96e-01 | bc 5.33e-03 | data 4.11e-04 | TV loss 1.99e-03 | total 2.92e-01 | scales [14.708684   6.6808276]
# [Adam] Step 28000 | pde 1.22e-01 | bc 1.56e-02 | data 4.31e-04 | TV loss 2.01e-03 | total 3.24e-01 | scales [14.708673  6.67945 ]
# [Adam] Step 28200 | pde 1.09e-01 | bc 1.21e-02 | data 4.21e-04 | TV loss 2.01e-03 | total 2.75e-01 | scales [14.708642  6.679064]
# [Adam] Step 28400 | pde 2.09e-01 | bc 5.23e-03 | data 3.89e-04 | TV loss 2.01e-03 | total 3.03e-01 | scales [14.708532  6.678111]
# [Adam] Step 28600 | pde 1.49e-01 | bc 5.56e-03 | data 3.58e-04 | TV loss 2.06e-03 | total 2.43e-01 | scales [14.708492  6.676853]
# [Adam] Step 28800 | pde 1.95e-01 | bc 1.31e-02 | data 4.45e-04 | TV loss 2.00e-03 | total 3.72e-01 | scales [14.708469   6.6755157]
# [Adam] Step 29000 | pde 1.08e-01 | bc 1.02e-02 | data 4.30e-04 | TV loss 2.07e-03 | total 2.55e-01 | scales [14.708481   6.6753826]
# [Adam] Step 29200 | pde 1.56e-01 | bc 4.07e-03 | data 4.09e-04 | TV loss 1.97e-03 | total 2.40e-01 | scales [14.70835    6.6744823]
# [Adam] Step 29400 | pde 1.65e-01 | bc 6.16e-03 | data 3.73e-04 | TV loss 2.04e-03 | total 2.66e-01 | scales [14.708276  6.673293]
# [Adam] Step 29600 | pde 1.16e-01 | bc 7.31e-03 | data 3.85e-04 | TV loss 2.06e-03 | total 2.30e-01 | scales [14.708167   6.6721206]
# [Adam] Step 29800 | pde 1.21e-01 | bc 4.35e-03 | data 3.76e-04 | TV loss 2.01e-03 | total 2.04e-01 | scales [14.708083   6.6716285]
# [Adam] Step 30000 | pde 1.14e-01 | bc 9.88e-03 | data 3.84e-04 | TV loss 2.01e-03 | total 2.53e-01 | scales [14.708027  6.671559]
# [Adam] Step 30200 | pde 7.39e-02 | bc 1.76e-02 | data 3.58e-04 | TV loss 2.00e-03 | total 2.88e-01 | scales [14.707907   6.6713114]
# [Adam] Step 30400 | pde 8.03e-02 | bc 1.19e-02 | data 3.64e-04 | TV loss 2.02e-03 | total 2.38e-01 | scales [14.7079525  6.6715884]
# [Adam] Step 30600 | pde 8.56e-02 | bc 1.35e-02 | data 3.78e-04 | TV loss 2.02e-03 | total 2.60e-01 | scales [14.707942   6.6717043]
# [Adam] Step 30800 | pde 1.37e-01 | bc 4.40e-03 | data 3.88e-04 | TV loss 2.03e-03 | total 2.22e-01 | scales [14.70797    6.6711507]
# [Adam] Step 31000 | pde 1.35e-01 | bc 5.56e-03 | data 3.67e-04 | TV loss 2.03e-03 | total 2.30e-01 | scales [14.707896  6.669287]
# [Adam] Step 31200 | pde 8.63e-02 | bc 1.17e-02 | data 3.88e-04 | TV loss 2.01e-03 | total 2.44e-01 | scales [14.707787   6.6690583]
# [Adam] Step 31400 | pde 7.31e-02 | bc 8.71e-03 | data 4.05e-04 | TV loss 2.04e-03 | total 2.03e-01 | scales [14.707763   6.6694984]
# [Adam] Step 31600 | pde 8.20e-02 | bc 7.02e-03 | data 4.04e-04 | TV loss 2.02e-03 | total 1.95e-01 | scales [14.707721   6.6694174]
# [Adam] Step 31800 | pde 1.24e-01 | bc 8.40e-03 | data 3.92e-04 | TV loss 2.09e-03 | total 2.50e-01 | scales [14.707636  6.668746]
# [Adam] Step 32000 | pde 1.30e-01 | bc 1.08e-02 | data 3.83e-04 | TV loss 1.98e-03 | total 2.79e-01 | scales [14.7076235  6.667475 ]
# [Adam] Step 32200 | pde 9.49e-02 | bc 1.36e-02 | data 4.24e-04 | TV loss 2.07e-03 | total 2.75e-01 | scales [14.707629   6.6678095]
# [Adam] Step 32400 | pde 1.17e-01 | bc 4.59e-03 | data 3.90e-04 | TV loss 2.03e-03 | total 2.04e-01 | scales [14.707574  6.667864]
# [Adam] Step 32600 | pde 1.29e-01 | bc 4.32e-03 | data 3.90e-04 | TV loss 2.01e-03 | total 2.13e-01 | scales [14.707494   6.6667867]
# [Adam] Step 32800 | pde 8.00e-02 | bc 1.06e-02 | data 3.87e-04 | TV loss 2.06e-03 | total 2.27e-01 | scales [14.707396   6.6660376]
# [Adam] Step 33000 | pde 8.96e-02 | bc 1.00e-02 | data 3.92e-04 | TV loss 2.07e-03 | total 2.31e-01 | scales [14.707355   6.6657195]
# [Adam] Step 33200 | pde 1.30e-01 | bc 4.95e-03 | data 3.91e-04 | TV loss 2.06e-03 | total 2.21e-01 | scales [14.707331   6.6647997]
# [Adam] Step 33400 | pde 7.44e-02 | bc 5.89e-03 | data 3.87e-04 | TV loss 1.99e-03 | total 1.74e-01 | scales [14.707251  6.664003]
# [Adam] Step 33600 | pde 7.62e-02 | bc 1.06e-02 | data 4.01e-04 | TV loss 2.05e-03 | total 2.24e-01 | scales [14.707258   6.6639333]
# [Adam] Step 33800 | pde 7.05e-02 | bc 1.04e-02 | data 4.19e-04 | TV loss 2.07e-03 | total 2.19e-01 | scales [14.707238   6.6634917]
# [Adam] Step 34000 | pde 7.31e-02 | bc 7.53e-03 | data 4.18e-04 | TV loss 2.06e-03 | total 1.92e-01 | scales [14.70721    6.6633015]
# [Adam] Step 34200 | pde 9.66e-02 | bc 3.74e-03 | data 3.86e-04 | TV loss 2.05e-03 | total 1.75e-01 | scales [14.707126   6.6629233]
# [Adam] Step 34400 | pde 7.97e-02 | bc 5.71e-03 | data 3.65e-04 | TV loss 2.01e-03 | total 1.75e-01 | scales [14.707106   6.6627584]
# [Adam] Step 34600 | pde 8.46e-02 | bc 7.48e-03 | data 3.65e-04 | TV loss 2.05e-03 | total 1.98e-01 | scales [14.707016   6.6624475]
# [Adam] Step 34800 | pde 8.44e-02 | bc 4.39e-03 | data 3.80e-04 | TV loss 2.03e-03 | total 1.68e-01 | scales [14.7069645  6.661869 ]
# [Adam] Step 35000 | pde 7.55e-02 | bc 7.44e-03 | data 3.64e-04 | TV loss 2.02e-03 | total 1.88e-01 | scales [14.706895   6.6610303]
# [Adam] Step 35200 | pde 7.24e-02 | bc 7.14e-03 | data 3.41e-04 | TV loss 2.03e-03 | total 1.80e-01 | scales [14.706885   6.6605787]
# [Adam] Step 35400 | pde 8.46e-02 | bc 3.83e-03 | data 3.85e-04 | TV loss 2.01e-03 | total 1.63e-01 | scales [14.706894  6.660308]
# [Adam] Step 35600 | pde 8.69e-02 | bc 3.99e-03 | data 3.61e-04 | TV loss 2.07e-03 | total 1.65e-01 | scales [14.70681   6.659258]
# [Adam] Step 35800 | pde 1.03e-01 | bc 6.92e-03 | data 3.53e-04 | TV loss 2.07e-03 | total 2.10e-01 | scales [14.706776  6.658662]
# [Adam] Step 36000 | pde 8.00e-02 | bc 3.33e-03 | data 3.87e-04 | TV loss 2.02e-03 | total 1.54e-01 | scales [14.706767  6.657932]
# [Adam] Step 36200 | pde 8.50e-02 | bc 3.64e-03 | data 3.93e-04 | TV loss 2.04e-03 | total 1.63e-01 | scales [14.70675    6.6572943]
# [Adam] Step 36400 | pde 6.87e-02 | bc 4.93e-03 | data 3.78e-04 | TV loss 2.04e-03 | total 1.58e-01 | scales [14.706668  6.65741 ]
# [Adam] Step 36600 | pde 6.60e-02 | bc 5.01e-03 | data 3.92e-04 | TV loss 2.08e-03 | total 1.57e-01 | scales [14.706631  6.656932]
# [Adam] Step 36800 | pde 6.74e-02 | bc 5.73e-03 | data 4.11e-04 | TV loss 2.06e-03 | total 1.68e-01 | scales [14.706594   6.6565876]
# [Adam] Step 37000 | pde 5.88e-02 | bc 4.79e-03 | data 3.99e-04 | TV loss 2.04e-03 | total 1.49e-01 | scales [14.706535   6.6562295]
# [Adam] Step 37200 | pde 7.72e-02 | bc 7.69e-03 | data 3.80e-04 | TV loss 2.04e-03 | total 1.94e-01 | scales [14.706477   6.6556287]
# [Adam] Step 37400 | pde 6.16e-02 | bc 7.33e-03 | data 3.64e-04 | TV loss 2.06e-03 | total 1.73e-01 | scales [14.706474  6.655215]
# [Adam] Step 37600 | pde 6.87e-02 | bc 4.73e-03 | data 3.64e-04 | TV loss 2.03e-03 | total 1.54e-01 | scales [14.706421   6.6551595]
# [Adam] Step 37800 | pde 6.97e-02 | bc 4.13e-03 | data 3.61e-04 | TV loss 2.07e-03 | total 1.49e-01 | scales [14.706369  6.655087]
# [Adam] Step 38000 | pde 7.10e-02 | bc 3.57e-03 | data 3.66e-04 | TV loss 2.10e-03 | total 1.45e-01 | scales [14.706341  6.654442]
# [Adam] Step 38200 | pde 6.59e-02 | bc 4.58e-03 | data 3.59e-04 | TV loss 2.04e-03 | total 1.50e-01 | scales [14.706283   6.6542006]
# [Adam] Step 38400 | pde 7.10e-02 | bc 3.45e-03 | data 3.59e-04 | TV loss 2.05e-03 | total 1.43e-01 | scales [14.706232   6.6535435]
# [Adam] Step 38600 | pde 6.66e-02 | bc 4.58e-03 | data 3.67e-04 | TV loss 2.05e-03 | total 1.51e-01 | scales [14.706211  6.652969]
# [Adam] Step 38800 | pde 6.32e-02 | bc 6.64e-03 | data 3.73e-04 | TV loss 2.01e-03 | total 1.69e-01 | scales [14.706212  6.652483]
# [Adam] Step 39000 | pde 5.80e-02 | bc 5.46e-03 | data 3.50e-04 | TV loss 2.02e-03 | total 1.50e-01 | scales [14.706184  6.651984]
# [Adam] Step 39200 | pde 5.38e-02 | bc 5.39e-03 | data 3.39e-04 | TV loss 2.06e-03 | total 1.44e-01 | scales [14.706162   6.6520104]
# [Adam] Step 39400 | pde 5.46e-02 | bc 4.24e-03 | data 3.63e-04 | TV loss 2.02e-03 | total 1.35e-01 | scales [14.706156   6.6516266]
# [Adam] Step 39600 | pde 6.25e-02 | bc 4.03e-03 | data 3.73e-04 | TV loss 2.05e-03 | total 1.42e-01 | scales [14.706122   6.6513715]
# [Adam] Step 39800 | pde 6.00e-02 | bc 3.68e-03 | data 3.72e-04 | TV loss 2.04e-03 | total 1.36e-01 | scales [14.706088   6.6509366]
# [Adam] Step 40000 | pde 6.53e-02 | bc 4.25e-03 | data 3.73e-04 | TV loss 2.04e-03 | total 1.47e-01 | scales [14.706046  6.650709]
# [Adam] Step 40200 | pde 5.78e-02 | bc 4.71e-03 | data 3.79e-04 | TV loss 2.05e-03 | total 1.45e-01 | scales [14.7059765  6.65047  ]
# [Adam] Step 40400 | pde 6.55e-02 | bc 6.93e-03 | data 3.47e-04 | TV loss 2.04e-03 | total 1.72e-01 | scales [14.706012  6.649903]
# [Adam] Step 40600 | pde 5.32e-02 | bc 9.66e-03 | data 3.48e-04 | TV loss 2.05e-03 | total 1.87e-01 | scales [14.70598    6.6497636]
# [Adam] Step 40800 | pde 4.62e-02 | bc 5.71e-03 | data 3.36e-04 | TV loss 2.04e-03 | total 1.39e-01 | scales [14.706003   6.6497307]
# [Adam] Step 41000 | pde 4.71e-02 | bc 6.08e-03 | data 3.57e-04 | TV loss 2.04e-03 | total 1.46e-01 | scales [14.705994   6.6495194]
# [Adam] Step 41200 | pde 6.45e-02 | bc 5.82e-03 | data 3.86e-04 | TV loss 2.02e-03 | total 1.63e-01 | scales [14.705963   6.6496706]
# [Adam] Step 41400 | pde 5.04e-02 | bc 4.25e-03 | data 3.64e-04 | TV loss 2.04e-03 | total 1.31e-01 | scales [14.7059765  6.6488924]
# [Adam] Step 41600 | pde 6.53e-02 | bc 3.44e-03 | data 3.59e-04 | TV loss 2.05e-03 | total 1.38e-01 | scales [14.70597   6.648693]
# [Adam] Step 41800 | pde 4.71e-02 | bc 4.20e-03 | data 3.83e-04 | TV loss 2.06e-03 | total 1.29e-01 | scales [14.7059555  6.6482706]
# [Adam] Step 42000 | pde 4.51e-02 | bc 4.44e-03 | data 3.56e-04 | TV loss 2.02e-03 | total 1.27e-01 | scales [14.7059355  6.6478047]
# [Adam] Step 42200 | pde 5.23e-02 | bc 3.35e-03 | data 3.44e-04 | TV loss 1.99e-03 | total 1.22e-01 | scales [14.705915  6.647222]
# [Adam] Step 42400 | pde 5.61e-02 | bc 3.24e-03 | data 3.67e-04 | TV loss 2.06e-03 | total 1.27e-01 | scales [14.705903   6.6471405]
# [Adam] Step 42600 | pde 4.91e-02 | bc 4.03e-03 | data 3.54e-04 | TV loss 2.02e-03 | total 1.27e-01 | scales [14.705862   6.6469913]
# [Adam] Step 42800 | pde 5.40e-02 | bc 3.34e-03 | data 3.69e-04 | TV loss 2.03e-03 | total 1.26e-01 | scales [14.705846  6.646356]
# [Adam] Step 43000 | pde 5.00e-02 | bc 3.92e-03 | data 3.45e-04 | TV loss 2.07e-03 | total 1.26e-01 | scales [14.705834   6.6461616]
# [Adam] Step 43200 | pde 5.42e-02 | bc 3.47e-03 | data 3.70e-04 | TV loss 2.03e-03 | total 1.28e-01 | scales [14.705778  6.645936]
# [Adam] Step 43400 | pde 5.82e-02 | bc 3.65e-03 | data 3.53e-04 | TV loss 2.05e-03 | total 1.32e-01 | scales [14.70574  6.6457 ]
# [Adam] Step 43600 | pde 5.14e-02 | bc 3.02e-03 | data 3.59e-04 | TV loss 2.06e-03 | total 1.20e-01 | scales [14.705679  6.645345]
# [Adam] Step 43800 | pde 5.11e-02 | bc 3.24e-03 | data 3.75e-04 | TV loss 2.05e-03 | total 1.23e-01 | scales [14.705651  6.645156]
# [Adam] Step 44000 | pde 4.93e-02 | bc 3.56e-03 | data 3.56e-04 | TV loss 2.02e-03 | total 1.22e-01 | scales [14.705592  6.644814]
# [Adam] Step 44200 | pde 4.86e-02 | bc 3.22e-03 | data 3.55e-04 | TV loss 2.07e-03 | total 1.18e-01 | scales [14.705551  6.644304]
# [Adam] Step 44400 | pde 4.09e-02 | bc 4.35e-03 | data 3.54e-04 | TV loss 2.06e-03 | total 1.22e-01 | scales [14.705504   6.6440864]
# [Adam] Step 44600 | pde 4.57e-02 | bc 3.94e-03 | data 3.61e-04 | TV loss 2.03e-03 | total 1.23e-01 | scales [14.70548   6.643651]
# [Adam] Step 44800 | pde 4.74e-02 | bc 3.23e-03 | data 3.66e-04 | TV loss 2.06e-03 | total 1.18e-01 | scales [14.705463   6.6437798]
# [Adam] Step 45000 | pde 4.87e-02 | bc 3.12e-03 | data 3.58e-04 | TV loss 2.07e-03 | total 1.18e-01 | scales [14.705446  6.643626]
# [Adam] Step 45200 | pde 5.38e-02 | bc 3.35e-03 | data 3.52e-04 | TV loss 2.09e-03 | total 1.25e-01 | scales [14.705418   6.6432414]
# [Adam] Step 45400 | pde 4.59e-02 | bc 3.02e-03 | data 3.66e-04 | TV loss 2.08e-03 | total 1.15e-01 | scales [14.7053795  6.6429615]
# [Adam] Step 45600 | pde 4.55e-02 | bc 2.95e-03 | data 3.59e-04 | TV loss 2.05e-03 | total 1.13e-01 | scales [14.705323  6.642706]
# [Adam] Step 45800 | pde 4.57e-02 | bc 3.16e-03 | data 3.60e-04 | TV loss 2.03e-03 | total 1.15e-01 | scales [14.705313  6.642225]
# [Adam] Step 46000 | pde 4.68e-02 | bc 3.24e-03 | data 3.46e-04 | TV loss 2.06e-03 | total 1.16e-01 | scales [14.7052555  6.641758 ]
# [Adam] Step 46200 | pde 4.33e-02 | bc 3.53e-03 | data 3.63e-04 | TV loss 2.05e-03 | total 1.17e-01 | scales [14.705227   6.6411457]
# [Adam] Step 46400 | pde 4.52e-02 | bc 2.91e-03 | data 3.69e-04 | TV loss 2.06e-03 | total 1.13e-01 | scales [14.7052    6.640928]
# [Adam] Step 46600 | pde 4.97e-02 | bc 3.15e-03 | data 3.57e-04 | TV loss 2.07e-03 | total 1.19e-01 | scales [14.7051325  6.6407995]
# [Adam] Step 46800 | pde 8.33e-02 | bc 3.35e-03 | data 3.76e-04 | TV loss 2.12e-03 | total 1.57e-01 | scales [14.70511    6.6403894]
# [Adam] Step 47000 | pde 4.88e-02 | bc 3.44e-03 | data 3.58e-04 | TV loss 2.03e-03 | total 1.21e-01 | scales [14.705098  6.640187]
# [Adam] Step 47200 | pde 5.14e-02 | bc 3.86e-03 | data 3.72e-04 | TV loss 2.10e-03 | total 1.29e-01 | scales [14.705115   6.6400714]
# [Adam] Step 47400 | pde 4.67e-02 | bc 3.13e-03 | data 3.59e-04 | TV loss 2.05e-03 | total 1.16e-01 | scales [14.705048   6.6399584]
# [Adam] Step 47600 | pde 4.76e-02 | bc 3.14e-03 | data 3.65e-04 | TV loss 2.03e-03 | total 1.17e-01 | scales [14.70501    6.6397734]
# [Adam] Step 47800 | pde 4.91e-02 | bc 3.06e-03 | data 3.46e-04 | TV loss 2.05e-03 | total 1.16e-01 | scales [14.704977   6.6397934]
# [Adam] Step 48000 | pde 5.04e-02 | bc 3.22e-03 | data 3.58e-04 | TV loss 2.03e-03 | total 1.20e-01 | scales [14.704896   6.6394415]
# [Adam] Step 48200 | pde 4.85e-02 | bc 3.17e-03 | data 3.62e-04 | TV loss 2.06e-03 | total 1.18e-01 | scales [14.704876   6.6393394]
# [Adam] Step 48400 | pde 4.74e-02 | bc 3.05e-03 | data 3.59e-04 | TV loss 2.06e-03 | total 1.16e-01 | scales [14.70484    6.6390176]
# [Adam] Step 48600 | pde 4.53e-02 | bc 3.32e-03 | data 3.60e-04 | TV loss 2.03e-03 | total 1.16e-01 | scales [14.7047825  6.638823 ]
# [Adam] Step 48800 | pde 4.69e-02 | bc 3.23e-03 | data 3.52e-04 | TV loss 2.02e-03 | total 1.16e-01 | scales [14.704741   6.6387486]
# [Adam] Step 49000 | pde 4.57e-02 | bc 3.03e-03 | data 3.60e-04 | TV loss 2.06e-03 | total 1.14e-01 | scales [14.70466    6.6384826]
# [Adam] Step 49200 | pde 4.32e-02 | bc 3.42e-03 | data 3.68e-04 | TV loss 2.07e-03 | total 1.16e-01 | scales [14.704621  6.638167]
# [Adam] Step 49400 | pde 4.12e-02 | bc 2.92e-03 | data 3.68e-04 | TV loss 2.10e-03 | total 1.09e-01 | scales [14.704572  6.63786 ]
# [Adam] Step 49600 | pde 4.70e-02 | bc 3.05e-03 | data 3.54e-04 | TV loss 2.06e-03 | total 1.15e-01 | scales [14.704516   6.6375637]
# [Adam] Step 49800 | pde 4.72e-02 | bc 2.95e-03 | data 3.56e-04 | TV loss 2.09e-03 | total 1.14e-01 | scales [14.704473  6.637404]
# [Adam] Step 50000 | pde 4.69e-02 | bc 3.15e-03 | data 3.52e-04 | TV loss 2.04e-03 | total 1.16e-01 | scales [14.704439  6.63715 ]

# %%
def u_real(x,y):
    features = gamma(x, y, params_uv['sigma'])
    return forward_func(params_uv['layers'], features)[0] * U_norm[f_test]

x = np.linspace(-1, 1, 500)
y = np.linspace(0, 0.6, 150)

u_grid = jax.vmap(jax.vmap(u_real, in_axes=(0, None)), in_axes=(None, 0))(x, 2*y/H - 1)

fig, ax = plt.subplots(figsize=(8, 4))

pcm = ax.pcolormesh(x, y, u_grid, cmap='RdBu_r', rasterized=True)

ax.set_title('Re(u) PINN')

fig.colorbar(pcm, ax=ax, shrink=0.8, location='left')
plt.tight_layout()
#plt.savefig('fig/2D_WG_PINN_forward.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
loss_forward_arr = np.array(loss_forward)
pde_losses = loss_forward_arr[:, 0]
bc_losses = loss_forward_arr[:, 1]
total_losses = pde_losses + bc_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_forward))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Parial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.show()

loss_inverse_arr = np.array(loss_inverse)
pde_losses = loss_inverse_arr[:,0]
bc_losses = loss_inverse_arr[:,1]
data_losses = loss_inverse_arr[:,2]
TV_losses = loss_inverse_arr[:,3]
total_losses = pde_losses + bc_losses + data_losses + TV_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_inverse_arr))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")
ax1.semilogy(x_axis, data_losses, label="Data Loss")
ax1.semilogy(x_axis, TV_losses, label="TV loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Parial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
#plt.savefig('fig/2D_Wave_guide_c_map.pdf')
plt.show()
