# %% [markdown]
# ## PINN for the Helmholtz inverse problem

# %%
import jax
import jax.numpy as jnp
import functools
import numpy as np
import optax
import matplotlib.pyplot as plt
from data_load import WaveguideBoundaryData

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# **Data loading**

# %%
#Domain Omega : [-1,1]x[0,0.6]
#conditions de neuman en y=0 et y=0.6
H = 0.6
L = 1

data_loader_left = WaveguideBoundaryData('data/pinn_boundary_left_barre_contrast20percent_mode0.csv')
data_loader_right = WaveguideBoundaryData('data/pinn_boundary_right_barre_contrast20percent_mode0.csv')

X_left, Y_left, U_re_left, U_im_left, freq = data_loader_left.get_training_data()
X_right, Y_right, U_re_right, U_im_right, _ = data_loader_right.get_training_data()

Y_left = Y_left[freq[0]]
Y_right = Y_right[freq[0]]

# %% [markdown]
# **Normalisation**

# %%
# x is already in [-1,1]
#y and u [-1,1]

Y_norm = jnp.max(Y_left)
Y_left=2*Y_left/Y_norm - 1
Y_right=2*Y_right/Y_norm - 1

U_norm = {}
U_left_norm = {}
U_right_norm = {}

for f in freq:
    U_norm[f] = np.sqrt(jnp.max(np.concatenate((U_re_left[f]**2 + U_im_left[f]**2,U_re_right[f]**2 + U_im_right[f]**2))))
    U_re_left[f]/=U_norm[f]
    U_im_left[f]/=U_norm[f]
    U_re_right[f]/=U_norm[f]
    U_im_right[f]/=U_norm[f]
    U_left_norm[f] = jnp.stack([U_re_left[f],U_im_left[f]], axis=1)
    U_right_norm[f] = jnp.stack([U_re_right[f],U_im_right[f]], axis=1)

# %% [markdown]
# **Initialization**

# %%
key = jax.random.key(0)

c0 = 340
cmax = 1.5 * c0
cmin = 0.5 * c0

msq_min = 1.0 / (cmax**2)
msq_max = 1.0 / (cmin**2)

fmax = jnp.max(freq)
N_modes = int(jnp.round(2*H*fmax/c0)) + 5
contrast = 1

m = 64

key, subkey = jax.random.split(key)

B_base = jax.random.normal(subkey, (m, 2))

def gamma(x, y, sigma):
    x_phys = x * L 
    y_phys = (y + 1.0) * H / 2.0
    v_phys = jnp.array([x_phys, y_phys])
    B = B_base * sigma
    return jnp.concatenate([jnp.cos(B@v_phys),jnp.sin(B@v_phys)])

n_gauss_legendre = 20

y_gauss_legendre, w_gauss_legendre = np.polynomial.legendre.leggauss(n_gauss_legendre)

n_input = 2
n_layers_uv = [2*m, 64, 64, 64, 64, 2]
n_layers_m = [n_input, 64, 64, 1]

#Xavier init

def init_layers(key, n_layers):
    layers = []
    keys = jax.random.split(key, len(n_layers) - 1)
    
    for i, k in enumerate(keys):
        W = jax.random.normal(k, (n_layers[i], n_layers[i+1])) * jnp.sqrt(2.0 / (n_layers[i] + n_layers[i+1]))
        b = jnp.zeros(n_layers[i+1])
        layers.append({"W": W, "b": b})
    return layers

def init_layers_uv(key, n_layers, f_val, mode_val):
    term_under_sqrt = (2 * jnp.pi * f_val / (contrast * 340.0))**2 - (mode_val * jnp.pi / H)**2
    kx = jnp.sqrt(jnp.maximum(term_under_sqrt, 0.0))
    ky = mode_val * jnp.pi / H
    
    layers_uv = init_layers(key, n_layers)
    return {'layers': layers_uv, 'sigma': jnp.array([kx, ky])}

key, subkey_m = jax.random.split(key)
layers_m = init_layers(subkey_m, n_layers_m)
layers_m[-1]["b"] = -jnp.log(27.0 / 5.0)

params_uv = {}

for f in freq:
    key, subkey_f = jax.random.split(key)
    params_uv[float(f)] = init_layers_uv(subkey_f, n_layers_uv, f, 0)

# %% [markdown]
# **The Forward pass**

# %%
def forward_func(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = Z @ layers[-1]["W"] + layers[-1]["b"]
    return Z
 
def forward_params(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = msq_min + (msq_max-msq_min) * jax.nn.sigmoid(Z @ layers[-1]["W"] + layers[-1]["b"])
    return Z.squeeze()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# **The loss function**

# %%
y_quad = (y_gauss_legendre + 1.0) * H / 2.0
w_quad = w_gauss_legendre * H / 2.0
n_modes = jnp.arange(N_modes)
a_n = jnp.sqrt(2/H) * jnp.ones(N_modes)
a_n = a_n.at[0].set(jnp.sqrt(1/H))
C_quad = a_n[:, None] * jnp.cos(n_modes[:, None] * jnp.pi * y_quad[None, :] / H)

def loss_fn(params_uv, layers_m, x, y, f, target_u_left, target_u_right, y_bnd_left, y_bnd_right, u_norm_val, weights, is_warmup=False, use_healthy_guide=False):

    def uv(x,y):
        features = gamma(x, y, params_uv['sigma'])
        return forward_func(params_uv['layers'], features)
    
    def m(x,y):
        return forward_params(layers_m, jnp.array([x, y]))
    
    def k2(x,y):
        if use_healthy_guide:
            return (2*jnp.pi*f/c0)**2
        else:
            return (2*jnp.pi*f)**2*m(x,y)
    
    def uv_x(x, y):
        return jax.jacfwd(uv, argnums=0)(x, y)/L
    
    def uv_y(x, y):
        return jax.jacfwd(uv, argnums=1)(x, y)*(2/H)
    
    def m_x(x,y):
        return jax.grad(m, argnums=0)(x, y)/L
    
    def m_y(x,y):
        return jax.grad(m, argnums=1)(x, y)*(2/H)

    def pde_residual(x, y):
        uv_xx = jax.jacfwd(jax.jacfwd(uv, argnums=0), argnums=0)(x, y) / L**2
        uv_yy = jax.jacfwd(jax.jacfwd(uv, argnums=1), argnums=1)(x, y)*(2/H)**2
        return uv_xx + uv_yy + k2(x,y)*uv(x,y)
    
    k0 = 2*jnp.pi*f/c0
    beta_n = jnp.sqrt(k0**2 - (n_modes*jnp.pi/H)**2 +0j)
    
    def compute_dtn_loss(x_bnd, y_data, sign, A_inc=None):
        uv_quad = jax.vmap(uv, in_axes=(None, 0))(x_bnd, y_gauss_legendre)
        U_quad_complex = uv_quad[:, 0] + 1j * uv_quad[:, 1]
        
        u_n = C_quad @ (w_quad * U_quad_complex)
        
        dtn_n = sign * 1j * beta_n * u_n
        if A_inc is not None:
            dtn_n = dtn_n + 2j * beta_n * A_inc
        
        def DtN_eval(y_eval):
            C_y = a_n * jnp.cos(n_modes * jnp.pi * (y_eval+1)/2)
            return C_y @ dtn_n
            
        dtn_pred_complex = jax.vmap(DtN_eval)(y_data)
        
        dtn_actual = jax.vmap(uv_x, in_axes=(None, 0))(x_bnd, y_data)
        dtn_actual_complex = dtn_actual[:, 0] + 1j * dtn_actual[:, 1]
        
        return jnp.mean(jnp.abs(dtn_pred_complex - dtn_actual_complex)**2)

    A_inc_left = jnp.zeros(N_modes, dtype=jnp.complex64)
    amplitude_incidente = jnp.exp(-1j * beta_n[0] * L) / u_norm_val
    A_inc_left = A_inc_left.at[0].set(amplitude_incidente)
    #residual
    vmap_pde_residual = jax.vmap(pde_residual, in_axes=(0, 0))
    pde_loss = jnp.mean(vmap_pde_residual(x, y)**2)
    #boundary conditions
    dtn_loss_left = compute_dtn_loss(-1.0, y, sign=-1, A_inc=A_inc_left)
    dtn_loss_right = compute_dtn_loss(1.0, y, sign=1, A_inc=None)
    neum_loss = jnp.mean(jax.vmap(uv_y, in_axes=(0, None))(x, 1.0)**2 + jax.vmap(uv_y, in_axes=(0, None))(x, -1.0)**2)
    bc_loss = neum_loss + dtn_loss_left + dtn_loss_right
    #data + TV
    if is_warmup:
        data_loss = 0.0
        TV_loss = 0.0
    else:
        vmap_uv_y = jax.vmap(uv, (None,0))
        data_loss = jnp.mean((vmap_uv_y(-1.0,y_bnd_left) - target_u_left)**2)+jnp.mean((vmap_uv_y(1.0,y_bnd_right) - target_u_right)**2)
        vmap_m_x = jax.vmap(m_x, (0,0))
        vmap_m_y = jax.vmap(m_y, (0,0))
        TV_loss = jnp.mean(jnp.sqrt(c0**2*vmap_m_x(x,y)**2 + c0**2*vmap_m_y(x,y)**2 + 10**-8))
        

    total_loss = weights[0]*pde_loss + weights[1]*bc_loss + weights[2]*data_loss + weights[3]*TV_loss
    
    return total_loss, (pde_loss, bc_loss, data_loss, TV_loss)

# %% [markdown]
# **Le training**

# %%
lr_uv = 1e-3
lr_m = 3e-4

def make_train_step_forward(adam_opt, lbfgs_opt):

    @functools.partial(jax.jit, static_argnames=('use_lbfgs', 'use_healthy_guide'))
    def train_step_forward(params_uv, layers_m, opt_state_uv, x, y, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, use_lbfgs=False, use_healthy_guide=True):
        def loss_uv(p_uv):
            return loss_fn(p_uv, layers_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, is_warmup=True, use_healthy_guide=use_healthy_guide)

        (loss, aux), grads_uv = jax.value_and_grad(loss_uv, has_aux=True)(params_uv)

        if use_lbfgs:
            def value_fn(p_uv):
                v, _ = loss_uv(p_uv)
                return v
            updates_uv, opt_state_uv = lbfgs_opt.update(
                grads_uv, opt_state_uv, params_uv,
                value=loss, grad=grads_uv, value_fn=value_fn)
        else:
            updates_uv, opt_state_uv = adam_opt.update(grads_uv, opt_state_uv, params_uv)

        params_uv = optax.apply_updates(params_uv, updates_uv)
        return params_uv, opt_state_uv, loss, aux

    return train_step_forward


def make_train_step_inverse(adam_opt_uv, adam_opt_m, lbfgs_opt_packed):

    @functools.partial(jax.jit, static_argnames=('use_lbfgs',))
    def train_step_inverse(params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x, y, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, use_lbfgs=False):
        
        def loss_full(p_uv, l_m):
            # MODIFICATION : Explicite is_warmup=False et use_healthy_guide=False
            return loss_fn(p_uv, l_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, is_warmup=False, use_healthy_guide=False)
        
        (loss, aux), (grads_uv, grads_m) = jax.value_and_grad(loss_full, argnums=(0,1), has_aux=True)(params_uv, layers_m)

        if use_lbfgs:
            params_packed = {'uv': params_uv, 'm': layers_m}
            grads_packed = {'uv': grads_uv, 'm': grads_m}
            
            def value_fn_packed(p_packed):
                v, _ = loss_full(p_packed['uv'], p_packed['m'])
                return v

            updates_packed, opt_state_lbfgs = lbfgs_opt_packed.update(
                grads_packed, opt_state_lbfgs, params_packed,
                value=loss, grad=grads_packed, value_fn=value_fn_packed)
            
            params_packed = optax.apply_updates(params_packed, updates_packed)
            params_uv = params_packed['uv']
            layers_m = params_packed['m']
        else:
            updates_uv, opt_state_uv = adam_opt_uv.update(grads_uv, opt_state_uv, params_uv)
            params_uv = optax.apply_updates(params_uv, updates_uv)

            updates_m, opt_state_m = adam_opt_m.update(grads_m, opt_state_m, layers_m)
            layers_m = optax.apply_updates(layers_m, updates_m)

        return params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux

    return train_step_inverse


# --- Convergence criterion ---

def check_switch_criterion(loss_history, window=10, threshold=1e-3):
    """Returns True if the relative slope of the loss is below threshold."""
    if len(loss_history) < window:
        return False
    old_loss = loss_history[-window]
    new_loss = loss_history[-1]
    relative_slope = abs(new_loss - old_loss) / max(abs(old_loss), 1e-12)
    return relative_slope < threshold and jnp.mean(old_loss) < 1e-1


# --- Main training function ---

def train(params_uv, layers_m, N,
          max_steps_adam_phase1, max_steps_lbfgs_phase1,
          max_steps_adam_phase2, max_steps_lbfgs_phase2,
          freqs, eval_interval, switch_threshold, switch_window, key):

    loss_forward = []
    loss_inverse = []

    weights_phase1 = jnp.array([1.0, 10.0, 0.0, 0.0])

    best_params_uv = params_uv

    for i, freq in enumerate(freqs):
        print(f"\n{'='*60}")
        print(f"--- f = {freq} Hz ---")
        print(f"{'='*60}")

        param_uv = params_uv[freq]
        best_params_uv[freq] = param_uv
        best_params_m = layers_m
        best_loss = float('inf')

        use_healthy_guide_flag = (i == 0)

        # ============================================================
        # PHASE 1: Forward (only param_uv)
        # ============================================================

        print(f"\n--- Phase 1: Adam (max {max_steps_adam_phase1} steps) ---")

        cosine_p1 = optax.schedules.cosine_decay_schedule(
            init_value=lr_uv, decay_steps=max_steps_adam_phase1, alpha=0.1)
        adam_uv_p1 = optax.chain(
            optax.clip_by_global_norm(1.0),
            optax.scale_by_adam(),
            optax.scale_by_schedule(cosine_p1),
            optax.scale(-1.0))
        lbfgs_uv_p1 = optax.lbfgs()

        step_forward = make_train_step_forward(adam_uv_p1, lbfgs_uv_p1)
        opt_state_uv = adam_uv_p1.init(param_uv)

        loss_history_p1 = []
        switched_to_lbfgs = False

        for step in range(max_steps_adam_phase1):
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
            y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

            param_uv, opt_state_uv, loss, aux = step_forward(
                param_uv, layers_m, opt_state_uv, x, y, freq,
                U_left_norm[freq], U_right_norm[freq],
                Y_left, Y_right, U_norm[freq], weights_phase1,
                use_lbfgs=False, use_healthy_guide=use_healthy_guide_flag)

            loss_history_p1.append(float(loss))

            if step % eval_interval == 0:
                pde_loss, bc_loss, _, _ = aux
                loss_forward.append((pde_loss, bc_loss))
                print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                if loss < best_loss:
                    best_loss = loss
                    best_params_uv[freq] = param_uv

            if check_switch_criterion(loss_history_p1, window=switch_window, threshold=switch_threshold):
                print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                switched_to_lbfgs = True
                param_uv = best_params_uv[freq]
                break

        # --- Phase 1: L-BFGS ---
        if switched_to_lbfgs or max_steps_lbfgs_phase1 > 0:
            print(f"\n--- Phase 1: L-BFGS (max {max_steps_lbfgs_phase1} steps) ---")
            opt_state_uv = lbfgs_uv_p1.init(param_uv)

            # L-BFGS : Génération unique de x, y (les points restent constants)
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x_lbfgs = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
            y_lbfgs = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

            for step in range(max_steps_lbfgs_phase1):
                param_uv, opt_state_uv, loss, aux = step_forward(
                    param_uv, layers_m, opt_state_uv, x_lbfgs, y_lbfgs, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase1,
                    use_lbfgs=True, use_healthy_guide=use_healthy_guide_flag)

                if step % eval_interval == 0:
                    pde_loss, bc_loss, _, _ = aux
                    loss_forward.append((pde_loss, bc_loss))
                    print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv[freq] = param_uv

        # ============================================================
        # PHASE 2: Inverse (param_uv + layers_m)
        # ============================================================

        best_loss = float('inf')
        
        if max_steps_adam_phase2 > 0 or max_steps_lbfgs_phase2 > 0:

            print(f"\n--- Phase 2: Adam (max {max_steps_adam_phase2} steps) ---")

            cosine_uv_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_uv, decay_steps=max_steps_adam_phase2, alpha=0.1)
            cosine_m_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_m, decay_steps=max_steps_adam_phase2, alpha=0.1)
            adam_uv_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_uv_p2),
                optax.scale(-1.0))
            adam_m_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_m_p2),
                optax.scale(-1.0))
            
            lbfgs_packed_p2 = optax.lbfgs()

            step_inverse = make_train_step_inverse(adam_uv_p2, adam_m_p2, lbfgs_packed_p2)

            opt_state_uv = adam_uv_p2.init(param_uv)
            opt_state_m = adam_m_p2.init(layers_m)
            opt_state_lbfgs = None

            data_weight_schedule = optax.linear_schedule(
                init_value=1.0, end_value=100,
                transition_steps=max(max_steps_adam_phase2 // 3, 1))

            loss_history_p2 = []
            switched_to_lbfgs_p2 = False

            for step in range(max_steps_adam_phase2):
                weights_phase2 = jnp.array([1.0, 10.0, data_weight_schedule(step), 0.0])
                
                # ADAM : Nouveaux points x, y à chaque étape
                key, subkey1, subkey2 = jax.random.split(key, 3)
                x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
                y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

                param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux = step_inverse(
                    param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x, y, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase2,
                    use_lbfgs=False)

                loss_history_p2.append(float(loss))

                if step % eval_interval == 0:
                    pde_loss, bc_loss, data_loss, TV_loss = aux
                    loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                    print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv[freq] = param_uv
                        best_params_m = layers_m

                if check_switch_criterion(loss_history_p2, window=switch_window, threshold=switch_threshold):
                    print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                    switched_to_lbfgs_p2 = True
                    param_uv = best_params_uv[freq]
                    layers_m = best_params_m
                    break

            # --- Phase 2: L-BFGS ---
            if switched_to_lbfgs_p2 or max_steps_lbfgs_phase2 > 0:
                print(f"\n--- Phase 2: L-BFGS (max {max_steps_lbfgs_phase2} steps) ---")
                opt_state_lbfgs = lbfgs_packed_p2.init({'uv': param_uv, 'm': layers_m})
                weights_phase2_lbfgs = jnp.array([1.0, 10.0, 100.0, 1.0])

                # L-BFGS : Génération unique de x, y (les points restent constants)
                key, subkey1, subkey2 = jax.random.split(key, 3)
                x_lbfgs = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
                y_lbfgs = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

                for step in range(max_steps_lbfgs_phase2):
                    param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux = step_inverse(
                        param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x_lbfgs, y_lbfgs, freq,
                        U_left_norm[freq], U_right_norm[freq],
                        Y_left, Y_right, U_norm[freq], weights_phase2_lbfgs,
                        use_lbfgs=True)

                    if step % eval_interval == 0:
                        pde_loss, bc_loss, data_loss, TV_loss = aux
                        loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                        print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                        if loss < best_loss:
                            best_loss = loss
                            best_params_uv[freq] = param_uv
                            best_params_m = layers_m

    return best_params_uv, best_params_m, key, loss_forward, loss_inverse

# %% [markdown]
# **La phase d'entrainement**

# %%
N = 1000
eval_interval = 200
switch_threshold = 1e-5
switch_window = 10

max_steps_adam_phase1 = 3001
max_steps_lbfgs_phase1 = 601
max_steps_adam_phase2 = 50001
max_steps_lbfgs_phase2 = 601

freq = np.array([50.0,80.0,100.0])

key, subkey = jax.random.split(key)
params_uv, layers_m, key, loss_forward, loss_inverse = train(
    params_uv, layers_m, N,
    max_steps_adam_phase1, max_steps_lbfgs_phase1,
    max_steps_adam_phase2, max_steps_lbfgs_phase2,
    freq, eval_interval, switch_threshold, switch_window, key)
# Out:
# ============================================================
# --- f = 50.0 Hz ---
# ============================================================
#
# --- Phase 1: Adam (max 3001 steps) ---
# [Adam] Step 0 | pde 1.07e+00 | bc 7.29e+00 | total 7.39e+01 | scales [0.9229979  0.00099999]
# [Adam] Step 200 | pde 9.07e-04 | bc 1.89e-03 | total 1.98e-02 | scales [9.1202784e-01 2.8791243e-05]
# [Adam] Step 400 | pde 1.49e-03 | bc 4.30e-03 | total 4.45e-02 | scales [9.1000700e-01 1.0716422e-04]
# [Adam] Step 600 | pde 4.73e-04 | bc 1.04e-03 | total 1.08e-02 | scales [ 9.1063082e-01 -1.1780312e-04]
# [Adam] Step 800 | pde 2.44e-04 | bc 7.81e-04 | total 8.06e-03 | scales [9.1088957e-01 1.5464837e-05]
# [Adam] Step 1000 | pde 8.80e-04 | bc 1.75e-03 | total 1.84e-02 | scales [9.1030985e-01 3.8489976e-05]
# [Adam] Step 1200 | pde 1.82e-04 | bc 1.34e-03 | total 1.36e-02 | scales [9.1014916e-01 3.1540880e-05]
# [Adam] Step 1400 | pde 1.83e-04 | bc 3.74e-04 | total 3.93e-03 | scales [9.1000146e-01 1.6849814e-04]
# [Adam] Step 1600 | pde 5.63e-04 | bc 2.68e-03 | total 2.73e-02 | scales [9.0999186e-01 2.0865347e-04]
# [Adam] Step 1800 | pde 6.30e-05 | bc 1.05e-04 | total 1.11e-03 | scales [9.098484e-01 3.589088e-05]
# [Adam] Step 2000 | pde 3.46e-05 | bc 1.43e-04 | total 1.46e-03 | scales [ 9.0973800e-01 -1.6248985e-05]
# [Adam] Step 2200 | pde 2.49e-05 | bc 9.24e-05 | total 9.49e-04 | scales [9.0966058e-01 1.3833599e-04]
# [Adam] Step 2400 | pde 6.65e-06 | bc 5.79e-07 | total 1.24e-05 | scales [ 9.0961313e-01 -3.9253528e-06]
# [Adam] Step 2600 | pde 7.95e-06 | bc 1.02e-06 | total 1.81e-05 | scales [ 9.0958261e-01 -4.3458713e-06]
# [Adam] Step 2800 | pde 6.45e-06 | bc 1.66e-06 | total 2.31e-05 | scales [ 9.095590e-01 -6.374397e-06]
# [Adam] Step 3000 | pde 6.62e-06 | bc 2.27e-05 | total 2.33e-04 | scales [ 9.095346e-01 -6.475261e-05]
#
# --- Phase 1: L-BFGS (max 6001 steps) ---
# [LBFGS] Step 0 | pde 6.04e-06 | bc 1.37e-05 | total 1.43e-04 | scales [ 9.095415e-01 -6.414879e-05]
# [LBFGS] Step 200 | pde 1.25e-05 | bc 3.13e-05 | total 3.26e-04 | scales [ 0.9098448  -0.00272987]
# [LBFGS] Step 400 | pde 3.33e-05 | bc 4.51e-06 | total 7.83e-05 | scales [9.1046852e-01 4.4459794e-06]
# [LBFGS] Step 600 | pde 1.69e-05 | bc 5.53e-08 | total 1.75e-05 | scales [9.105897e-01 6.367927e-06]
# [LBFGS] Step 800 | pde 1.40e-05 | bc 1.04e-08 | total 1.41e-05 | scales [ 9.1042757e-01 -2.3941216e-06]
# [LBFGS] Step 1000 | pde 9.49e-06 | bc 1.11e-08 | total 9.60e-06 | scales [ 9.1036451e-01 -4.4822085e-04]
# [LBFGS] Step 1200 | pde 1.04e-05 | bc 8.29e-07 | total 1.87e-05 | scales [ 9.103657e-01 -2.263705e-06]
# [LBFGS] Step 1400 | pde 8.80e-06 | bc 7.66e-09 | total 8.88e-06 | scales [9.1036499e-01 2.9391083e-06]
# [LBFGS] Step 1600 | pde 8.37e-06 | bc 1.90e-07 | total 1.03e-05 | scales [9.1033864e-01 3.8093626e-07]
# [LBFGS] Step 1800 | pde 9.75e-06 | bc 2.03e-07 | total 1.18e-05 | scales [ 9.1046005e-01 -1.1496815e-06]
# [LBFGS] Step 2000 | pde 8.88e-06 | bc 6.70e-09 | total 8.95e-06 | scales [9.1036934e-01 6.8924583e-06]
# [LBFGS] Step 2200 | pde 1.19e-05 | bc 2.49e-05 | total 2.61e-04 | scales [ 0.9104251 -0.0018066]
# [LBFGS] Step 2400 | pde 1.68e-05 | bc 1.65e-05 | total 1.81e-04 | scales [ 0.91015434 -0.00259753]
# [LBFGS] Step 2600 | pde 1.20e-05 | bc 2.09e-05 | total 2.21e-04 | scales [9.1031778e-01 4.8975216e-04]
# [LBFGS] Step 2800 | pde 3.78e-05 | bc 1.27e-05 | total 1.65e-04 | scales [ 9.1089493e-01 -1.5293952e-05]
# [LBFGS] Step 3000 | pde 2.14e-05 | bc 1.62e-05 | total 1.83e-04 | scales [ 0.91067237 -0.00184707]
# [LBFGS] Step 3200 | pde 2.35e-05 | bc 1.10e-07 | total 2.46e-05 | scales [ 9.1067874e-01 -2.2270801e-06]
# [LBFGS] Step 3400 | pde 1.56e-05 | bc 1.63e-08 | total 1.58e-05 | scales [ 9.107657e-01 -4.673342e-06]
# [LBFGS] Step 3600 | pde 1.37e-05 | bc 1.07e-07 | total 1.47e-05 | scales [ 9.1083694e-01 -1.1998929e-07]
# [LBFGS] Step 3800 | pde 1.35e-05 | bc 9.07e-08 | total 1.44e-05 | scales [9.1084546e-01 1.2479325e-06]
# [LBFGS] Step 4000 | pde 9.23e-06 | bc 4.99e-08 | total 9.73e-06 | scales [9.108669e-01 8.924311e-06]
# [LBFGS] Step 4200 | pde 7.94e-06 | bc 1.10e-07 | total 9.04e-06 | scales [9.1096628e-01 3.6794518e-07]
# [LBFGS] Step 4400 | pde 7.51e-06 | bc 6.59e-08 | total 8.17e-06 | scales [9.1096264e-01 7.6145116e-06]
# [LBFGS] Step 4600 | pde 7.50e-06 | bc 1.71e-07 | total 9.21e-06 | scales [9.1096932e-01 2.9635314e-06]
# [LBFGS] Step 4800 | pde 4.86e-05 | bc 3.00e-05 | total 3.49e-04 | scales [9.104921e-01 8.325234e-04]
# [LBFGS] Step 5000 | pde 4.93e-05 | bc 3.02e-05 | total 3.51e-04 | scales [0.9114744  0.00096531]
# [LBFGS] Step 5200 | pde 1.44e-05 | bc 8.05e-07 | total 2.24e-05 | scales [9.107881e-01 6.171133e-06]
# [LBFGS] Step 5400 | pde 1.20e-05 | bc 2.29e-06 | total 3.49e-05 | scales [ 9.1097569e-01 -4.8355687e-06]
# [LBFGS] Step 5600 | pde 1.23e-05 | bc 7.68e-07 | total 2.00e-05 | scales [9.1118175e-01 1.6307840e-06]
# [LBFGS] Step 5800 | pde 8.94e-06 | bc 9.68e-06 | total 1.06e-04 | scales [9.1118151e-01 4.8620517e-05]
# [LBFGS] Step 6000 | pde 8.85e-06 | bc 6.87e-06 | total 7.75e-05 | scales [9.1126150e-01 3.3074157e-05]
#
# --- Phase 2: Adam (max 50001 steps) ---
# [Adam] Step 0 | pde 3.73e-03 | bc 1.72e-06 | data 1.05e-02 | TV loss 5.27e-04 | total 1.42e-02 | scales [0.9122615  0.00103306]
# [Adam] Step 200 | pde 7.04e-04 | bc 1.77e-03 | data 4.52e-04 | TV loss 1.16e-04 | total 1.94e-02 | scales [ 9.1024065e-01 -2.0260335e-04]
# [Adam] Step 400 | pde 7.76e-04 | bc 7.00e-04 | data 3.38e-04 | TV loss 1.14e-04 | total 8.91e-03 | scales [ 9.1126192e-01 -2.3799129e-04]
# [Adam] Step 600 | pde 9.28e-04 | bc 2.56e-03 | data 1.34e-03 | TV loss 1.13e-04 | total 3.26e-02 | scales [ 9.1140509e-01 -2.9057053e-05]
# [Adam] Step 800 | pde 8.35e-04 | bc 5.66e-04 | data 1.14e-04 | TV loss 1.12e-04 | total 7.15e-03 | scales [9.1111135e-01 1.4300094e-04]
# [Adam] Step 1000 | pde 2.07e-03 | bc 3.33e-03 | data 4.08e-04 | TV loss 1.14e-04 | total 3.82e-02 | scales [9.1133344e-01 2.0297279e-04]
# [Adam] Step 1200 | pde 1.59e-03 | bc 8.19e-04 | data 1.61e-04 | TV loss 1.19e-04 | total 1.11e-02 | scales [9.1135395e-01 2.7600073e-04]
# [Adam] Step 1400 | pde 1.21e-03 | bc 4.71e-04 | data 2.34e-04 | TV loss 1.20e-04 | total 8.10e-03 | scales [9.1091186e-01 6.6415773e-04]
# [Adam] Step 1600 | pde 1.14e-03 | bc 6.14e-04 | data 2.15e-04 | TV loss 1.29e-04 | total 9.53e-03 | scales [9.1132224e-01 2.6194804e-04]
# [Adam] Step 1800 | pde 1.83e-03 | bc 8.31e-04 | data 1.75e-04 | TV loss 1.50e-04 | total 1.22e-02 | scales [9.1115487e-01 5.2431691e-04]
# [Adam] Step 2000 | pde 1.32e-03 | bc 6.04e-04 | data 1.60e-04 | TV loss 1.96e-04 | total 9.42e-03 | scales [9.1167015e-01 2.1085571e-04]
# [Adam] Step 2200 | pde 9.87e-04 | bc 3.47e-04 | data 2.42e-04 | TV loss 3.03e-04 | total 7.86e-03 | scales [9.1210061e-01 1.3888918e-04]
# [Adam] Step 2400 | pde 8.87e-04 | bc 5.72e-04 | data 1.04e-04 | TV loss 4.77e-04 | total 8.20e-03 | scales [9.1177356e-01 3.5058009e-04]
# [Adam] Step 2600 | pde 6.17e-04 | bc 1.20e-03 | data 1.80e-04 | TV loss 7.39e-04 | total 1.56e-02 | scales [9.1192317e-01 4.0493201e-04]
# [Adam] Step 2800 | pde 2.26e-04 | bc 6.40e-04 | data 1.09e-04 | TV loss 9.66e-04 | total 8.55e-03 | scales [9.1313910e-01 4.0062583e-05]
# [Adam] Step 3000 | pde 2.46e-04 | bc 5.80e-04 | data 1.15e-04 | TV loss 1.09e-03 | total 8.21e-03 | scales [ 9.1331351e-01 -6.9777033e-04]
# [Adam] Step 3200 | pde 6.46e-04 | bc 2.31e-03 | data 8.54e-04 | TV loss 1.14e-03 | total 4.08e-02 | scales [ 9.1254014e-01 -9.2321658e-05]
# [Adam] Step 3400 | pde 1.60e-04 | bc 4.21e-04 | data 1.09e-04 | TV loss 1.18e-03 | total 6.69e-03 | scales [9.1324836e-01 7.0359558e-04]
# [Adam] Step 3600 | pde 1.92e-04 | bc 3.94e-04 | data 1.03e-04 | TV loss 1.18e-03 | total 6.44e-03 | scales [9.1421890e-01 3.1148558e-04]
# [Adam] Step 3800 | pde 2.11e-03 | bc 8.61e-04 | data 8.81e-04 | TV loss 1.13e-03 | total 3.15e-02 | scales [ 0.9143003  -0.00094888]
# [Adam] Step 4000 | pde 4.90e-04 | bc 9.37e-04 | data 2.06e-04 | TV loss 1.16e-03 | total 1.50e-02 | scales [9.1455019e-01 5.4802236e-05]
# [Adam] Step 4200 | pde 8.97e-05 | bc 2.84e-04 | data 6.89e-05 | TV loss 1.15e-03 | total 4.71e-03 | scales [9.1471916e-01 1.7188904e-04]
# [Adam] Step 4400 | pde 2.07e-04 | bc 4.68e-04 | data 5.16e-05 | TV loss 1.21e-03 | total 6.29e-03 | scales [9.1481030e-01 3.9134253e-04]
# [Adam] Step 4600 | pde 2.69e-04 | bc 6.79e-04 | data 1.83e-04 | TV loss 1.23e-03 | total 1.22e-02 | scales [ 9.148654e-01 -1.285106e-04]
# [Adam] Step 4800 | pde 1.73e-04 | bc 4.43e-04 | data 1.77e-04 | TV loss 1.22e-03 | total 9.83e-03 | scales [ 9.1485155e-01 -1.3958663e-04]
# [Adam] Step 5000 | pde 1.52e-04 | bc 4.78e-04 | data 9.51e-05 | TV loss 1.22e-03 | total 7.85e-03 | scales [9.1572702e-01 3.3817303e-04]
# [Adam] Step 5200 | pde 2.15e-03 | bc 2.40e-03 | data 1.13e-03 | TV loss 1.23e-03 | total 6.22e-02 | scales [ 9.1528445e-01 -3.0863125e-04]
# [Adam] Step 5400 | pde 1.11e-04 | bc 3.13e-04 | data 1.32e-04 | TV loss 1.18e-03 | total 7.60e-03 | scales [ 9.157041e-01 -1.463669e-04]
# [Adam] Step 5600 | pde 2.18e-03 | bc 3.16e-03 | data 9.97e-04 | TV loss 1.22e-03 | total 6.80e-02 | scales [ 9.1633105e-01 -3.3008028e-04]
# [Adam] Step 5800 | pde 5.77e-03 | bc 2.71e-03 | data 8.76e-04 | TV loss 1.21e-03 | total 6.40e-02 | scales [ 9.166998e-01 -8.680927e-06]
# [Adam] Step 6000 | pde 1.89e-04 | bc 3.56e-04 | data 1.73e-04 | TV loss 1.19e-03 | total 1.01e-02 | scales [ 9.1589445e-01 -8.2757681e-05]
# [Adam] Step 6200 | pde 1.96e-04 | bc 3.97e-04 | data 1.47e-04 | TV loss 1.20e-03 | total 9.75e-03 | scales [9.1725618e-01 2.1915794e-04]
# [Adam] Step 6400 | pde 2.35e-04 | bc 3.90e-04 | data 2.38e-04 | TV loss 1.22e-03 | total 1.34e-02 | scales [ 9.1775793e-01 -5.8562646e-04]
# [Adam] Step 6600 | pde 1.52e-04 | bc 4.73e-04 | data 5.73e-05 | TV loss 1.25e-03 | total 7.18e-03 | scales [ 9.1813725e-01 -1.7698613e-04]
# [Adam] Step 6800 | pde 3.59e-04 | bc 6.39e-04 | data 1.13e-04 | TV loss 1.25e-03 | total 1.14e-02 | scales [ 9.1861415e-01 -2.1125394e-04]
# [Adam] Step 7000 | pde 1.11e-03 | bc 1.32e-04 | data 2.73e-04 | TV loss 1.27e-03 | total 1.40e-02 | scales [9.1882825e-01 3.2275766e-06]
# [Adam] Step 7200 | pde 1.14e-04 | bc 1.94e-04 | data 8.01e-05 | TV loss 1.34e-03 | total 5.56e-03 | scales [9.1923469e-01 2.1599431e-04]
# [Adam] Step 7400 | pde 1.60e-04 | bc 4.73e-04 | data 1.31e-04 | TV loss 1.33e-03 | total 1.08e-02 | scales [ 9.1997546e-01 -2.7232018e-04]
# [Adam] Step 7600 | pde 1.11e-04 | bc 2.66e-04 | data 1.02e-04 | TV loss 1.37e-03 | total 7.49e-03 | scales [ 9.1997945e-01 -6.7318950e-05]
# [Adam] Step 7800 | pde 1.47e-04 | bc 3.58e-04 | data 6.30e-05 | TV loss 1.38e-03 | total 6.71e-03 | scales [9.2055613e-01 1.8525745e-04]
# [Adam] Step 8000 | pde 1.40e-04 | bc 4.49e-04 | data 1.34e-04 | TV loss 1.41e-03 | total 1.11e-02 | scales [9.206205e-01 7.693112e-05]
# [Adam] Step 8200 | pde 1.84e-03 | bc 4.56e-04 | data 8.21e-05 | TV loss 1.44e-03 | total 1.05e-02 | scales [9.2061573e-01 3.3639773e-04]
# [Adam] Step 8400 | pde 1.33e-04 | bc 2.76e-04 | data 3.29e-05 | TV loss 1.43e-03 | total 4.57e-03 | scales [9.2108524e-01 1.8378791e-04]
# [Adam] Step 8600 | pde 2.82e-04 | bc 4.85e-04 | data 2.61e-05 | TV loss 1.41e-03 | total 6.50e-03 | scales [ 9.2101979e-01 -3.3610933e-05]
# [Adam] Step 8800 | pde 1.58e-04 | bc 2.25e-04 | data 1.14e-04 | TV loss 1.42e-03 | total 8.51e-03 | scales [ 9.2112744e-01 -5.5119184e-05]
# [Adam] Step 9000 | pde 4.80e-05 | bc 1.87e-04 | data 6.45e-05 | TV loss 1.46e-03 | total 5.43e-03 | scales [ 9.2171305e-01 -1.4268566e-04]
# [Adam] Step 9200 | pde 1.52e-03 | bc 5.83e-04 | data 1.50e-04 | TV loss 1.41e-03 | total 1.57e-02 | scales [ 9.2157692e-01 -3.9394601e-04]
# [Adam] Step 9400 | pde 1.46e-04 | bc 1.67e-04 | data 1.38e-04 | TV loss 1.49e-03 | total 9.66e-03 | scales [9.223597e-01 5.825812e-05]
# [Adam] Step 9600 | pde 2.08e-03 | bc 1.87e-03 | data 1.03e-04 | TV loss 1.51e-03 | total 2.68e-02 | scales [ 9.220354e-01 -1.495256e-04]
# [Adam] Convergence criterion met at step 9665. Switching to L-BFGS.
#
# --- Phase 2: L-BFGS (max 6001 steps) ---
# [LBFGS] Step 0 | pde 2.23e-04 | bc 4.93e-04 | data 5.92e-05 | TV loss 1.41e-03 | total 1.25e-02 | scales [9.2121583e-01 1.6532544e-04]
# [LBFGS] Step 200 | pde 3.12e-05 | bc 1.64e-06 | data 2.01e-07 | TV loss 1.41e-03 | total 1.48e-03 | scales [ 9.2135054e-01 -8.0448654e-06]
# [LBFGS] Step 400 | pde 2.16e-05 | bc 6.84e-06 | data 8.22e-08 | TV loss 1.41e-03 | total 1.51e-03 | scales [ 9.21581864e-01 -1.17638934e-04]
# [LBFGS] Step 600 | pde 2.15e-05 | bc 1.18e-07 | data 6.50e-09 | TV loss 1.41e-03 | total 1.43e-03 | scales [ 9.2145622e-01 -1.1401381e-06]
# [LBFGS] Step 800 | pde 2.01e-05 | bc 8.23e-07 | data 9.28e-08 | TV loss 1.41e-03 | total 1.45e-03 | scales [9.2145425e-01 3.1676223e-06]
# [LBFGS] Step 1000 | pde 2.14e-05 | bc 3.47e-06 | data 1.01e-07 | TV loss 1.41e-03 | total 1.48e-03 | scales [9.2144608e-01 3.0085926e-05]
# [LBFGS] Step 1200 | pde 1.69e-04 | bc 1.33e-04 | data 1.87e-05 | TV loss 1.41e-03 | total 4.78e-03 | scales [ 0.92236656 -0.00207645]
# [LBFGS] Step 1400 | pde 2.09e-05 | bc 2.16e-05 | data 8.71e-08 | TV loss 1.41e-03 | total 1.66e-03 | scales [ 0.9210785  -0.00199918]
# [LBFGS] Step 1600 | pde 2.12e-05 | bc 1.87e-05 | data 9.83e-08 | TV loss 1.41e-03 | total 1.63e-03 | scales [ 0.9212373  -0.00231707]
# [LBFGS] Step 1800 | pde 2.00e-05 | bc 1.43e-05 | data 2.20e-07 | TV loss 1.41e-03 | total 1.60e-03 | scales [ 0.9219175  -0.00238748]
# [LBFGS] Step 2000 | pde 7.33e-05 | bc 7.64e-05 | data 8.84e-07 | TV loss 1.41e-03 | total 2.34e-03 | scales [ 0.92293733 -0.00310272]
# [LBFGS] Step 2200 | pde 2.52e-05 | bc 1.33e-05 | data 7.49e-08 | TV loss 1.41e-03 | total 1.58e-03 | scales [ 0.9224323  -0.00294532]
# [LBFGS] Step 2400 | pde 3.79e-05 | bc 4.97e-06 | data 2.88e-07 | TV loss 1.41e-03 | total 1.53e-03 | scales [ 9.2241383e-01 -1.3573335e-05]
# [LBFGS] Step 2600 | pde 3.19e-05 | bc 4.26e-06 | data 3.69e-07 | TV loss 1.41e-03 | total 1.52e-03 | scales [ 9.2264158e-01 -1.5590367e-05]
# [LBFGS] Step 2800 | pde 3.20e-05 | bc 6.77e-06 | data 5.99e-08 | TV loss 1.41e-03 | total 1.52e-03 | scales [9.2270970e-01 5.7341713e-05]
# [LBFGS] Step 3000 | pde 5.58e-05 | bc 1.94e-06 | data 7.32e-08 | TV loss 1.41e-03 | total 1.50e-03 | scales [ 9.2378199e-01 -2.8627306e-05]
# [LBFGS] Step 3200 | pde 6.23e-05 | bc 1.86e-06 | data 2.34e-07 | TV loss 1.41e-03 | total 1.52e-03 | scales [ 9.2397624e-01 -1.1373042e-05]
# [LBFGS] Step 3400 | pde 3.43e-05 | bc 1.59e-06 | data 6.45e-08 | TV loss 1.41e-03 | total 1.47e-03 | scales [9.2409647e-01 1.5070959e-05]
# [LBFGS] Step 3600 | pde 4.19e-05 | bc 1.51e-06 | data 7.76e-08 | TV loss 1.41e-03 | total 1.48e-03 | scales [9.2432886e-01 1.2809184e-06]
# [LBFGS] Step 3800 | pde 3.66e-05 | bc 2.77e-07 | data 3.41e-08 | TV loss 1.41e-03 | total 1.46e-03 | scales [9.2437434e-01 1.1889920e-06]
# [LBFGS] Step 4000 | pde 3.54e-05 | bc 3.19e-06 | data 4.63e-07 | TV loss 1.41e-03 | total 1.53e-03 | scales [9.2429727e-01 3.8891408e-06]
# [LBFGS] Step 4200 | pde 3.32e-05 | bc 2.44e-06 | data 2.13e-07 | TV loss 1.41e-03 | total 1.49e-03 | scales [9.2440170e-01 1.6677532e-05]
# [LBFGS] Step 4400 | pde 3.32e-05 | bc 3.25e-07 | data 9.66e-09 | TV loss 1.41e-03 | total 1.45e-03 | scales [9.2440599e-01 3.3450592e-06]
# [LBFGS] Step 4600 | pde 3.68e-05 | bc 1.19e-06 | data 1.84e-07 | TV loss 1.41e-03 | total 1.48e-03 | scales [ 9.2433584e-01 -1.3615223e-06]
# [LBFGS] Step 4800 | pde 3.75e-05 | bc 8.67e-07 | data 1.48e-07 | TV loss 1.41e-03 | total 1.47e-03 | scales [9.2436147e-01 3.8646349e-06]
# [LBFGS] Step 5000 | pde 2.82e-05 | bc 3.88e-08 | data 5.90e-09 | TV loss 1.41e-03 | total 1.44e-03 | scales [9.2441887e-01 1.2852114e-06]
# [LBFGS] Step 5200 | pde 2.87e-05 | bc 1.78e-05 | data 2.31e-07 | TV loss 1.41e-03 | total 1.64e-03 | scales [9.235650e-01 8.514009e-04]
# [LBFGS] Step 5400 | pde 2.73e-05 | bc 1.80e-06 | data 7.57e-08 | TV loss 1.41e-03 | total 1.47e-03 | scales [ 9.2349392e-01 -2.0085716e-05]
# [LBFGS] Step 5600 | pde 2.72e-05 | bc 1.28e-07 | data 4.91e-08 | TV loss 1.41e-03 | total 1.45e-03 | scales [ 9.2346376e-01 -1.5508955e-05]
# [LBFGS] Step 5800 | pde 2.57e-05 | bc 5.89e-08 | data 1.16e-08 | TV loss 1.41e-03 | total 1.44e-03 | scales [ 9.2342925e-01 -4.0260907e-06]
# [LBFGS] Step 6000 | pde 2.52e-05 | bc 4.46e-07 | data 1.95e-08 | TV loss 1.41e-03 | total 1.44e-03 | scales [9.234694e-01 6.582083e-06]
#
# ============================================================
# --- f = 80.0 Hz ---
# ============================================================
#
# --- Phase 1: Adam (max 3001 steps) ---
# [Adam] Step 0 | pde 5.27e+00 | bc 6.32e+00 | total 6.85e+01 | scales [1.4793967e+00 9.9999248e-04]
# [Adam] Step 200 | pde 3.86e-03 | bc 6.60e-03 | total 6.98e-02 | scales [1.4748722e+00 6.6055720e-05]
# [Adam] Step 400 | pde 1.50e-03 | bc 3.42e-03 | total 3.57e-02 | scales [1.4744862e+00 2.5342012e-04]
# [Adam] Step 600 | pde 5.47e-03 | bc 4.34e-03 | total 4.89e-02 | scales [ 1.4725294e+00 -1.4497209e-04]
# [Adam] Step 800 | pde 8.85e-03 | bc 2.68e-02 | total 2.77e-01 | scales [ 1.4706866e+00 -4.2599492e-04]
# [Adam] Step 1000 | pde 1.17e-03 | bc 2.20e-03 | total 2.32e-02 | scales [ 1.47065699e+00 -1.15810675e-04]
# [Adam] Step 1200 | pde 8.32e-04 | bc 2.53e-03 | total 2.61e-02 | scales [ 1.4711288e+00 -3.8296799e-04]
# [Adam] Step 1400 | pde 1.99e-04 | bc 8.36e-04 | total 8.55e-03 | scales [ 1.4714608e+00 -4.1798325e-04]
# [Adam] Step 1600 | pde 1.50e-04 | bc 2.37e-04 | total 2.52e-03 | scales [ 1.4715255e+00 -2.5123253e-04]
# [Adam] Step 1800 | pde 1.75e-04 | bc 5.56e-04 | total 5.73e-03 | scales [1.4710305e+00 1.6872618e-05]
# [Adam] Step 2000 | pde 9.96e-05 | bc 3.31e-04 | total 3.41e-03 | scales [1.4710516e+00 1.3019249e-04]
# [Adam] Step 2200 | pde 2.57e-05 | bc 1.86e-04 | total 1.88e-03 | scales [1.4709246e+00 1.3400648e-04]
# [Adam] Step 2400 | pde 2.17e-05 | bc 9.65e-05 | total 9.86e-04 | scales [1.4709193e+00 1.1501147e-04]
# [Adam] Step 2600 | pde 6.39e-05 | bc 1.27e-04 | total 1.34e-03 | scales [1.4708973e+00 2.0243938e-04]
# [Adam] Step 2800 | pde 2.66e-05 | bc 6.94e-05 | total 7.21e-04 | scales [1.4708945e+00 5.1975345e-05]
# [Adam] Step 3000 | pde 1.65e-05 | bc 6.44e-05 | total 6.61e-04 | scales [1.4708803e+00 3.6602622e-05]
#
# --- Phase 1: L-BFGS (max 6001 steps) ---
# [LBFGS] Step 0 | pde 1.36e-05 | bc 5.14e-05 | total 5.28e-04 | scales [1.4709181e+00 3.2212345e-05]
# [LBFGS] Step 200 | pde 7.87e-06 | bc 1.67e-07 | total 9.54e-06 | scales [ 1.4709065e+00 -1.1124134e-06]
# [LBFGS] Step 400 | pde 6.37e-06 | bc 1.52e-07 | total 7.89e-06 | scales [ 1.4709175e+00 -6.9039760e-07]
# [LBFGS] Step 600 | pde 3.49e-05 | bc 1.98e-06 | total 5.47e-05 | scales [1.470861e+00 8.860271e-07]
# [LBFGS] Step 800 | pde 1.18e-05 | bc 8.69e-08 | total 1.27e-05 | scales [ 1.4708790e+00 -1.8962112e-06]
# [LBFGS] Step 1000 | pde 1.05e-05 | bc 1.09e-06 | total 2.14e-05 | scales [1.4708706e+00 6.0805446e-06]
# [LBFGS] Step 1200 | pde 1.24e-05 | bc 3.52e-06 | total 4.76e-05 | scales [1.4708227e+00 1.5842581e-05]
# [LBFGS] Step 1400 | pde 1.32e-05 | bc 2.22e-05 | total 2.35e-04 | scales [1.4708357  0.00156964]
# [LBFGS] Step 1600 | pde 1.17e-05 | bc 2.54e-07 | total 1.43e-05 | scales [1.4707816e+00 1.7283819e-06]
# [LBFGS] Step 1800 | pde 7.18e-05 | bc 1.79e-06 | total 8.97e-05 | scales [ 1.4713330e+00 -1.8299288e-06]
# [LBFGS] Step 2000 | pde 4.71e-05 | bc 2.62e-05 | total 3.09e-04 | scales [1.4714108e+00 1.8173501e-05]
# [LBFGS] Step 2200 | pde 3.42e-05 | bc 3.69e-06 | total 7.11e-05 | scales [1.4708978e+00 8.4670846e-06]
# [LBFGS] Step 2400 | pde 2.47e-05 | bc 3.28e-06 | total 5.75e-05 | scales [1.4706755e+00 2.3078304e-07]
# [LBFGS] Step 2600 | pde 2.34e-05 | bc 1.16e-07 | total 2.46e-05 | scales [1.4707420e+00 1.2416276e-06]
# [LBFGS] Step 2800 | pde 1.77e-05 | bc 3.11e-08 | total 1.80e-05 | scales [ 1.4707315e+00 -1.6293084e-06]
# [LBFGS] Step 3000 | pde 1.77e-05 | bc 6.93e-08 | total 1.84e-05 | scales [ 1.4707474e+00 -2.4774845e-05]
# [LBFGS] Step 3200 | pde 2.89e-05 | bc 6.39e-07 | total 3.53e-05 | scales [ 1.4706725e+00 -1.1521691e-05]
# [LBFGS] Step 3400 | pde 3.04e-05 | bc 7.90e-08 | total 3.12e-05 | scales [ 1.4706620e+00 -2.4766923e-06]
# [LBFGS] Step 3600 | pde 2.12e-05 | bc 2.94e-06 | total 5.06e-05 | scales [1.4706671e+00 7.3338210e-06]
# [LBFGS] Step 3800 | pde 1.61e-05 | bc 2.55e-07 | total 1.86e-05 | scales [ 1.4706565e+00 -2.1728056e-07]
# [LBFGS] Step 4000 | pde 2.66e-05 | bc 6.38e-06 | total 9.04e-05 | scales [ 1.4706366e+00 -6.9702464e-06]
# [LBFGS] Step 4200 | pde 2.41e-05 | bc 2.91e-07 | total 2.70e-05 | scales [1.4705324e+00 3.1100956e-06]
# [LBFGS] Step 4400 | pde 1.59e-05 | bc 1.16e-05 | total 1.32e-04 | scales [ 1.4705732e+00 -1.2561811e-04]
# [LBFGS] Step 4600 | pde 1.59e-05 | bc 1.33e-07 | total 1.72e-05 | scales [1.4705820e+00 2.4245467e-06]
# [LBFGS] Step 4800 | pde 1.51e-05 | bc 3.22e-07 | total 1.83e-05 | scales [1.4705639e+00 1.2599148e-06]
# [LBFGS] Step 5000 | pde 1.74e-05 | bc 4.48e-06 | total 6.22e-05 | scales [ 1.4705974e+00 -6.4062384e-05]
# [LBFGS] Step 5200 | pde 1.33e-05 | bc 5.57e-07 | total 1.88e-05 | scales [ 1.4705850e+00 -3.0610272e-07]
# [LBFGS] Step 5400 | pde 1.59e-05 | bc 9.52e-08 | total 1.69e-05 | scales [ 1.4705212e+00 -2.5388906e-06]
# [LBFGS] Step 5600 | pde 3.44e-05 | bc 1.32e-05 | total 1.66e-04 | scales [ 1.4704884e+00 -3.5213106e-06]
# [LBFGS] Step 5800 | pde 1.81e-05 | bc 4.04e-07 | total 2.21e-05 | scales [1.4705036e+00 1.7991096e-06]
# [LBFGS] Step 6000 | pde 2.57e-05 | bc 1.39e-06 | total 3.97e-05 | scales [ 1.4704820e+00 -2.3165985e-06]
#
# --- Phase 2: Adam (max 50001 steps) ---
# [Adam] Step 0 | pde 2.77e-05 | bc 1.35e-06 | data 6.31e-04 | TV loss 1.44e-03 | total 6.72e-04 | scales [ 1.4714820e+00 -1.0023074e-03]
# [Adam] Step 200 | pde 1.12e-03 | bc 4.96e-03 | data 4.89e-04 | TV loss 1.49e-03 | total 5.18e-02 | scales [ 1.4689467e+00 -3.7770926e-05]
# [Adam] Step 400 | pde 4.68e-04 | bc 1.60e-03 | data 2.31e-04 | TV loss 1.47e-03 | total 1.73e-02 | scales [ 1.4666362e+00 -3.3702503e-04]
# [Adam] Step 600 | pde 1.26e-03 | bc 3.68e-03 | data 4.97e-04 | TV loss 1.53e-03 | total 4.04e-02 | scales [ 1.4665802e+00 -6.0727244e-04]
# [Adam] Step 800 | pde 9.27e-04 | bc 2.35e-03 | data 1.46e-04 | TV loss 1.49e-03 | total 2.53e-02 | scales [1.4668264e+00 2.5874743e-04]
# [Adam] Step 1000 | pde 7.19e-04 | bc 2.03e-03 | data 1.57e-04 | TV loss 1.41e-03 | total 2.21e-02 | scales [ 1.4669292e+00 -8.4947824e-06]
# [Adam] Step 1200 | pde 2.85e-04 | bc 5.83e-04 | data 3.99e-05 | TV loss 1.42e-03 | total 6.44e-03 | scales [ 1.4664873e+00 -1.4563137e-05]
# [Adam] Step 1400 | pde 6.07e-04 | bc 1.51e-03 | data 1.37e-04 | TV loss 1.41e-03 | total 1.69e-02 | scales [ 1.466545e+00 -3.685057e-04]
# [Adam] Step 1600 | pde 1.50e-03 | bc 4.16e-03 | data 2.02e-04 | TV loss 1.39e-03 | total 4.52e-02 | scales [ 1.4654665e+00 -4.6578953e-06]
# [Adam] Step 1800 | pde 5.54e-04 | bc 1.86e-03 | data 1.98e-04 | TV loss 1.44e-03 | total 2.15e-02 | scales [ 1.4660813e+00 -5.7139678e-04]
# [Adam] Step 2000 | pde 4.42e-03 | bc 8.33e-04 | data 1.15e-04 | TV loss 1.47e-03 | total 1.42e-02 | scales [ 1.4658082e+00 -2.8375484e-04]
# [Adam] Step 2200 | pde 6.12e-04 | bc 2.29e-03 | data 2.26e-04 | TV loss 1.47e-03 | total 2.67e-02 | scales [1.4649395e+00 6.6380418e-04]
# [Adam] Step 2400 | pde 6.80e-04 | bc 2.81e-03 | data 1.85e-04 | TV loss 1.50e-03 | total 3.16e-02 | scales [1.4644109e+00 4.0418771e-04]
# [Adam] Step 2600 | pde 2.85e-04 | bc 1.22e-03 | data 1.25e-04 | TV loss 1.43e-03 | total 1.45e-02 | scales [1.4644022e+00 1.1619687e-04]
# [Adam] Step 2800 | pde 8.02e-04 | bc 1.96e-03 | data 3.72e-04 | TV loss 1.45e-03 | total 2.69e-02 | scales [1.4644936e+00 2.7178315e-04]
# [Adam] Step 3000 | pde 1.73e-03 | bc 1.77e-03 | data 1.34e-04 | TV loss 1.50e-03 | total 2.20e-02 | scales [ 1.4643101e+00 -1.7065673e-04]
# [Adam] Step 3200 | pde 2.17e-03 | bc 7.00e-03 | data 6.07e-04 | TV loss 1.55e-03 | total 8.43e-02 | scales [ 1.4631716e+00 -4.3339381e-04]
# [Adam] Step 3400 | pde 5.90e-04 | bc 8.53e-04 | data 5.64e-05 | TV loss 1.47e-03 | total 1.03e-02 | scales [1.4627981e+00 9.4079995e-05]
# [Adam] Step 3600 | pde 3.98e-04 | bc 9.70e-04 | data 7.10e-05 | TV loss 1.52e-03 | total 1.17e-02 | scales [ 1.4636658e+00 -3.2525478e-04]
# [Adam] Step 3800 | pde 3.01e-04 | bc 8.23e-04 | data 7.85e-05 | TV loss 1.53e-03 | total 1.04e-02 | scales [ 1.4632205e+00 -7.2946271e-04]
# [Adam] Step 4000 | pde 5.80e-04 | bc 1.09e-03 | data 3.57e-05 | TV loss 1.56e-03 | total 1.23e-02 | scales [1.4632214e+00 2.6578904e-04]
# [Adam] Step 4200 | pde 9.22e-04 | bc 1.24e-03 | data 9.77e-05 | TV loss 1.52e-03 | total 1.58e-02 | scales [ 1.4636365e+00 -5.5250170e-04]
# [Adam] Step 4400 | pde 3.72e-04 | bc 1.17e-03 | data 6.42e-05 | TV loss 1.52e-03 | total 1.38e-02 | scales [ 1.4641794e+00 -3.2289760e-04]
# [Adam] Step 4600 | pde 3.41e-04 | bc 1.20e-03 | data 1.10e-04 | TV loss 1.50e-03 | total 1.55e-02 | scales [ 1.4637361e+00 -1.2721989e-04]
# [Adam] Step 4800 | pde 4.23e-04 | bc 9.19e-04 | data 1.57e-04 | TV loss 1.53e-03 | total 1.42e-02 | scales [ 1.4633167e+00 -3.7820774e-04]
# [Adam] Step 5000 | pde 1.77e-02 | bc 3.90e-04 | data 2.61e-04 | TV loss 1.55e-03 | total 2.96e-02 | scales [ 1.4627434e+00 -2.1316801e-04]
# [Adam] Step 5200 | pde 4.89e-04 | bc 1.41e-03 | data 1.13e-04 | TV loss 1.54e-03 | total 1.82e-02 | scales [1.4631064e+00 5.7003122e-05]
# [Adam] Step 5400 | pde 2.67e-03 | bc 3.38e-03 | data 1.30e-04 | TV loss 1.60e-03 | total 4.07e-02 | scales [ 1.4625661e+00 -2.3141100e-04]
# [Adam] Step 5600 | pde 8.91e-04 | bc 1.45e-03 | data 2.52e-04 | TV loss 1.61e-03 | total 2.40e-02 | scales [ 1.462809e+00 -9.072290e-05]
# [Adam] Step 5800 | pde 3.36e-04 | bc 9.13e-04 | data 5.45e-05 | TV loss 1.64e-03 | total 1.14e-02 | scales [ 1.4631836e+00 -4.7634385e-04]
# [Adam] Step 6000 | pde 1.58e-03 | bc 2.05e-03 | data 5.14e-05 | TV loss 1.67e-03 | total 2.40e-02 | scales [ 1.4626160e+00 -1.7462594e-04]
# [Adam] Step 6200 | pde 3.58e-03 | bc 1.75e-03 | data 5.07e-04 | TV loss 1.61e-03 | total 4.02e-02 | scales [ 1.4625376e+00 -4.0668161e-05]
# [Adam] Step 6400 | pde 2.30e-03 | bc 2.54e-03 | data 1.14e-04 | TV loss 1.63e-03 | total 3.21e-02 | scales [ 1.4628705e+00 -1.9665174e-04]
# [Adam] Step 6600 | pde 2.06e-04 | bc 7.89e-04 | data 1.09e-04 | TV loss 1.64e-03 | total 1.25e-02 | scales [1.4626622e+00 3.4412136e-05]
# [Adam] Step 6800 | pde 7.46e-04 | bc 7.34e-04 | data 1.46e-04 | TV loss 1.64e-03 | total 1.41e-02 | scales [1.4625164e+00 4.5370095e-04]
# [Adam] Step 7000 | pde 5.54e-03 | bc 2.21e-03 | data 2.75e-04 | TV loss 1.68e-03 | total 3.94e-02 | scales [ 1.4625320e+00 -1.1873315e-04]
# [Adam] Step 7200 | pde 3.40e-04 | bc 1.11e-03 | data 3.38e-05 | TV loss 1.69e-03 | total 1.29e-02 | scales [ 1.4621047e+00 -1.2346792e-04]
# [Adam] Step 7400 | pde 8.52e-04 | bc 1.40e-03 | data 2.13e-05 | TV loss 1.69e-03 | total 1.58e-02 | scales [ 1.4623079e+00 -1.5441196e-04]
# [Adam] Step 7600 | pde 5.36e-04 | bc 9.43e-04 | data 3.21e-05 | TV loss 1.64e-03 | total 1.14e-02 | scales [1.4623471e+00 2.0604104e-05]
# [Adam] Step 7800 | pde 2.07e-04 | bc 5.71e-04 | data 8.95e-05 | TV loss 1.58e-03 | total 1.02e-02 | scales [ 1.4625294e+00 -1.5915137e-04]
# [Adam] Step 8000 | pde 1.11e-02 | bc 3.22e-03 | data 1.51e-04 | TV loss 1.66e-03 | total 5.06e-02 | scales [ 1.4629992e+00 -9.1153968e-05]
# [Adam] Step 8200 | pde 5.20e-04 | bc 8.50e-04 | data 8.97e-05 | TV loss 1.73e-03 | total 1.35e-02 | scales [ 1.4623255e+00 -2.1331548e-04]
# [Adam] Step 8400 | pde 4.24e-04 | bc 1.23e-03 | data 6.50e-05 | TV loss 1.70e-03 | total 1.61e-02 | scales [1.4621494e+00 3.9471161e-05]
# [Adam] Step 8600 | pde 3.19e-04 | bc 8.43e-04 | data 5.91e-05 | TV loss 1.73e-03 | total 1.18e-02 | scales [1.4622104e+00 1.5241830e-04]
# [Adam] Step 8800 | pde 4.94e-04 | bc 5.94e-04 | data 5.76e-05 | TV loss 1.71e-03 | total 9.50e-03 | scales [ 1.4626029e+00 -3.2979186e-04]
# [Adam] Step 9000 | pde 3.57e-04 | bc 3.36e-04 | data 8.43e-05 | TV loss 1.74e-03 | total 8.30e-03 | scales [1.4630097e+00 4.4471963e-06]
# [Adam] Step 9200 | pde 2.73e-04 | bc 3.81e-04 | data 5.64e-05 | TV loss 1.79e-03 | total 7.22e-03 | scales [1.4627694e+00 1.6205406e-04]
# [Adam] Step 9400 | pde 6.50e-04 | bc 1.02e-03 | data 6.46e-05 | TV loss 1.79e-03 | total 1.45e-02 | scales [ 1.4628975e+00 -1.5104099e-04]
# [Adam] Step 9600 | pde 9.05e-04 | bc 7.88e-04 | data 1.00e-04 | TV loss 1.69e-03 | total 1.46e-02 | scales [1.4626814e+00 2.5553460e-04]
# [Adam] Step 9800 | pde 1.81e-02 | bc 3.76e-03 | data 2.41e-04 | TV loss 1.77e-03 | total 7.00e-02 | scales [1.4621500e+00 2.5749372e-04]
# [Adam] Step 10000 | pde 1.88e-03 | bc 1.34e-03 | data 2.83e-05 | TV loss 1.78e-03 | total 1.70e-02 | scales [ 1.4613389e+00 -9.9208090e-05]
# [Adam] Step 10200 | pde 3.85e-04 | bc 7.66e-04 | data 1.19e-05 | TV loss 1.77e-03 | total 8.78e-03 | scales [1.4612265e+00 2.0779272e-04]
# [Adam] Step 10400 | pde 7.93e-04 | bc 2.89e-04 | data 9.76e-06 | TV loss 1.75e-03 | total 4.30e-03 | scales [ 1.4608189e+00 -2.2261971e-04]
# [Adam] Step 10600 | pde 2.41e-04 | bc 6.01e-04 | data 8.24e-05 | TV loss 1.72e-03 | total 1.15e-02 | scales [ 1.4612038e+00 -4.6234817e-04]
# [Adam] Step 10800 | pde 2.05e-04 | bc 6.26e-04 | data 4.44e-05 | TV loss 1.78e-03 | total 9.36e-03 | scales [ 1.4617789e+00 -3.4444427e-04]
# [Adam] Step 11000 | pde 1.94e-02 | bc 5.19e-04 | data 6.99e-06 | TV loss 1.77e-03 | total 2.50e-02 | scales [1.4620223e+00 2.5677125e-04]
# [Adam] Step 11200 | pde 3.25e-03 | bc 8.36e-04 | data 3.44e-05 | TV loss 1.80e-03 | total 1.39e-02 | scales [1.4612864e+00 2.2338756e-04]
# [Adam] Step 11400 | pde 2.70e-04 | bc 1.00e-03 | data 4.38e-05 | TV loss 1.73e-03 | total 1.33e-02 | scales [1.4612432e+00 2.5041212e-04]
# [Adam] Step 11600 | pde 7.88e-04 | bc 9.01e-04 | data 5.99e-05 | TV loss 1.73e-03 | total 1.40e-02 | scales [ 1.4609791e+00 -3.3524339e-06]
# [Adam] Step 11800 | pde 8.47e-05 | bc 1.60e-04 | data 1.45e-05 | TV loss 1.83e-03 | total 2.72e-03 | scales [ 1.4612693e+00 -1.7107070e-04]
# [Adam] Step 12000 | pde 4.34e-04 | bc 8.37e-04 | data 7.56e-05 | TV loss 1.78e-03 | total 1.43e-02 | scales [ 1.4607428e+00 -3.2905978e-04]
# [Adam] Step 12200 | pde 2.95e-04 | bc 3.77e-04 | data 4.43e-05 | TV loss 1.76e-03 | total 7.32e-03 | scales [ 1.4608172e+00 -3.0547436e-04]
# [Adam] Step 12400 | pde 5.29e-04 | bc 6.36e-04 | data 2.37e-05 | TV loss 1.80e-03 | total 8.66e-03 | scales [ 1.4611522e+00 -9.7387747e-05]
# [Adam] Step 12600 | pde 1.84e-04 | bc 3.67e-04 | data 4.33e-05 | TV loss 1.80e-03 | total 7.14e-03 | scales [1.4614351e+00 3.6666478e-04]
# [Adam] Step 12800 | pde 2.78e-04 | bc 4.23e-04 | data 4.91e-05 | TV loss 1.78e-03 | total 8.30e-03 | scales [1.4611967e+00 1.6115497e-04]
# [Adam] Step 13000 | pde 6.58e-04 | bc 1.16e-03 | data 1.08e-05 | TV loss 1.78e-03 | total 1.31e-02 | scales [ 1.4613996e+00 -3.8236566e-04]
# [Adam] Step 13200 | pde 6.97e-04 | bc 1.40e-03 | data 7.88e-05 | TV loss 1.79e-03 | total 2.10e-02 | scales [1.4616280e+00 2.2045887e-04]
# [Adam] Step 13400 | pde 2.26e-04 | bc 3.95e-04 | data 4.05e-05 | TV loss 1.77e-03 | total 7.44e-03 | scales [ 1.4619296e+00 -2.2719563e-05]
# [Adam] Step 13600 | pde 2.83e-03 | bc 5.56e-04 | data 1.47e-04 | TV loss 1.80e-03 | total 2.05e-02 | scales [ 1.4620951e+00 -4.3448345e-05]
# [Adam] Step 13800 | pde 2.06e-04 | bc 3.31e-04 | data 5.22e-05 | TV loss 1.78e-03 | total 7.85e-03 | scales [ 1.4611533e+00 -1.4079009e-04]
# [Adam] Step 14000 | pde 1.28e-04 | bc 1.79e-04 | data 1.60e-05 | TV loss 1.86e-03 | total 3.27e-03 | scales [1.4614203e+00 1.8037156e-04]
# [Adam] Step 14200 | pde 6.15e-04 | bc 9.51e-04 | data 1.42e-05 | TV loss 1.78e-03 | total 1.13e-02 | scales [ 1.4614614e+00 -3.9469165e-04]
# [Adam] Step 14400 | pde 1.06e-04 | bc 1.55e-04 | data 8.75e-06 | TV loss 1.81e-03 | total 2.41e-03 | scales [1.4613703e+00 9.7322300e-06]
# [Adam] Step 14600 | pde 1.49e-03 | bc 2.48e-04 | data 1.26e-05 | TV loss 1.81e-03 | total 5.09e-03 | scales [1.4612521e+00 5.2372903e-05]
# [Adam] Step 14800 | pde 5.94e-03 | bc 1.82e-03 | data 1.04e-04 | TV loss 1.83e-03 | total 3.34e-02 | scales [1.4610316e+00 1.6401355e-05]
# [Adam] Step 15000 | pde 1.86e-04 | bc 2.22e-04 | data 4.06e-05 | TV loss 1.88e-03 | total 6.07e-03 | scales [ 1.4612516e+00 -6.7946887e-05]
# [Adam] Step 15200 | pde 1.43e-04 | bc 1.20e-04 | data 1.58e-05 | TV loss 1.80e-03 | total 2.79e-03 | scales [ 1.4615239e+00 -1.4082390e-05]
# [Adam] Step 15400 | pde 3.03e-04 | bc 4.00e-04 | data 5.32e-05 | TV loss 1.80e-03 | total 9.22e-03 | scales [1.4614655e+00 5.4350123e-05]
# [Adam] Step 15600 | pde 9.84e-04 | bc 7.89e-04 | data 2.85e-05 | TV loss 1.83e-03 | total 1.15e-02 | scales [1.461713e+00 2.587200e-04]
# [Adam] Step 15800 | pde 3.82e-04 | bc 3.91e-04 | data 3.00e-05 | TV loss 1.83e-03 | total 7.14e-03 | scales [ 1.4614838e+00 -2.0349768e-04]
# [Adam] Step 16000 | pde 6.39e-04 | bc 4.00e-04 | data 4.76e-05 | TV loss 1.94e-03 | total 9.21e-03 | scales [ 1.4615008e+00 -1.2713103e-04]
# [Adam] Step 16200 | pde 1.46e-04 | bc 2.18e-04 | data 4.01e-05 | TV loss 1.83e-03 | total 6.23e-03 | scales [ 1.4614992e+00 -8.1542748e-06]
# [Adam] Step 16400 | pde 3.91e-04 | bc 2.69e-04 | data 2.69e-05 | TV loss 1.80e-03 | total 5.73e-03 | scales [ 1.4615446e+00 -5.1029783e-06]
# [Adam] Step 16600 | pde 5.97e-04 | bc 6.37e-04 | data 1.38e-05 | TV loss 1.83e-03 | total 8.34e-03 | scales [ 1.461469e+00 -9.174459e-05]
# [Adam] Step 16800 | pde 2.07e-04 | bc 2.37e-04 | data 3.80e-05 | TV loss 1.83e-03 | total 6.38e-03 | scales [ 1.4618129e+00 -6.3991254e-05]
# [Adam] Step 17000 | pde 4.76e-02 | bc 7.69e-04 | data 1.33e-04 | TV loss 1.82e-03 | total 6.86e-02 | scales [ 1.4611348e+00 -3.3593076e-04]
# [Adam] Step 17200 | pde 1.67e-04 | bc 2.87e-04 | data 2.34e-05 | TV loss 1.84e-03 | total 5.38e-03 | scales [1.461455e+00 9.950127e-06]
# [Adam] Step 17400 | pde 3.47e-04 | bc 5.52e-04 | data 1.33e-05 | TV loss 1.81e-03 | total 7.20e-03 | scales [1.4615455e+00 1.3665709e-04]
# [Adam] Step 17600 | pde 1.85e-04 | bc 3.30e-04 | data 3.39e-05 | TV loss 1.82e-03 | total 6.87e-03 | scales [ 1.461607e+00 -3.588793e-04]
# [Adam] Step 17800 | pde 9.95e-04 | bc 4.96e-04 | data 6.63e-06 | TV loss 1.76e-03 | total 6.62e-03 | scales [1.4609253e+00 3.4942437e-04]
# [Adam] Step 18000 | pde 7.87e-05 | bc 1.37e-04 | data 1.06e-05 | TV loss 1.81e-03 | total 2.51e-03 | scales [1.4610089e+00 6.4591222e-05]
# [Adam] Step 18200 | pde 1.73e-04 | bc 2.85e-04 | data 2.75e-05 | TV loss 1.80e-03 | total 5.77e-03 | scales [1.4611653e+00 8.7004919e-05]
# [Adam] Step 18400 | pde 2.77e-03 | bc 1.08e-03 | data 8.42e-05 | TV loss 1.77e-03 | total 2.20e-02 | scales [1.4612591e+00 1.6557786e-05]
# [Adam] Step 18600 | pde 2.03e-03 | bc 6.85e-04 | data 5.84e-05 | TV loss 1.82e-03 | total 1.47e-02 | scales [ 1.4612778e+00 -9.7279633e-05]
# [Adam] Step 18800 | pde 2.89e-04 | bc 3.64e-04 | data 2.47e-05 | TV loss 1.79e-03 | total 6.40e-03 | scales [ 1.4611988e+00 -7.2803632e-05]
# [Adam] Step 19000 | pde 5.51e-05 | bc 1.88e-04 | data 1.52e-05 | TV loss 1.80e-03 | total 3.46e-03 | scales [1.4613668e+00 2.4775128e-04]
# [Adam] Step 19200 | pde 2.02e-03 | bc 1.11e-04 | data 2.05e-05 | TV loss 1.78e-03 | total 5.18e-03 | scales [1.4615561e+00 2.4997516e-04]
# [Adam] Step 19400 | pde 8.58e-05 | bc 1.61e-04 | data 1.97e-05 | TV loss 1.77e-03 | total 3.67e-03 | scales [1.46143973e+00 1.01086705e-04]
# [Adam] Step 19600 | pde 2.60e-03 | bc 6.14e-03 | data 2.17e-04 | TV loss 1.84e-03 | total 8.57e-02 | scales [1.4613750e+00 1.4537456e-04]
# [Adam] Step 19800 | pde 1.69e-03 | bc 5.59e-05 | data 1.42e-05 | TV loss 1.76e-03 | total 3.67e-03 | scales [1.4609489e+00 5.0028764e-05]
# [Adam] Step 20000 | pde 1.38e-04 | bc 1.86e-04 | data 2.60e-05 | TV loss 1.82e-03 | total 4.60e-03 | scales [ 1.4610006e+00 -2.8398121e-04]
# [Adam] Step 20200 | pde 9.03e-05 | bc 4.12e-04 | data 9.80e-06 | TV loss 1.79e-03 | total 5.19e-03 | scales [ 1.4611328e+00 -6.6975786e-05]
# [Adam] Step 20400 | pde 6.22e-04 | bc 1.07e-03 | data 3.77e-05 | TV loss 1.84e-03 | total 1.51e-02 | scales [1.46125603e+00 1.16487674e-04]
# [Adam] Step 20600 | pde 8.56e-05 | bc 2.82e-04 | data 2.56e-05 | TV loss 1.82e-03 | total 5.47e-03 | scales [ 1.4611868e+00 -1.0862770e-04]
# [Adam] Step 20800 | pde 2.85e-03 | bc 2.66e-04 | data 1.85e-05 | TV loss 1.79e-03 | total 7.36e-03 | scales [1.4613196e+00 8.9469322e-05]
# [Adam] Step 21000 | pde 2.52e-04 | bc 1.42e-04 | data 1.14e-05 | TV loss 1.79e-03 | total 2.81e-03 | scales [ 1.4609568e+00 -1.6090709e-04]
# [Adam] Step 21200 | pde 6.46e-05 | bc 1.16e-04 | data 1.94e-05 | TV loss 1.82e-03 | total 3.16e-03 | scales [ 1.4611611e+00 -9.8911114e-06]
# [Adam] Step 21400 | pde 6.26e-04 | bc 1.42e-04 | data 1.54e-05 | TV loss 1.82e-03 | total 3.59e-03 | scales [1.4612412e+00 1.8075599e-04]
# [Adam] Step 21600 | pde 3.92e-04 | bc 1.18e-04 | data 1.45e-05 | TV loss 1.82e-03 | total 3.03e-03 | scales [ 1.4610977e+00 -1.9864921e-04]
# [Adam] Step 21800 | pde 1.77e-04 | bc 2.88e-04 | data 9.77e-06 | TV loss 1.82e-03 | total 4.04e-03 | scales [1.4611872e+00 6.9853013e-05]
# [Adam] Step 22000 | pde 1.02e-03 | bc 1.25e-04 | data 4.60e-05 | TV loss 1.79e-03 | total 6.87e-03 | scales [1.460573e+00 5.761892e-05]
# [Adam] Step 22200 | pde 6.68e-05 | bc 1.78e-04 | data 2.29e-05 | TV loss 1.82e-03 | total 4.14e-03 | scales [1.4605163e+00 6.6444692e-05]
# [Adam] Step 22400 | pde 1.99e-04 | bc 1.30e-04 | data 3.02e-05 | TV loss 1.86e-03 | total 4.52e-03 | scales [1.4604037e+00 1.2078635e-05]
# [Adam] Step 22600 | pde 3.07e-04 | bc 4.16e-04 | data 2.58e-05 | TV loss 1.82e-03 | total 7.05e-03 | scales [ 1.4604868e+00 -1.2021412e-04]
# [Adam] Step 22800 | pde 2.90e-04 | bc 3.29e-04 | data 7.97e-07 | TV loss 1.77e-03 | total 3.66e-03 | scales [ 1.4606926e+00 -2.9814529e-04]
# [Adam] Step 23000 | pde 1.85e-04 | bc 1.50e-04 | data 6.45e-06 | TV loss 1.86e-03 | total 2.33e-03 | scales [ 1.4602274e+00 -1.5894161e-04]
# [Adam] Step 23200 | pde 2.38e-04 | bc 2.78e-04 | data 8.88e-06 | TV loss 1.87e-03 | total 3.91e-03 | scales [ 1.4603853e+00 -8.8473244e-05]
# [Adam] Step 23400 | pde 4.49e-03 | bc 5.77e-05 | data 8.68e-06 | TV loss 1.83e-03 | total 5.94e-03 | scales [ 1.4604373e+00 -1.1580023e-05]
# [Adam] Step 23600 | pde 6.80e-05 | bc 1.48e-04 | data 2.29e-05 | TV loss 1.80e-03 | total 3.85e-03 | scales [ 1.4604458e+00 -3.0104804e-04]
# [Adam] Step 23800 | pde 3.54e-05 | bc 1.21e-04 | data 1.35e-05 | TV loss 1.89e-03 | total 2.60e-03 | scales [ 1.4605294e+00 -6.5148470e-06]
# [Adam] Step 24000 | pde 1.38e-04 | bc 1.19e-04 | data 9.54e-06 | TV loss 1.86e-03 | total 2.28e-03 | scales [ 1.4606160e+00 -2.5362178e-05]
# [Adam] Step 24200 | pde 1.18e-04 | bc 1.94e-04 | data 1.47e-05 | TV loss 1.90e-03 | total 3.52e-03 | scales [ 1.460505e+00 -2.248401e-06]
# [Adam] Step 24400 | pde 1.22e-04 | bc 1.99e-04 | data 1.34e-05 | TV loss 1.87e-03 | total 3.44e-03 | scales [ 1.4605199e+00 -1.2998517e-04]
# [Adam] Step 24600 | pde 2.63e-04 | bc 2.64e-04 | data 1.61e-05 | TV loss 1.81e-03 | total 4.51e-03 | scales [ 1.4604864e+00 -2.1788946e-07]
# [Adam] Step 24800 | pde 7.79e-05 | bc 1.57e-04 | data 8.41e-06 | TV loss 1.82e-03 | total 2.48e-03 | scales [ 1.4606408e+00 -1.2456189e-04]
# [Adam] Step 25000 | pde 7.53e-05 | bc 1.69e-04 | data 8.64e-06 | TV loss 1.83e-03 | total 2.63e-03 | scales [ 1.4604274e+00 -2.0911070e-04]
# [Adam] Step 25200 | pde 3.97e-04 | bc 3.26e-04 | data 1.24e-05 | TV loss 1.84e-03 | total 4.89e-03 | scales [1.4604630e+00 9.8375975e-05]
# [Adam] Step 25400 | pde 7.38e-05 | bc 1.28e-04 | data 1.08e-05 | TV loss 1.83e-03 | total 2.43e-03 | scales [ 1.4605973e+00 -4.4303768e-05]
# [Adam] Step 25600 | pde 6.19e-04 | bc 1.38e-04 | data 1.90e-05 | TV loss 1.82e-03 | total 3.90e-03 | scales [ 1.4605943e+00 -2.4659524e-04]
# [Adam] Step 25800 | pde 5.67e-05 | bc 8.62e-05 | data 7.41e-06 | TV loss 1.83e-03 | total 1.66e-03 | scales [1.4605849e+00 8.1197453e-05]
# [Adam] Step 26000 | pde 7.01e-04 | bc 7.12e-05 | data 4.70e-06 | TV loss 1.75e-03 | total 1.88e-03 | scales [1.460339e+00 6.884150e-05]
# [Adam] Step 26200 | pde 1.35e-04 | bc 1.54e-04 | data 5.18e-06 | TV loss 1.82e-03 | total 2.20e-03 | scales [ 1.4604696e+00 -1.2472473e-04]
# [Adam] Step 26400 | pde 8.73e-05 | bc 9.22e-05 | data 6.36e-06 | TV loss 1.89e-03 | total 1.65e-03 | scales [1.4604630e+00 2.5934138e-05]
# [Adam] Step 26600 | pde 1.66e-04 | bc 1.61e-04 | data 1.24e-05 | TV loss 1.83e-03 | total 3.02e-03 | scales [ 1.4604619e+00 -5.2358519e-05]
# [Adam] Step 26800 | pde 1.09e-04 | bc 1.70e-04 | data 3.42e-06 | TV loss 1.83e-03 | total 2.15e-03 | scales [ 1.4605659e+00 -8.8062123e-05]
# [Adam] Step 27000 | pde 1.39e-04 | bc 1.93e-04 | data 8.42e-06 | TV loss 1.86e-03 | total 2.91e-03 | scales [ 1.4604669e+00 -9.4852385e-06]
# [Adam] Step 27200 | pde 1.55e-04 | bc 1.46e-04 | data 1.02e-05 | TV loss 1.79e-03 | total 2.64e-03 | scales [ 1.4605436e+00 -3.4661825e-05]
# [Adam] Step 27400 | pde 3.61e-04 | bc 1.33e-04 | data 8.57e-06 | TV loss 1.76e-03 | total 2.55e-03 | scales [ 1.4600695e+00 -5.5551845e-06]
# [Adam] Step 27600 | pde 5.68e-05 | bc 1.40e-04 | data 1.41e-05 | TV loss 1.84e-03 | total 2.87e-03 | scales [ 1.4601063e+00 -6.9898728e-05]
# [Adam] Step 27800 | pde 5.50e-05 | bc 9.95e-05 | data 1.33e-05 | TV loss 1.81e-03 | total 2.38e-03 | scales [ 1.4602245e+00 -9.5582931e-05]
# [Adam] Step 28000 | pde 8.72e-04 | bc 3.14e-04 | data 1.04e-06 | TV loss 1.84e-03 | total 4.11e-03 | scales [1.4603105e+00 2.8899703e-06]
# [Adam] Step 28200 | pde 4.25e-05 | bc 6.42e-05 | data 7.93e-06 | TV loss 1.81e-03 | total 1.48e-03 | scales [ 1.4600919e+00 -2.4961555e-05]
# [Adam] Step 28400 | pde 5.19e-04 | bc 1.53e-04 | data 6.00e-06 | TV loss 1.77e-03 | total 2.65e-03 | scales [1.4601179e+00 1.6161934e-05]
# [Adam] Step 28600 | pde 7.90e-05 | bc 1.02e-04 | data 9.25e-06 | TV loss 1.81e-03 | total 2.02e-03 | scales [ 1.4601469e+00 -1.4407217e-04]
# [Adam] Step 28800 | pde 2.48e-04 | bc 2.42e-04 | data 1.14e-05 | TV loss 1.85e-03 | total 3.81e-03 | scales [ 1.4602623e+00 -1.0753916e-04]
# [Adam] Step 29000 | pde 1.37e-04 | bc 1.82e-04 | data 1.02e-05 | TV loss 1.77e-03 | total 2.98e-03 | scales [ 1.4602505e+00 -6.4062515e-05]
# [Adam] Step 29200 | pde 1.52e-04 | bc 1.30e-04 | data 5.73e-06 | TV loss 1.74e-03 | total 2.03e-03 | scales [1.4603211e+00 7.6519842e-05]
# [Adam] Step 29400 | pde 2.48e-04 | bc 3.79e-05 | data 4.15e-06 | TV loss 1.81e-03 | total 1.04e-03 | scales [ 1.4603510e+00 -1.4659188e-05]
# [Adam] Step 29600 | pde 1.78e-04 | bc 1.94e-04 | data 1.91e-06 | TV loss 1.83e-03 | total 2.31e-03 | scales [1.4602749e+00 3.2607997e-05]
# [Adam] Step 29800 | pde 1.69e-03 | bc 4.70e-04 | data 4.28e-05 | TV loss 1.79e-03 | total 1.07e-02 | scales [ 1.4600558e+00 -9.3108392e-06]
# [Adam] Step 30000 | pde 7.56e-05 | bc 3.40e-05 | data 1.27e-05 | TV loss 1.83e-03 | total 1.69e-03 | scales [ 1.4600366e+00 -2.6937532e-06]
# [Adam] Step 30200 | pde 5.81e-04 | bc 1.80e-04 | data 3.89e-06 | TV loss 1.76e-03 | total 2.77e-03 | scales [ 1.4600004e+00 -1.6183869e-04]
# [Adam] Step 30400 | pde 2.91e-04 | bc 9.06e-05 | data 6.44e-07 | TV loss 1.81e-03 | total 1.26e-03 | scales [ 1.4600611e+00 -5.4858257e-05]
# [Adam] Step 30600 | pde 2.22e-05 | bc 3.19e-05 | data 5.87e-06 | TV loss 1.81e-03 | total 9.28e-04 | scales [1.4600109e+00 2.2559059e-05]
# [Adam] Step 30800 | pde 2.19e-05 | bc 4.68e-05 | data 6.24e-06 | TV loss 1.81e-03 | total 1.11e-03 | scales [1.4600716e+00 1.1994076e-04]
# [Adam] Step 31000 | pde 8.69e-05 | bc 8.53e-05 | data 3.34e-06 | TV loss 1.81e-03 | total 1.27e-03 | scales [ 1.4600966e+00 -2.1400392e-06]
# [Adam] Step 31200 | pde 4.30e-03 | bc 6.28e-05 | data 1.37e-05 | TV loss 1.81e-03 | total 6.29e-03 | scales [ 1.4600588e+00 -2.6135924e-04]
# [Adam] Step 31400 | pde 2.13e-04 | bc 1.15e-04 | data 2.83e-06 | TV loss 1.85e-03 | total 1.64e-03 | scales [ 1.4599696e+00 -1.2699028e-05]
# [Adam] Step 31600 | pde 3.12e-03 | bc 1.82e-04 | data 3.43e-06 | TV loss 1.79e-03 | total 5.28e-03 | scales [1.4599200e+00 4.6340574e-05]
# [Adam] Step 31800 | pde 1.03e-04 | bc 9.21e-05 | data 4.33e-06 | TV loss 1.86e-03 | total 1.46e-03 | scales [1.4598322e+00 1.0319103e-04]
# [Adam] Step 32000 | pde 2.06e-04 | bc 5.44e-05 | data 9.50e-06 | TV loss 1.75e-03 | total 1.70e-03 | scales [1.4598652e+00 2.6208911e-05]
# [Adam] Step 32200 | pde 3.56e-05 | bc 5.73e-05 | data 5.45e-06 | TV loss 1.85e-03 | total 1.15e-03 | scales [1.4598417e+00 1.4761966e-04]
# [Adam] Step 32400 | pde 1.05e-04 | bc 1.28e-04 | data 5.58e-06 | TV loss 1.80e-03 | total 1.95e-03 | scales [1.4598949e+00 7.9912512e-05]
# [Adam] Step 32600 | pde 1.95e-05 | bc 3.70e-05 | data 4.29e-06 | TV loss 1.85e-03 | total 8.18e-04 | scales [ 1.4599276e+00 -3.5356723e-05]
# [Adam] Step 32800 | pde 2.07e-03 | bc 1.62e-04 | data 2.74e-05 | TV loss 1.81e-03 | total 6.43e-03 | scales [ 1.4598783e+00 -3.3409509e-05]
# [Adam] Step 33000 | pde 4.24e-05 | bc 6.95e-05 | data 3.39e-06 | TV loss 1.84e-03 | total 1.08e-03 | scales [1.4598427e+00 1.9174538e-05]
# [Adam] Step 33200 | pde 1.70e-04 | bc 7.31e-05 | data 1.16e-05 | TV loss 1.84e-03 | total 2.06e-03 | scales [1.4598264e+00 4.8066126e-05]
# [Adam] Step 33400 | pde 1.00e-04 | bc 8.66e-05 | data 3.96e-06 | TV loss 1.76e-03 | total 1.36e-03 | scales [1.4599019e+00 1.5240243e-04]
# [Adam] Step 33600 | pde 2.01e-04 | bc 4.07e-05 | data 7.59e-06 | TV loss 1.81e-03 | total 1.37e-03 | scales [1.4599217e+00 3.7166697e-05]
# [Adam] Step 33800 | pde 9.48e-05 | bc 1.15e-04 | data 5.66e-06 | TV loss 1.86e-03 | total 1.81e-03 | scales [1.4598203e+00 8.9712747e-05]
# [Adam] Step 34000 | pde 1.87e-05 | bc 4.76e-05 | data 2.96e-06 | TV loss 1.85e-03 | total 7.90e-04 | scales [1.4598713e+00 7.5518292e-05]
# [Adam] Step 34200 | pde 9.18e-05 | bc 6.17e-05 | data 1.18e-06 | TV loss 1.76e-03 | total 8.27e-04 | scales [1.4598459e+00 1.5737291e-04]
# [Adam] Step 34400 | pde 1.85e-05 | bc 3.41e-05 | data 3.55e-06 | TV loss 1.82e-03 | total 7.14e-04 | scales [1.4599065e+00 1.1898941e-04]
# [Adam] Step 34600 | pde 5.67e-05 | bc 2.62e-05 | data 3.70e-07 | TV loss 1.84e-03 | total 3.56e-04 | scales [ 1.4598293e+00 -3.5637384e-04]
# [Adam] Step 34800 | pde 1.81e-05 | bc 4.26e-05 | data 5.25e-07 | TV loss 1.84e-03 | total 4.96e-04 | scales [1.4598333e+00 4.0084575e-05]
# [Adam] Step 35000 | pde 2.04e-05 | bc 4.11e-05 | data 4.07e-06 | TV loss 1.84e-03 | total 8.39e-04 | scales [1.4598222e+00 1.8526687e-06]
# [Adam] Step 35200 | pde 1.47e-04 | bc 6.21e-05 | data 4.80e-06 | TV loss 1.82e-03 | total 1.25e-03 | scales [1.4597840e+00 2.9502842e-05]
# [Adam] Step 35400 | pde 8.32e-05 | bc 4.26e-05 | data 5.94e-06 | TV loss 1.82e-03 | total 1.10e-03 | scales [1.4597113e+00 2.7353060e-05]
# [Adam] Step 35600 | pde 2.02e-05 | bc 3.05e-05 | data 3.00e-06 | TV loss 1.83e-03 | total 6.26e-04 | scales [1.4597521e+00 2.0449670e-06]
# [Adam] Step 35800 | pde 3.23e-04 | bc 2.82e-05 | data 1.22e-06 | TV loss 1.80e-03 | total 7.27e-04 | scales [1.4597676e+00 3.0541298e-05]
# [Adam] Step 36000 | pde 1.76e-05 | bc 3.23e-05 | data 1.49e-06 | TV loss 1.89e-03 | total 4.90e-04 | scales [ 1.4597297e+00 -4.4064302e-05]
# [Adam] Step 36200 | pde 1.47e-04 | bc 2.08e-05 | data 1.71e-06 | TV loss 1.85e-03 | total 5.25e-04 | scales [ 1.4597248e+00 -8.5855769e-05]
# [Adam] Step 36400 | pde 1.22e-05 | bc 2.23e-05 | data 1.41e-06 | TV loss 1.84e-03 | total 3.76e-04 | scales [ 1.4597657e+00 -4.7729820e-05]
# [Adam] Step 36600 | pde 2.33e-05 | bc 2.28e-05 | data 1.11e-06 | TV loss 1.86e-03 | total 3.62e-04 | scales [ 1.4597319e+00 -5.0839262e-05]
# [Adam] Step 36800 | pde 1.96e-04 | bc 1.53e-04 | data 4.24e-06 | TV loss 1.87e-03 | total 2.15e-03 | scales [ 1.4597547e+00 -3.3043805e-05]
# [Adam] Step 37000 | pde 7.09e-05 | bc 8.09e-05 | data 1.01e-06 | TV loss 1.87e-03 | total 9.81e-04 | scales [ 1.4597474e+00 -1.2018464e-04]
# [Adam] Step 37200 | pde 3.25e-05 | bc 2.59e-05 | data 2.37e-06 | TV loss 1.85e-03 | total 5.29e-04 | scales [ 1.4597552e+00 -3.1445612e-04]
# [Adam] Step 37400 | pde 4.84e-05 | bc 4.25e-05 | data 7.42e-07 | TV loss 1.84e-03 | total 5.48e-04 | scales [1.4597647e+00 8.4130690e-05]
# [Adam] Step 37600 | pde 3.37e-05 | bc 3.35e-05 | data 1.45e-06 | TV loss 1.76e-03 | total 5.14e-04 | scales [ 1.4597602e+00 -2.7617374e-05]
# [Adam] Step 37800 | pde 5.64e-04 | bc 2.52e-04 | data 3.81e-05 | TV loss 1.87e-03 | total 6.90e-03 | scales [ 1.4598113e+00 -3.2575786e-05]
# [Adam] Step 38000 | pde 5.20e-05 | bc 8.11e-05 | data 2.20e-07 | TV loss 1.86e-03 | total 8.85e-04 | scales [ 1.4597125e+00 -2.5265432e-05]
# [Adam] Step 38200 | pde 1.99e-05 | bc 3.04e-05 | data 1.88e-06 | TV loss 1.76e-03 | total 5.12e-04 | scales [1.4597262e+00 1.8180083e-04]
# ...
# [Adam] Step 33600 | pde 1.26e-03 | bc 1.04e-04 | data 4.51e-06 | TV loss 1.57e-03 | total 2.75e-03 | scales [ 1.7991651e+00 -9.5973319e-06]
# [Adam] Step 33800 | pde 3.11e-05 | bc 5.81e-05 | data 4.35e-06 | TV loss 1.56e-03 | total 1.05e-03 | scales [ 1.7992034e+00 -7.0133938e-05]
# [Adam] Step 34000 | pde 4.60e-05 | bc 3.83e-05 | data 2.50e-06 | TV loss 1.59e-03 | total 6.79e-04 | scales [ 1.7992541e+00 -1.3713448e-04]
# [Adam] Step 34200 | pde 1.13e-04 | bc 1.30e-05 | data 3.53e-06 | TV loss 1.52e-03 | total 5.96e-04 | scales [1.7992312e+00 1.1892200e-04]
# [Adam] Step 34400 | pde 2.14e-05 | bc 4.24e-05 | data 2.80e-06 | TV loss 1.59e-03 | total 7.25e-04 | scales [ 1.7992042e+00 -4.4361168e-05]
# [Adam] Step 34600 | pde 1.79e-04 | bc 7.45e-05 | data 5.23e-06 | TV loss 1.58e-03 | total 1.45e-03 | scales [1.7991846e+00 3.6584563e-05]
# [Adam] Step 34800 | pde 8.13e-05 | bc 9.85e-05 | data 2.36e-06 | TV loss 1.52e-03 | total 1.30e-03 | scales [ 1.7992013e+00 -1.3656325e-05]
# [Adam] Step 35000 | pde 6.52e-05 | bc 9.41e-05 | data 1.66e-06 | TV loss 1.57e-03 | total 1.17e-03 | scales [ 1.7992625e+00 -2.2877783e-05]
# [Adam] Step 35200 | pde 2.55e-04 | bc 4.51e-05 | data 3.38e-06 | TV loss 1.50e-03 | total 1.04e-03 | scales [ 1.7992377e+00 -1.5806709e-05]
# [Adam] Step 35400 | pde 3.90e-05 | bc 1.70e-05 | data 6.63e-07 | TV loss 1.56e-03 | total 2.75e-04 | scales [ 1.7992331e+00 -5.5907854e-05]
# [Adam] Step 35600 | pde 6.89e-05 | bc 5.46e-05 | data 3.36e-06 | TV loss 1.56e-03 | total 9.50e-04 | scales [1.7991689e+00 1.8436094e-06]
# [Adam] Step 35800 | pde 3.45e-05 | bc 3.70e-05 | data 2.62e-06 | TV loss 1.62e-03 | total 6.67e-04 | scales [1.7992395e+00 1.2494734e-04]
# [Adam] Step 36000 | pde 4.94e-05 | bc 4.71e-05 | data 2.64e-06 | TV loss 1.54e-03 | total 7.84e-04 | scales [ 1.7992526e+00 -5.2625095e-05]
# [Adam] Step 36200 | pde 9.07e-05 | bc 2.49e-05 | data 1.46e-06 | TV loss 1.57e-03 | total 4.86e-04 | scales [ 1.7992196e+00 -1.8101855e-05]
# [Adam] Step 36400 | pde 4.86e-05 | bc 3.19e-05 | data 1.93e-06 | TV loss 1.55e-03 | total 5.61e-04 | scales [ 1.7992122e+00 -2.5387693e-05]
# [Adam] Step 36600 | pde 5.28e-05 | bc 4.75e-05 | data 1.25e-06 | TV loss 1.64e-03 | total 6.53e-04 | scales [1.7992351e+00 9.5702690e-06]
# [Adam] Step 36800 | pde 5.42e-05 | bc 4.66e-05 | data 1.08e-06 | TV loss 1.59e-03 | total 6.29e-04 | scales [1.7992142e+00 1.3493780e-05]
# [Adam] Step 37000 | pde 2.53e-05 | bc 7.07e-06 | data 2.30e-07 | TV loss 1.56e-03 | total 1.19e-04 | scales [ 1.799245e+00 -7.054433e-05]
# [Adam] Step 37200 | pde 4.68e-04 | bc 3.44e-05 | data 1.20e-07 | TV loss 1.59e-03 | total 8.24e-04 | scales [ 1.7992325e+00 -6.6483481e-05]
# [Adam] Step 37400 | pde 1.07e-04 | bc 4.11e-05 | data 3.00e-06 | TV loss 1.59e-03 | total 8.18e-04 | scales [ 1.7992418e+00 -1.2939199e-05]
# [Adam] Step 37600 | pde 2.60e-05 | bc 3.66e-06 | data 7.11e-08 | TV loss 1.57e-03 | total 6.97e-05 | scales [1.7992343e+00 2.0767267e-05]
# [Adam] Step 37800 | pde 9.42e-05 | bc 2.11e-05 | data 6.46e-07 | TV loss 1.54e-03 | total 3.69e-04 | scales [1.7992129e+00 5.9729820e-05]
# [Adam] Step 38000 | pde 3.74e-05 | bc 1.71e-05 | data 1.45e-06 | TV loss 1.59e-03 | total 3.54e-04 | scales [1.7992276e+00 3.1883923e-05]
# [Adam] Step 38200 | pde 3.93e-04 | bc 6.84e-06 | data 1.75e-06 | TV loss 1.57e-03 | total 6.37e-04 | scales [1.7992452e+00 1.0718515e-05]
# [Adam] Step 38400 | pde 6.94e-05 | bc 2.18e-05 | data 6.72e-07 | TV loss 1.52e-03 | total 3.55e-04 | scales [1.7992349e+00 1.7838471e-05]
# [Adam] Step 38600 | pde 3.71e-05 | bc 5.16e-05 | data 4.19e-07 | TV loss 1.50e-03 | total 5.95e-04 | scales [1.7992202e+00 9.8321470e-05]
# [Adam] Step 38800 | pde 3.33e-05 | bc 1.74e-05 | data 1.16e-06 | TV loss 1.53e-03 | total 3.24e-04 | scales [ 1.7992257e+00 -5.3460453e-06]
# [Adam] Step 39000 | pde 2.10e-05 | bc 1.01e-05 | data 5.85e-07 | TV loss 1.57e-03 | total 1.81e-04 | scales [1.7992294e+00 3.6534389e-06]
# [Adam] Step 39200 | pde 3.47e-05 | bc 1.70e-05 | data 1.55e-06 | TV loss 1.57e-03 | total 3.59e-04 | scales [1.7992114e+00 4.2640535e-05]
# [Adam] Step 39400 | pde 5.61e-05 | bc 2.15e-05 | data 1.64e-06 | TV loss 1.52e-03 | total 4.35e-04 | scales [1.7992073e+00 2.2816150e-05]
# [Adam] Step 39600 | pde 2.58e-05 | bc 1.32e-05 | data 4.11e-07 | TV loss 1.56e-03 | total 1.99e-04 | scales [ 1.7992327e+00 -3.3150212e-05]
# [Adam] Step 39800 | pde 2.46e-05 | bc 1.23e-05 | data 5.69e-07 | TV loss 1.57e-03 | total 2.04e-04 | scales [1.7992287e+00 6.9229194e-05]
# [Adam] Step 40000 | pde 2.84e-05 | bc 3.96e-06 | data 5.55e-07 | TV loss 1.59e-03 | total 1.23e-04 | scales [1.7992167e+00 3.6008823e-05]
# [Adam] Step 40200 | pde 1.78e-05 | bc 1.32e-05 | data 3.18e-07 | TV loss 1.58e-03 | total 1.82e-04 | scales [1.799216e+00 9.069825e-06]
# [Adam] Step 40400 | pde 8.55e-05 | bc 5.63e-05 | data 1.62e-06 | TV loss 1.57e-03 | total 8.10e-04 | scales [1.7992278e+00 1.1510506e-05]
# [Adam] Step 40600 | pde 9.35e-06 | bc 7.95e-06 | data 9.52e-08 | TV loss 1.58e-03 | total 9.83e-05 | scales [1.7992059e+00 3.8209371e-05]
# [Adam] Step 40800 | pde 1.94e-05 | bc 2.54e-05 | data 4.44e-07 | TV loss 1.62e-03 | total 3.18e-04 | scales [ 1.7992084e+00 -1.1546380e-05]
# [Adam] Step 41000 | pde 1.04e-05 | bc 7.28e-06 | data 3.31e-07 | TV loss 1.63e-03 | total 1.16e-04 | scales [1.7992102e+00 3.4479963e-05]
# [Adam] Step 41200 | pde 1.22e-05 | bc 6.96e-06 | data 5.23e-07 | TV loss 1.55e-03 | total 1.34e-04 | scales [ 1.7991805e+00 -3.7662448e-06]
# [Adam] Step 41400 | pde 6.58e-06 | bc 9.83e-06 | data 2.77e-07 | TV loss 1.58e-03 | total 1.33e-04 | scales [1.7991953e+00 7.2417170e-05]
# [Adam] Step 41600 | pde 4.90e-05 | bc 3.68e-05 | data 1.22e-06 | TV loss 1.52e-03 | total 5.39e-04 | scales [ 1.7991968e+00 -2.5542698e-05]
# [Adam] Step 41800 | pde 9.06e-06 | bc 9.45e-06 | data 1.87e-07 | TV loss 1.63e-03 | total 1.22e-04 | scales [1.7992173e+00 5.8119309e-05]
# [Adam] Step 42000 | pde 1.29e-05 | bc 1.25e-05 | data 9.82e-07 | TV loss 1.53e-03 | total 2.36e-04 | scales [ 1.7992153e+00 -5.9894021e-05]
# [Adam] Step 42200 | pde 2.07e-05 | bc 8.24e-06 | data 3.20e-07 | TV loss 1.55e-03 | total 1.35e-04 | scales [ 1.79921317e+00 -1.11340205e-05]
# [Adam] Step 42400 | pde 5.23e-05 | bc 1.39e-05 | data 2.87e-07 | TV loss 1.53e-03 | total 2.20e-04 | scales [ 1.7992117e+00 -4.7600802e-06]
# [Adam] Step 42600 | pde 8.39e-06 | bc 8.44e-06 | data 2.12e-07 | TV loss 1.60e-03 | total 1.14e-04 | scales [ 1.799197e+00 -4.112390e-05]
# [Adam] Step 42800 | pde 1.08e-05 | bc 8.24e-06 | data 6.49e-08 | TV loss 1.59e-03 | total 9.97e-05 | scales [ 1.7991939e+00 -1.0795568e-04]
# [Adam] Step 43000 | pde 1.12e-05 | bc 2.84e-06 | data 2.17e-07 | TV loss 1.59e-03 | total 6.13e-05 | scales [1.79918396e+00 1.01683345e-05]
# [Adam] Step 43200 | pde 2.37e-05 | bc 1.75e-05 | data 4.45e-07 | TV loss 1.56e-03 | total 2.43e-04 | scales [1.7991768e+00 6.5553377e-06]
# [Adam] Step 43400 | pde 3.16e-05 | bc 6.10e-06 | data 3.06e-07 | TV loss 1.59e-03 | total 1.23e-04 | scales [ 1.7991778e+00 -2.7823087e-05]
# [Adam] Step 43600 | pde 3.83e-05 | bc 6.66e-06 | data 1.42e-06 | TV loss 1.56e-03 | total 2.47e-04 | scales [1.7991676e+00 1.4006542e-05]
# [Adam] Step 43800 | pde 6.20e-05 | bc 1.74e-05 | data 2.37e-06 | TV loss 1.59e-03 | total 4.73e-04 | scales [1.7991844e+00 6.3427997e-06]
# [Adam] Step 44000 | pde 1.85e-05 | bc 5.93e-06 | data 3.72e-07 | TV loss 1.60e-03 | total 1.15e-04 | scales [ 1.7991718e+00 -1.9853604e-05]
# [Adam] Step 44200 | pde 9.30e-06 | bc 7.41e-06 | data 3.37e-07 | TV loss 1.54e-03 | total 1.17e-04 | scales [1.7991728e+00 1.8338373e-05]
# [Adam] Step 44400 | pde 1.44e-05 | bc 1.00e-05 | data 1.99e-07 | TV loss 1.62e-03 | total 1.35e-04 | scales [1.7991629e+00 1.2230892e-05]
# [Adam] Step 44600 | pde 1.52e-05 | bc 7.48e-06 | data 3.05e-07 | TV loss 1.63e-03 | total 1.20e-04 | scales [ 1.7991664e+00 -7.1553823e-06]
# [Adam] Step 44800 | pde 2.67e-05 | bc 1.18e-05 | data 1.18e-07 | TV loss 1.63e-03 | total 1.56e-04 | scales [1.7991720e+00 8.6645574e-05]
# [Adam] Step 45000 | pde 1.79e-05 | bc 7.96e-06 | data 5.68e-07 | TV loss 1.60e-03 | total 1.54e-04 | scales [ 1.7991576e+00 -1.4979136e-05]
# [Adam] Step 45200 | pde 1.10e-05 | bc 7.49e-06 | data 3.24e-07 | TV loss 1.55e-03 | total 1.18e-04 | scales [ 1.7991445e+00 -5.4937254e-06]
# [Adam] Step 45400 | pde 7.03e-06 | bc 4.61e-06 | data 1.73e-07 | TV loss 1.52e-03 | total 7.04e-05 | scales [1.7991493e+00 4.7812500e-05]
# [Adam] Step 45600 | pde 1.56e-05 | bc 3.12e-06 | data 2.95e-08 | TV loss 1.61e-03 | total 4.97e-05 | scales [1.7991464e+00 5.2526302e-05]
# [Adam] Step 45800 | pde 5.05e-06 | bc 4.73e-06 | data 1.22e-07 | TV loss 1.62e-03 | total 6.46e-05 | scales [ 1.799146e+00 -3.076528e-05]
# [Adam] Step 46000 | pde 1.28e-05 | bc 7.41e-06 | data 1.30e-07 | TV loss 1.57e-03 | total 9.99e-05 | scales [ 1.7991419e+00 -1.0477503e-05]
# [Adam] Step 46200 | pde 1.11e-05 | bc 4.07e-06 | data 5.15e-08 | TV loss 1.61e-03 | total 5.70e-05 | scales [1.799139e+00 6.150133e-05]
# [Adam] Step 46400 | pde 6.56e-06 | bc 4.58e-06 | data 7.91e-08 | TV loss 1.58e-03 | total 6.03e-05 | scales [1.7991279e+00 1.8971312e-05]
# [Adam] Step 46600 | pde 1.51e-05 | bc 5.04e-06 | data 2.52e-07 | TV loss 1.58e-03 | total 9.07e-05 | scales [1.7991319e+00 2.9786885e-05]
# [Adam] Step 46800 | pde 2.10e-05 | bc 8.25e-06 | data 1.26e-07 | TV loss 1.57e-03 | total 1.16e-04 | scales [1.7991304e+00 7.0345188e-05]
# [Adam] Step 47000 | pde 8.59e-06 | bc 1.20e-05 | data 4.16e-07 | TV loss 1.56e-03 | total 1.70e-04 | scales [1.7991198e+00 2.7410686e-05]
# [Adam] Step 47200 | pde 2.37e-05 | bc 4.27e-06 | data 2.35e-07 | TV loss 1.57e-03 | total 8.99e-05 | scales [ 1.7991190e+00 -1.9862604e-05]
# [Adam] Step 47400 | pde 9.47e-06 | bc 6.53e-06 | data 1.19e-07 | TV loss 1.61e-03 | total 8.67e-05 | scales [ 1.7991148e+00 -2.7308393e-05]
# [Adam] Step 47600 | pde 1.33e-05 | bc 5.27e-06 | data 5.62e-07 | TV loss 1.54e-03 | total 1.22e-04 | scales [1.7991226e+00 3.3634537e-05]
# [Adam] Step 47800 | pde 2.43e-04 | bc 9.77e-05 | data 5.42e-07 | TV loss 1.54e-03 | total 1.27e-03 | scales [1.7991195e+00 2.7397360e-05]
# [Adam] Step 48000 | pde 6.52e-06 | bc 4.27e-06 | data 1.96e-07 | TV loss 1.59e-03 | total 6.88e-05 | scales [1.7991054e+00 6.7053147e-06]
# [Adam] Step 48200 | pde 5.16e-06 | bc 4.52e-06 | data 1.25e-07 | TV loss 1.57e-03 | total 6.28e-05 | scales [ 1.7991061e+00 -6.4528234e-05]
# [Adam] Step 48400 | pde 8.47e-06 | bc 3.97e-06 | data 1.84e-07 | TV loss 1.51e-03 | total 6.66e-05 | scales [1.7990977e+00 4.3748136e-05]
# [Adam] Step 48600 | pde 4.35e-06 | bc 3.98e-06 | data 8.20e-08 | TV loss 1.61e-03 | total 5.23e-05 | scales [1.7990960e+00 1.3547514e-04]
# [Adam] Step 48800 | pde 1.01e-05 | bc 5.85e-06 | data 8.42e-08 | TV loss 1.52e-03 | total 7.70e-05 | scales [ 1.79909837e+00 -1.13477225e-04]
# [Adam] Step 49000 | pde 1.76e-05 | bc 8.66e-06 | data 4.44e-07 | TV loss 1.54e-03 | total 1.49e-04 | scales [ 1.7990872e+00 -4.4121407e-07]
# [Adam] Step 49200 | pde 9.02e-06 | bc 6.67e-06 | data 8.96e-08 | TV loss 1.55e-03 | total 8.47e-05 | scales [ 1.7990856e+00 -4.4259468e-05]
# [Adam] Step 49400 | pde 1.16e-05 | bc 9.07e-06 | data 8.65e-08 | TV loss 1.57e-03 | total 1.11e-04 | scales [ 1.7990812e+00 -2.3828170e-05]
# [Adam] Step 49600 | pde 9.99e-06 | bc 6.10e-06 | data 1.19e-07 | TV loss 1.60e-03 | total 8.29e-05 | scales [ 1.7990828e+00 -7.4887994e-06]
# [Adam] Step 49800 | pde 9.61e-06 | bc 1.28e-05 | data 2.00e-07 | TV loss 1.57e-03 | total 1.57e-04 | scales [1.7990791e+00 1.2397503e-04]
# [Adam] Step 50000 | pde 7.23e-06 | bc 5.86e-06 | data 3.01e-07 | TV loss 1.57e-03 | total 9.59e-05 | scales [ 1.7990755e+00 -2.9080582e-05]
#
# --- Phase 2: L-BFGS (max 6001 steps) ---
# [LBFGS] Step 0 | pde 8.98e-06 | bc 6.22e-06 | data 2.86e-07 | TV loss 1.61e-03 | total 1.71e-03 | scales [ 1.7990961e+00 -3.3635853e-05]
# [LBFGS] Step 200 | pde 4.95e-06 | bc 2.45e-06 | data 1.18e-08 | TV loss 1.61e-03 | total 1.64e-03 | scales [1.7990438e+00 1.3897229e-04]
# [LBFGS] Step 400 | pde 4.34e-06 | bc 9.59e-07 | data 5.71e-08 | TV loss 1.61e-03 | total 1.63e-03 | scales [ 1.7990158e+00 -1.0522210e-06]
# [LBFGS] Step 600 | pde 3.42e-06 | bc 4.43e-07 | data 9.82e-09 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7989918e+00 6.3294112e-07]
# [LBFGS] Step 800 | pde 2.77e-06 | bc 3.35e-07 | data 2.10e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7989820e+00 1.2720791e-06]
# [LBFGS] Step 1000 | pde 2.70e-06 | bc 1.27e-06 | data 4.13e-08 | TV loss 1.61e-03 | total 1.63e-03 | scales [ 1.7990798e+00 -1.4386821e-05]
# [LBFGS] Step 1200 | pde 3.48e-06 | bc 1.21e-06 | data 5.67e-09 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7990953e+00 1.5924925e-06]
# [LBFGS] Step 1400 | pde 3.14e-06 | bc 1.83e-08 | data 4.60e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7990988e+00 1.6427904e-06]
# [LBFGS] Step 1600 | pde 3.13e-06 | bc 1.80e-07 | data 8.17e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7991017e+00 8.8812087e-08]
# [LBFGS] Step 1800 | pde 3.83e-06 | bc 2.20e-07 | data 9.55e-09 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7991002e+00 6.0741098e-07]
# [LBFGS] Step 2000 | pde 3.59e-06 | bc 2.63e-06 | data 2.12e-08 | TV loss 1.61e-03 | total 1.64e-03 | scales [ 1.7991253e+00 -6.3111875e-05]
# [LBFGS] Step 2200 | pde 3.51e-06 | bc 2.25e-07 | data 2.17e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7991145e+00 1.2428402e-06]
# [LBFGS] Step 2400 | pde 2.74e-06 | bc 3.77e-08 | data 1.32e-08 | TV loss 1.61e-03 | total 1.61e-03 | scales [ 1.7990583e+00 -3.6649473e-07]
# [LBFGS] Step 2600 | pde 3.13e-06 | bc 4.71e-08 | data 6.29e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [ 1.7990721e+00 -1.0770202e-06]
# [LBFGS] Step 2800 | pde 4.31e-06 | bc 5.15e-07 | data 4.49e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [ 1.7990777e+00 -1.2297197e-06]
# [LBFGS] Step 3000 | pde 6.47e-06 | bc 3.35e-07 | data 1.10e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7990252e+00 1.8444631e-06]
# [LBFGS] Step 3200 | pde 2.07e-05 | bc 5.10e-06 | data 1.60e-06 | TV loss 1.61e-03 | total 1.84e-03 | scales [1.7980152e+00 5.8744673e-04]
# [LBFGS] Step 3400 | pde 4.39e-06 | bc 1.91e-07 | data 1.15e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7989315e+00 1.7856311e-06]
# [LBFGS] Step 3600 | pde 3.47e-06 | bc 2.56e-07 | data 1.66e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7990226e+00 8.9380201e-06]
# [LBFGS] Step 3800 | pde 3.70e-06 | bc 8.92e-09 | data 2.83e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7990556e+00 2.8871943e-07]
# [LBFGS] Step 4000 | pde 7.47e-06 | bc 1.19e-06 | data 5.97e-09 | TV loss 1.61e-03 | total 1.63e-03 | scales [1.7990893e+00 9.7326620e-06]
# [LBFGS] Step 4200 | pde 4.79e-06 | bc 3.49e-07 | data 7.94e-09 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7990743e+00 1.5406872e-06]
# [LBFGS] Step 4400 | pde 3.26e-06 | bc 1.46e-07 | data 4.87e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [ 1.7988818e+00 -1.0084978e-05]
# [LBFGS] Step 4600 | pde 2.96e-06 | bc 5.51e-08 | data 2.42e-08 | TV loss 1.61e-03 | total 1.61e-03 | scales [ 1.7988932e+00 -8.3325784e-07]
# [LBFGS] Step 4800 | pde 3.08e-06 | bc 7.54e-07 | data 1.25e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [1.7989067e+00 2.6109510e-05]
# [LBFGS] Step 5000 | pde 2.58e-06 | bc 9.69e-08 | data 1.03e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [ 1.7988982e+00 -5.4583870e-07]
# [LBFGS] Step 5200 | pde 2.51e-06 | bc 3.90e-08 | data 5.90e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7989235e+00 1.0381445e-06]
# [LBFGS] Step 5400 | pde 3.44e-06 | bc 3.04e-07 | data 1.75e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [ 1.7989371e+00 -7.4318109e-07]
# [LBFGS] Step 5600 | pde 3.01e-06 | bc 3.71e-07 | data 2.21e-08 | TV loss 1.61e-03 | total 1.62e-03 | scales [ 1.7988393e+00 -2.5736726e-05]
# [LBFGS] Step 5800 | pde 2.93e-06 | bc 9.02e-08 | data 1.19e-08 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7988398e+00 1.1412594e-06]
# [LBFGS] Step 6000 | pde 3.32e-06 | bc 5.65e-08 | data 3.95e-09 | TV loss 1.61e-03 | total 1.61e-03 | scales [1.7988056e+00 3.6281398e-07]

# %%
for f in freq:
    def u_real(x,y):
        features = gamma(x, y, params_uv[f]['sigma'])
        return forward_func(params_uv[f]['layers'], features)[0] * U_norm[f]

    x = np.linspace(-1, 1, 500)
    y = np.linspace(0, 0.6, 150)

    u_grid = jax.vmap(jax.vmap(u_real, in_axes=(0, None)), in_axes=(None, 0))(x, 2*y/H - 1)

    fig, ax = plt.subplots(figsize=(8, 4))

    pcm = ax.pcolormesh(x, y, u_grid, cmap='RdBu_r', rasterized=True)

    ax.set_title('Re(u) PINN')

    fig.colorbar(pcm, ax=ax, shrink=0.8, location='left')
    plt.tight_layout()
    #plt.savefig('fig/2D_WG_PINN_forward.pdf', dpi=300, bbox_inches='tight')
    plt.show()

# %%
loss_forward_arr = np.array(loss_forward)
pde_losses = loss_forward_arr[:, 0]
bc_losses = loss_forward_arr[:, 1]
total_losses = pde_losses + bc_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_forward))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Partial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.show()

loss_inverse_arr = np.array(loss_inverse)
pde_losses = loss_inverse_arr[:,0]
bc_losses = loss_inverse_arr[:,1]
data_losses = loss_inverse_arr[:,2]
#TV_losses = loss_inverse_arr[:,3]
total_losses = pde_losses + bc_losses + data_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_inverse_arr))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")
ax1.semilogy(x_axis, data_losses, label="Data Loss")
#ax1.semilogy(x_axis, TV_losses, label="TV loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Partial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.savefig('fig/2D_Wave_guide_losses.pdf')
plt.show()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
plt.savefig('fig/2D_Wave_guide_c_map_third.pdf')
plt.show()
