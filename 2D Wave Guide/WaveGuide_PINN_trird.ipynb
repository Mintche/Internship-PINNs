# %% [markdown]
# ## PINN for the Helmholtz inverse problem

# %%
import jax
import jax.numpy as jnp
import functools
import numpy as np
import optax
import matplotlib.pyplot as plt
from data_load import WaveguideBoundaryData

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# **Data loading**

# %%
#Domain Omega : [-1,1]x[0,0.6]
#conditions de neuman en y=0 et y=0.6
H = 0.6
L = 1

data_loader_left = WaveguideBoundaryData('data/pinn_boundary_left_barrehalf_contrast20percent_mode0.csv')
data_loader_right = WaveguideBoundaryData('data/pinn_boundary_right_barrehalf_contrast20percent_mode0.csv')

X_left, Y_left, U_re_left, U_im_left, freq = data_loader_left.get_training_data()
X_right, Y_right, U_re_right, U_im_right, _ = data_loader_right.get_training_data()

Y_left = Y_left[freq[0]]
Y_right = Y_right[freq[0]]

# %% [markdown]
# **Normalisation**

# %%
# x is already in [-1,1]
#y and u [-1,1]

Y_norm = jnp.max(Y_left)
Y_left=2*Y_left/Y_norm - 1
Y_right=2*Y_right/Y_norm - 1

U_norm = {}
U_left_norm = {}
U_right_norm = {}

for f in freq:
    U_norm[f] = np.sqrt(jnp.max(np.concatenate((U_re_left[f]**2 + U_im_left[f]**2,U_re_right[f]**2 + U_im_right[f]**2))))
    U_re_left[f]/=U_norm[f]
    U_im_left[f]/=U_norm[f]
    U_re_right[f]/=U_norm[f]
    U_im_right[f]/=U_norm[f]
    U_left_norm[f] = jnp.stack([U_re_left[f],U_im_left[f]], axis=1)
    U_right_norm[f] = jnp.stack([U_re_right[f],U_im_right[f]], axis=1)

# %% [markdown]
# **Initialization**

# %%
key = jax.random.key(0)

c0 = 340
cmax = 1.5 * c0
cmin = 0.5 * c0

msq_min = 1.0 / (cmax**2)
msq_max = 1.0 / (cmin**2)

fmax = jnp.max(freq)
N_modes = int(jnp.round(2*H*fmax/c0)) + 5
contrast = 1

m = 64

key, subkey = jax.random.split(key)

B_base = jax.random.normal(subkey, (m, 2))

def gamma(x, y, sigma):
    x_phys = x * L 
    y_phys = (y + 1.0) * H / 2.0
    v_phys = jnp.array([x_phys, y_phys])
    B = B_base * sigma
    return jnp.concatenate([jnp.cos(B@v_phys),jnp.sin(B@v_phys)])

n_gauss_legendre = 20

y_gauss_legendre, w_gauss_legendre = np.polynomial.legendre.leggauss(n_gauss_legendre)

n_input = 2
n_layers_uv = [2*m, 64, 64, 64, 64, 2]
n_layers_m = [n_input, 64, 64, 1]

#Xavier init

def init_layers(key, n_layers):
    layers = []
    keys = jax.random.split(key, len(n_layers) - 1)
    
    for i, k in enumerate(keys):
        W = jax.random.normal(k, (n_layers[i], n_layers[i+1])) * jnp.sqrt(2.0 / (n_layers[i] + n_layers[i+1]))
        b = jnp.zeros(n_layers[i+1])
        layers.append({"W": W, "b": b})
    return layers

def init_layers_uv(key, n_layers, f_val, mode_val):
    term_under_sqrt = (2 * jnp.pi * f_val / (contrast * 340.0))**2 - (mode_val * jnp.pi / H)**2
    kx = jnp.sqrt(jnp.maximum(term_under_sqrt, 0.0))
    ky = mode_val * jnp.pi / H
    
    layers_uv = init_layers(key, n_layers)
    return {'layers': layers_uv, 'sigma': jnp.array([kx, ky])}

key, subkey_m = jax.random.split(key)
layers_m = init_layers(subkey_m, n_layers_m)
layers_m[-1]["b"] = -jnp.log(27.0 / 5.0)

params_uv = {}

for f in freq:
    key, subkey_f = jax.random.split(key)
    params_uv[float(f)] = init_layers_uv(subkey_f, n_layers_uv, f, 0)

# %% [markdown]
# **The Forward pass**

# %%
def forward_func(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = Z @ layers[-1]["W"] + layers[-1]["b"]
    return Z
 
def forward_params(layers,X):
    n = len(layers)
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ layers[i]["W"] + layers[i]["b"])
    Z = msq_min + (msq_max-msq_min) * jax.nn.sigmoid(Z @ layers[-1]["W"] + layers[-1]["b"])
    return Z.squeeze()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# **The loss function**

# %%
y_quad = (y_gauss_legendre + 1.0) * H / 2.0
w_quad = w_gauss_legendre * H / 2.0
n_modes = jnp.arange(N_modes)
a_n = jnp.sqrt(2/H) * jnp.ones(N_modes)
a_n = a_n.at[0].set(jnp.sqrt(1/H))
C_quad = a_n[:, None] * jnp.cos(n_modes[:, None] * jnp.pi * y_quad[None, :] / H)

def loss_fn(params_uv, layers_m, x, y, f, target_u_left, target_u_right, y_bnd_left, y_bnd_right, u_norm_val, weights, is_warmup=False, use_healthy_guide=False):

    def uv(x,y):
        features = gamma(x, y, params_uv['sigma'])
        return forward_func(params_uv['layers'], features)
    
    def m(x,y):
        return forward_params(layers_m, jnp.array([x, y]))
    
    def k2(x,y):
        if use_healthy_guide:
            return (2*jnp.pi*f/c0)**2
        else:
            return (2*jnp.pi*f)**2*m(x,y)
    
    def uv_x(x, y):
        return jax.jacfwd(uv, argnums=0)(x, y)/L
    
    def uv_y(x, y):
        return jax.jacfwd(uv, argnums=1)(x, y)*(2/H)
    
    def m_x(x,y):
        return jax.grad(m, argnums=0)(x, y)/L
    
    def m_y(x,y):
        return jax.grad(m, argnums=1)(x, y)*(2/H)

    def pde_residual(x, y):
        uv_xx = jax.jacfwd(jax.jacfwd(uv, argnums=0), argnums=0)(x, y) / L**2
        uv_yy = jax.jacfwd(jax.jacfwd(uv, argnums=1), argnums=1)(x, y)*(2/H)**2
        return uv_xx + uv_yy + k2(x,y)*uv(x,y)
    
    k0 = 2*jnp.pi*f/c0
    beta_n = jnp.sqrt(k0**2 - (n_modes*jnp.pi/H)**2 +0j)
    
    def compute_dtn_loss(x_bnd, y_data, sign, A_inc=None):
        uv_quad = jax.vmap(uv, in_axes=(None, 0))(x_bnd, y_gauss_legendre)
        U_quad_complex = uv_quad[:, 0] + 1j * uv_quad[:, 1]
        
        u_n = C_quad @ (w_quad * U_quad_complex)
        
        dtn_n = sign * 1j * beta_n * u_n
        if A_inc is not None:
            dtn_n = dtn_n + 2j * beta_n * A_inc
        
        def DtN_eval(y_eval):
            C_y = a_n * jnp.cos(n_modes * jnp.pi * (y_eval+1)/2)
            return C_y @ dtn_n
            
        dtn_pred_complex = jax.vmap(DtN_eval)(y_data)
        
        dtn_actual = jax.vmap(uv_x, in_axes=(None, 0))(x_bnd, y_data)
        dtn_actual_complex = dtn_actual[:, 0] + 1j * dtn_actual[:, 1]
        
        return jnp.mean(jnp.abs(dtn_pred_complex - dtn_actual_complex)**2)

    A_inc_left = jnp.zeros(N_modes, dtype=jnp.complex64)
    amplitude_incidente = jnp.exp(-1j * beta_n[0] * L) / u_norm_val
    A_inc_left = A_inc_left.at[0].set(amplitude_incidente)
    #residual
    vmap_pde_residual = jax.vmap(pde_residual, in_axes=(0, 0))
    pde_loss = jnp.mean(vmap_pde_residual(x, y)**2)
    #boundary conditions
    dtn_loss_left = compute_dtn_loss(-1.0, y, sign=-1, A_inc=A_inc_left)
    dtn_loss_right = compute_dtn_loss(1.0, y, sign=1, A_inc=None)
    neum_loss = jnp.mean(jax.vmap(uv_y, in_axes=(0, None))(x, 1.0)**2 + jax.vmap(uv_y, in_axes=(0, None))(x, -1.0)**2)
    bc_loss = neum_loss + dtn_loss_left + dtn_loss_right
    #data + TV
    if is_warmup:
        data_loss = 0.0
        TV_loss = 0.0
    else:
        vmap_uv_y = jax.vmap(uv, (None,0))
        data_loss = jnp.mean((vmap_uv_y(-1.0,y_bnd_left) - target_u_left)**2)+jnp.mean((vmap_uv_y(1.0,y_bnd_right) - target_u_right)**2)
        vmap_m_x = jax.vmap(m_x, (0,0))
        vmap_m_y = jax.vmap(m_y, (0,0))
        TV_loss = jnp.mean(jnp.sqrt(c0**2*vmap_m_x(x,y)**2 + c0**2*vmap_m_y(x,y)**2 + 10**-8))
        

    total_loss = weights[0]*pde_loss + weights[1]*bc_loss + weights[2]*data_loss + weights[3]*TV_loss
    
    return total_loss, (pde_loss, bc_loss, data_loss, TV_loss)

# %% [markdown]
# **Le training**

# %%
lr_uv = 1e-3
lr_m = 3e-4

def make_train_step_forward(adam_opt, lbfgs_opt):

    @functools.partial(jax.jit, static_argnames=('use_lbfgs', 'use_healthy_guide'))
    def train_step_forward(params_uv, layers_m, opt_state_uv, x, y, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, use_lbfgs=False, use_healthy_guide=True):
        def loss_uv(p_uv):
            return loss_fn(p_uv, layers_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, is_warmup=True, use_healthy_guide=use_healthy_guide)

        (loss, aux), grads_uv = jax.value_and_grad(loss_uv, has_aux=True)(params_uv)

        if use_lbfgs:
            def value_fn(p_uv):
                v, _ = loss_uv(p_uv)
                return v
            updates_uv, opt_state_uv = lbfgs_opt.update(
                grads_uv, opt_state_uv, params_uv,
                value=loss, grad=grads_uv, value_fn=value_fn)
        else:
            updates_uv, opt_state_uv = adam_opt.update(grads_uv, opt_state_uv, params_uv)

        params_uv = optax.apply_updates(params_uv, updates_uv)
        return params_uv, opt_state_uv, loss, aux

    return train_step_forward


def make_train_step_inverse(adam_opt_uv, adam_opt_m, lbfgs_opt_packed):

    @functools.partial(jax.jit, static_argnames=('use_lbfgs',))
    def train_step_inverse(params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x, y, f_val, target_left, target_right, y_bnd_left, y_bnd_right, u_norm, current_weights, use_lbfgs=False):
        
        def loss_full(p_uv, l_m):
            # MODIFICATION : Explicite is_warmup=False et use_healthy_guide=False
            return loss_fn(p_uv, l_m, x, y, f_val, target_left, target_right,
                y_bnd_left, y_bnd_right, u_norm, current_weights, is_warmup=False, use_healthy_guide=False)
        
        (loss, aux), (grads_uv, grads_m) = jax.value_and_grad(loss_full, argnums=(0,1), has_aux=True)(params_uv, layers_m)

        if use_lbfgs:
            params_packed = {'uv': params_uv, 'm': layers_m}
            grads_packed = {'uv': grads_uv, 'm': grads_m}
            
            def value_fn_packed(p_packed):
                v, _ = loss_full(p_packed['uv'], p_packed['m'])
                return v

            updates_packed, opt_state_lbfgs = lbfgs_opt_packed.update(
                grads_packed, opt_state_lbfgs, params_packed,
                value=loss, grad=grads_packed, value_fn=value_fn_packed)
            
            params_packed = optax.apply_updates(params_packed, updates_packed)
            params_uv = params_packed['uv']
            layers_m = params_packed['m']
        else:
            updates_uv, opt_state_uv = adam_opt_uv.update(grads_uv, opt_state_uv, params_uv)
            params_uv = optax.apply_updates(params_uv, updates_uv)

            updates_m, opt_state_m = adam_opt_m.update(grads_m, opt_state_m, layers_m)
            layers_m = optax.apply_updates(layers_m, updates_m)

        return params_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux

    return train_step_inverse


# --- Convergence criterion ---

def check_switch_criterion(loss_history, window=10, threshold=1e-3):
    """Returns True if the relative slope of the loss is below threshold."""
    if len(loss_history) < window:
        return False
    old_loss = loss_history[-window]
    new_loss = loss_history[-1]
    relative_slope = abs(new_loss - old_loss) / max(abs(old_loss), 1e-12)
    return relative_slope < threshold and jnp.mean(old_loss) < 1e-1


# --- Main training function ---

def train(params_uv, layers_m, N,
          max_steps_adam_phase1, max_steps_lbfgs_phase1,
          max_steps_adam_phase2, max_steps_lbfgs_phase2,
          freqs, eval_interval, switch_threshold, switch_window, key):

    loss_forward = []
    loss_inverse = []

    weights_phase1 = jnp.array([1.0, 10.0, 0.0, 0.0])

    best_params_uv = params_uv

    for i, freq in enumerate(freqs):
        print(f"\n{'='*60}")
        print(f"--- f = {freq} Hz ---")
        print(f"{'='*60}")

        param_uv = params_uv[freq]
        best_params_uv[freq] = param_uv
        best_params_m = layers_m
        best_loss = float('inf')

        use_healthy_guide_flag = (i == 0)

        # ============================================================
        # PHASE 1: Forward (only param_uv)
        # ============================================================

        print(f"\n--- Phase 1: Adam (max {max_steps_adam_phase1} steps) ---")

        cosine_p1 = optax.schedules.cosine_decay_schedule(
            init_value=lr_uv, decay_steps=max_steps_adam_phase1, alpha=0.1)
        adam_uv_p1 = optax.chain(
            optax.clip_by_global_norm(1.0),
            optax.scale_by_adam(),
            optax.scale_by_schedule(cosine_p1),
            optax.scale(-1.0))
        lbfgs_uv_p1 = optax.lbfgs()

        step_forward = make_train_step_forward(adam_uv_p1, lbfgs_uv_p1)
        opt_state_uv = adam_uv_p1.init(param_uv)

        loss_history_p1 = []
        switched_to_lbfgs = False

        for step in range(max_steps_adam_phase1):
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
            y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

            param_uv, opt_state_uv, loss, aux = step_forward(
                param_uv, layers_m, opt_state_uv, x, y, freq,
                U_left_norm[freq], U_right_norm[freq],
                Y_left, Y_right, U_norm[freq], weights_phase1,
                use_lbfgs=False, use_healthy_guide=use_healthy_guide_flag)

            loss_history_p1.append(float(loss))

            if step % eval_interval == 0:
                pde_loss, bc_loss, _, _ = aux
                loss_forward.append((pde_loss, bc_loss))
                print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                if loss < best_loss:
                    best_loss = loss
                    best_params_uv[freq] = param_uv

            if check_switch_criterion(loss_history_p1, window=switch_window, threshold=switch_threshold):
                print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                switched_to_lbfgs = True
                param_uv = best_params_uv[freq]
                break

        # --- Phase 1: L-BFGS ---
        if switched_to_lbfgs or max_steps_lbfgs_phase1 > 0:
            print(f"\n--- Phase 1: L-BFGS (max {max_steps_lbfgs_phase1} steps) ---")
            opt_state_uv = lbfgs_uv_p1.init(param_uv)

            # L-BFGS : Génération unique de x, y (les points restent constants)
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x_lbfgs = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
            y_lbfgs = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

            for step in range(max_steps_lbfgs_phase1):
                param_uv, opt_state_uv, loss, aux = step_forward(
                    param_uv, layers_m, opt_state_uv, x_lbfgs, y_lbfgs, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase1,
                    use_lbfgs=True, use_healthy_guide=use_healthy_guide_flag)

                if step % eval_interval == 0:
                    pde_loss, bc_loss, _, _ = aux
                    loss_forward.append((pde_loss, bc_loss))
                    print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv[freq] = param_uv

        # ============================================================
        # PHASE 2: Inverse (param_uv + layers_m)
        # ============================================================

        best_loss = float('inf')
        
        if max_steps_adam_phase2 > 0 or max_steps_lbfgs_phase2 > 0:

            print(f"\n--- Phase 2: Adam (max {max_steps_adam_phase2} steps) ---")

            cosine_uv_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_uv, decay_steps=max_steps_adam_phase2, alpha=0.1)
            cosine_m_p2 = optax.schedules.cosine_decay_schedule(
                init_value=lr_m, decay_steps=max_steps_adam_phase2, alpha=0.1)
            adam_uv_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_uv_p2),
                optax.scale(-1.0))
            adam_m_p2 = optax.chain(
                optax.clip_by_global_norm(1.0),
                optax.scale_by_adam(),
                optax.scale_by_schedule(cosine_m_p2),
                optax.scale(-1.0))
            
            lbfgs_packed_p2 = optax.lbfgs()

            step_inverse = make_train_step_inverse(adam_uv_p2, adam_m_p2, lbfgs_packed_p2)

            opt_state_uv = adam_uv_p2.init(param_uv)
            opt_state_m = adam_m_p2.init(layers_m)
            opt_state_lbfgs = None

            data_weight_schedule = optax.linear_schedule(
                init_value=1.0, end_value=100,
                transition_steps=max(max_steps_adam_phase2 // 3, 1))

            loss_history_p2 = []
            switched_to_lbfgs_p2 = False

            for step in range(max_steps_adam_phase2):
                weights_phase2 = jnp.array([1.0, 1.0, data_weight_schedule(step), 0.0])
                
                # ADAM : Nouveaux points x, y à chaque étape
                key, subkey1, subkey2 = jax.random.split(key, 3)
                x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
                y = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

                param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux = step_inverse(
                    param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x, y, freq,
                    U_left_norm[freq], U_right_norm[freq],
                    Y_left, Y_right, U_norm[freq], weights_phase2,
                    use_lbfgs=False)

                loss_history_p2.append(float(loss))

                if step % eval_interval == 0:
                    pde_loss, bc_loss, data_loss, TV_loss = aux
                    loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                    print(f"[Adam] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                    if loss < best_loss:
                        best_loss = loss
                        best_params_uv[freq] = param_uv
                        best_params_m = layers_m

                if check_switch_criterion(loss_history_p2, window=switch_window, threshold=switch_threshold):
                    print(f"[Adam] Convergence criterion met at step {step}. Switching to L-BFGS.")
                    switched_to_lbfgs_p2 = True
                    param_uv = best_params_uv[freq]
                    layers_m = best_params_m
                    break

            # --- Phase 2: L-BFGS ---
            if switched_to_lbfgs_p2 or max_steps_lbfgs_phase2 > 0:
                print(f"\n--- Phase 2: L-BFGS (max {max_steps_lbfgs_phase2} steps) ---")
                opt_state_lbfgs = lbfgs_packed_p2.init({'uv': param_uv, 'm': layers_m})
                weights_phase2_lbfgs = jnp.array([1.0, 1.0, 1.0, 1.0])

                # L-BFGS : Génération unique de x, y (les points restent constants)
                key, subkey1, subkey2 = jax.random.split(key, 3)
                x_lbfgs = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
                y_lbfgs = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)

                for step in range(max_steps_lbfgs_phase2):
                    param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, loss, aux = step_inverse(
                        param_uv, layers_m, opt_state_uv, opt_state_m, opt_state_lbfgs, x_lbfgs, y_lbfgs, freq,
                        U_left_norm[freq], U_right_norm[freq],
                        Y_left, Y_right, U_norm[freq], weights_phase2_lbfgs,
                        use_lbfgs=True)

                    if step % eval_interval == 0:
                        pde_loss, bc_loss, data_loss, TV_loss = aux
                        loss_inverse.append((pde_loss, bc_loss, data_loss, TV_loss))
                        print(f"[LBFGS] Step {step} | pde {pde_loss:.2e} | bc {bc_loss:.2e} | data {data_loss:.2e} | TV loss {TV_loss:.2e} | total {loss:.2e} | scales {param_uv['sigma']}")
                        if loss < best_loss:
                            best_loss = loss
                            best_params_uv[freq] = param_uv
                            best_params_m = layers_m

    return best_params_uv, best_params_m, key, loss_forward, loss_inverse

# %% [markdown]
# **La phase d'entrainement**

# %%
N = 1000
eval_interval = 200
switch_threshold = 1e-5
switch_window = 10

max_steps_adam_phase1 = 10001
max_steps_lbfgs_phase1 = 601
max_steps_adam_phase2 = 50001
max_steps_lbfgs_phase2 = 601

freq = np.array([300.0,800.0,1300.0])

#freq = np.array([50.0,100.0,300.0,500.0,700.0,1200.0])

key, subkey = jax.random.split(key)
params_uv, layers_m, key, loss_forward, loss_inverse = train(
    params_uv, layers_m, N,
    max_steps_adam_phase1, max_steps_lbfgs_phase1,
    max_steps_adam_phase2, max_steps_lbfgs_phase2,
    freq, eval_interval, switch_threshold, switch_window, key)
# Out:
# ============================================================
# --- f = 300.0 Hz ---
# ============================================================
#
# --- Phase 1: Adam (max 3001 steps) ---
# [Adam] Step 0 | pde 6.98e+02 | bc 3.45e+01 | total 1.04e+03 | scales [ 5.5429873e+00 -9.9999306e-04]
# [Adam] Step 200 | pde 2.56e-01 | bc 1.20e-01 | total 1.46e+00 | scales [ 5.5231895e+00 -6.5613829e-04]
# [Adam] Step 400 | pde 9.15e-02 | bc 3.60e-02 | total 4.51e-01 | scales [ 5.5216527e+00 -5.6871664e-05]
# [Adam] Step 600 | pde 6.33e-02 | bc 4.55e-02 | total 5.19e-01 | scales [ 5.5209188e+00 -3.1173154e-04]
# [Adam] Step 800 | pde 4.98e-01 | bc 3.95e-03 | total 5.38e-01 | scales [5.520443e+00 4.938089e-04]
# [Adam] Step 1000 | pde 7.52e-02 | bc 4.65e-02 | total 5.40e-01 | scales [5.5195017e+00 9.4419382e-05]
# [Adam] Step 1200 | pde 3.46e-02 | bc 1.59e-02 | total 1.94e-01 | scales [ 5.5196505e+00 -4.1902993e-05]
# [Adam] Step 1400 | pde 2.74e-02 | bc 1.74e-02 | total 2.02e-01 | scales [5.5195546e+00 8.4024170e-05]
# [Adam] Step 1600 | pde 1.68e-02 | bc 8.87e-03 | total 1.06e-01 | scales [ 5.5193157e+00 -2.8803724e-05]
# [Adam] Step 1800 | pde 2.07e-02 | bc 4.88e-03 | total 6.96e-02 | scales [ 5.5189085e+00 -2.7626473e-05]
# [Adam] Step 2000 | pde 7.81e-03 | bc 4.92e-03 | total 5.70e-02 | scales [ 5.5185051e+00 -1.8452396e-04]
# [Adam] Step 2200 | pde 3.41e-03 | bc 2.32e-03 | total 2.66e-02 | scales [5.518507e+00 5.698148e-07]
# [Adam] Step 2400 | pde 1.08e-02 | bc 3.14e-04 | total 1.39e-02 | scales [ 5.5184674e+00 -2.7484132e-04]
# [Adam] Step 2600 | pde 2.49e-03 | bc 1.22e-03 | total 1.47e-02 | scales [ 5.518409e+00 -4.187964e-05]
# [Adam] Step 2800 | pde 1.75e-03 | bc 8.97e-04 | total 1.07e-02 | scales [ 5.5183973e+00 -3.5752106e-05]
# [Adam] Step 3000 | pde 9.24e-04 | bc 3.11e-04 | total 4.04e-03 | scales [5.5183554e+00 2.1071732e-05]
#
# --- Phase 1: L-BFGS (max 601 steps) ---
# [LBFGS] Step 0 | pde 7.96e-04 | bc 2.37e-04 | total 3.16e-03 | scales [5.5183220e+00 2.1746051e-05]
# [LBFGS] Step 200 | pde 2.64e-04 | bc 1.39e-06 | total 2.78e-04 | scales [5.5183229e+00 1.4156831e-05]
# [LBFGS] Step 400 | pde 2.64e-04 | bc 6.01e-06 | total 3.24e-04 | scales [ 5.518317e+00 -9.793669e-06]
# [LBFGS] Step 600 | pde 2.54e-04 | bc 1.53e-06 | total 2.69e-04 | scales [ 5.5183167e+00 -1.6057456e-06]
#
# --- Phase 2: Adam (max 50001 steps) ---
# [Adam] Step 0 | pde 2.53e+00 | bc 5.76e-07 | data 1.01e-01 | TV loss 5.27e-04 | total 2.63e+00 | scales [5.5193167e+00 9.9838735e-04]
# [Adam] Step 200 | pde 7.87e-02 | bc 5.32e-03 | data 8.77e-02 | TV loss 3.30e-04 | total 2.76e-01 | scales [ 5.5107031e+00 -1.6541139e-03]
# [Adam] Step 400 | pde 1.03e-01 | bc 1.49e-02 | data 8.80e-02 | TV loss 3.20e-04 | total 4.15e-01 | scales [ 5.5005722e+00 -2.1436356e-03]
# [Adam] Step 600 | pde 1.14e-01 | bc 9.74e-03 | data 8.82e-02 | TV loss 3.25e-04 | total 5.26e-01 | scales [ 5.4935279e+00 -3.2682826e-03]
# [Adam] Step 800 | pde 7.70e-02 | bc 4.28e-03 | data 8.76e-02 | TV loss 3.08e-04 | total 5.85e-01 | scales [ 5.4864745e+00 -4.5500700e-03]
# [Adam] Step 1000 | pde 7.14e-02 | bc 9.58e-03 | data 8.76e-02 | TV loss 3.29e-04 | total 6.89e-01 | scales [ 5.480962   -0.00635932]
# [Adam] Step 1200 | pde 6.55e-02 | bc 9.63e-03 | data 8.71e-02 | TV loss 3.69e-04 | total 7.83e-01 | scales [ 5.47612   -0.0090069]
# [Adam] Step 1400 | pde 9.23e-02 | bc 2.64e-02 | data 8.79e-02 | TV loss 3.81e-04 | total 9.38e-01 | scales [ 5.469446   -0.01461208]
# [Adam] Step 1600 | pde 7.10e-02 | bc 1.03e-02 | data 8.69e-02 | TV loss 3.70e-04 | total 9.94e-01 | scales [ 5.4664197  -0.02432279]
# [Adam] Step 1800 | pde 8.38e-02 | bc 2.51e-02 | data 8.43e-02 | TV loss 4.60e-04 | total 1.09e+00 | scales [ 5.4639874  -0.05809425]
# [Adam] Step 2000 | pde 1.74e-01 | bc 3.56e-02 | data 6.48e-02 | TV loss 3.87e-04 | total 1.04e+00 | scales [ 5.4586625  -0.18643525]
# [Adam] Step 2200 | pde 1.44e-01 | bc 1.43e-01 | data 4.51e-02 | TV loss 5.01e-04 | total 9.22e-01 | scales [ 5.4517117  -0.28701746]
# [Adam] Step 2400 | pde 1.66e-01 | bc 2.45e-01 | data 3.29e-02 | TV loss 6.61e-04 | total 9.13e-01 | scales [ 5.44458   -0.3467137]
# [Adam] Step 2600 | pde 1.76e-01 | bc 2.69e-01 | data 2.69e-02 | TV loss 8.20e-04 | total 8.88e-01 | scales [ 5.440895  -0.4000142]
# [Adam] Step 2800 | pde 1.78e-01 | bc 1.73e-01 | data 1.66e-02 | TV loss 8.96e-04 | total 6.44e-01 | scales [ 5.4309444  -0.47126946]
# [Adam] Step 3000 | pde 2.44e-01 | bc 1.53e-01 | data 1.14e-02 | TV loss 9.83e-04 | total 6.13e-01 | scales [ 5.420955  -0.5184296]
# [Adam] Step 3200 | pde 2.11e-01 | bc 1.47e-01 | data 6.45e-03 | TV loss 9.43e-04 | total 4.87e-01 | scales [ 5.414116  -0.5721952]
# [Adam] Step 3400 | pde 1.24e-01 | bc 1.19e-01 | data 2.22e-03 | TV loss 8.73e-04 | total 2.89e-01 | scales [ 5.4079785  -0.62492543]
# [Adam] Step 3600 | pde 1.69e-01 | bc 7.75e-02 | data 7.92e-04 | TV loss 7.73e-04 | total 2.64e-01 | scales [ 5.400854  -0.6486276]
# [Adam] Step 3800 | pde 1.13e-01 | bc 7.41e-02 | data 7.33e-04 | TV loss 6.73e-04 | total 2.05e-01 | scales [ 5.39695    -0.65723616]
# [Adam] Step 4000 | pde 1.18e-01 | bc 6.25e-02 | data 3.89e-04 | TV loss 6.33e-04 | total 1.90e-01 | scales [ 5.394478  -0.6637885]
# [Adam] Step 4200 | pde 5.43e-02 | bc 6.63e-02 | data 3.27e-04 | TV loss 5.74e-04 | total 1.29e-01 | scales [ 5.391393   -0.66956556]
# [Adam] Step 4400 | pde 1.17e-01 | bc 5.04e-02 | data 3.38e-04 | TV loss 5.50e-04 | total 1.77e-01 | scales [ 5.3878007 -0.6747809]
# [Adam] Step 4600 | pde 6.63e-02 | bc 5.58e-02 | data 3.66e-04 | TV loss 5.55e-04 | total 1.32e-01 | scales [ 5.3830934  -0.68081945]
# [Adam] Step 4800 | pde 6.34e-02 | bc 5.48e-02 | data 2.66e-04 | TV loss 5.65e-04 | total 1.26e-01 | scales [ 5.3799357 -0.6865557]
# [Adam] Step 5000 | pde 5.54e-02 | bc 6.61e-02 | data 3.29e-04 | TV loss 6.06e-04 | total 1.32e-01 | scales [ 5.3777356  -0.69118196]
# [Adam] Step 5200 | pde 4.50e-02 | bc 5.25e-02 | data 2.29e-04 | TV loss 6.32e-04 | total 1.05e-01 | scales [ 5.3766656 -0.6971488]
# [Adam] Step 5400 | pde 4.10e-02 | bc 5.30e-02 | data 2.12e-04 | TV loss 6.74e-04 | total 1.01e-01 | scales [ 5.373725 -0.702133]
# [Adam] Step 5600 | pde 8.14e-02 | bc 4.48e-02 | data 1.14e-04 | TV loss 6.76e-04 | total 1.30e-01 | scales [ 5.369468  -0.7061697]
# [Adam] Step 5800 | pde 7.07e-02 | bc 5.16e-02 | data 1.10e-04 | TV loss 7.29e-04 | total 1.26e-01 | scales [ 5.3648963 -0.709944 ]
# [Adam] Step 6000 | pde 4.91e-02 | bc 5.06e-02 | data 2.97e-04 | TV loss 7.65e-04 | total 1.11e-01 | scales [ 5.363385   -0.71311605]
# [Adam] Step 6200 | pde 6.41e-02 | bc 5.17e-02 | data 2.34e-04 | TV loss 7.57e-04 | total 1.25e-01 | scales [ 5.36241    -0.71745974]
# [Adam] Step 6400 | pde 5.12e-02 | bc 4.83e-02 | data 8.15e-05 | TV loss 7.74e-04 | total 1.03e-01 | scales [ 5.3607965  -0.72194314]
# [Adam] Step 6600 | pde 4.34e-02 | bc 4.49e-02 | data 2.59e-04 | TV loss 8.08e-04 | total 9.86e-02 | scales [ 5.3587503  -0.72619534]
# [Adam] Step 6800 | pde 5.39e-02 | bc 5.91e-02 | data 2.16e-04 | TV loss 7.91e-04 | total 1.22e-01 | scales [ 5.3578515  -0.73087674]
# [Adam] Step 7000 | pde 3.94e-02 | bc 4.19e-02 | data 1.37e-04 | TV loss 7.99e-04 | total 8.72e-02 | scales [ 5.3566704 -0.7357745]
# [Adam] Step 7200 | pde 4.42e-02 | bc 4.15e-02 | data 1.97e-04 | TV loss 7.96e-04 | total 9.43e-02 | scales [ 5.35416   -0.7405455]
# [Adam] Step 7400 | pde 4.43e-02 | bc 3.58e-02 | data 1.82e-04 | TV loss 8.16e-04 | total 8.83e-02 | scales [ 5.3534756  -0.74530494]
# [Adam] Step 7600 | pde 7.54e-02 | bc 5.11e-02 | data 1.03e-04 | TV loss 8.28e-04 | total 1.31e-01 | scales [ 5.3513265 -0.7491543]
# [Adam] Step 7800 | pde 8.13e-02 | bc 5.04e-02 | data 1.06e-04 | TV loss 8.44e-04 | total 1.37e-01 | scales [ 5.3482676  -0.75308913]
# [Adam] Step 8000 | pde 7.01e-02 | bc 3.63e-02 | data 1.34e-04 | TV loss 8.34e-04 | total 1.13e-01 | scales [ 5.3474584  -0.75697285]
# [Adam] Step 8200 | pde 6.22e-02 | bc 3.83e-02 | data 2.06e-04 | TV loss 8.59e-04 | total 1.11e-01 | scales [ 5.345782  -0.7603421]
# [Adam] Step 8400 | pde 2.67e-02 | bc 2.57e-02 | data 2.24e-05 | TV loss 8.63e-04 | total 5.35e-02 | scales [ 5.344127  -0.7639128]
# [Adam] Step 8600 | pde 4.91e-02 | bc 3.91e-02 | data 1.37e-04 | TV loss 8.78e-04 | total 9.53e-02 | scales [ 5.342368  -0.7676735]
# [Adam] Step 8800 | pde 4.29e-02 | bc 3.41e-02 | data 1.39e-04 | TV loss 9.29e-04 | total 8.44e-02 | scales [ 5.3419027 -0.7710566]
# [Adam] Step 9000 | pde 4.75e-02 | bc 3.14e-02 | data 1.19e-04 | TV loss 9.15e-04 | total 8.55e-02 | scales [ 5.3414965 -0.7749172]
# [Adam] Step 9200 | pde 7.46e-02 | bc 2.65e-02 | data 2.83e-05 | TV loss 9.15e-04 | total 1.03e-01 | scales [ 5.3392653 -0.7778028]
# [Adam] Step 9400 | pde 4.04e-02 | bc 3.69e-02 | data 9.14e-05 | TV loss 9.56e-04 | total 8.25e-02 | scales [ 5.3369827 -0.780873 ]
# [Adam] Step 9600 | pde 7.49e-02 | bc 3.59e-02 | data 1.55e-04 | TV loss 9.89e-04 | total 1.20e-01 | scales [ 5.3362193 -0.7847929]
# [Adam] Step 9800 | pde 4.17e-02 | bc 3.43e-02 | data 1.79e-04 | TV loss 9.58e-04 | total 8.66e-02 | scales [ 5.3344564 -0.7874209]
# [Adam] Step 10000 | pde 8.46e-02 | bc 2.83e-02 | data 9.25e-05 | TV loss 9.83e-04 | total 1.18e-01 | scales [ 5.3332224 -0.7906467]
# [Adam] Step 10200 | pde 3.87e-02 | bc 2.42e-02 | data 6.06e-05 | TV loss 1.01e-03 | total 6.67e-02 | scales [ 5.3324738 -0.7929568]
# [Adam] Step 10400 | pde 4.03e-02 | bc 2.94e-02 | data 1.09e-04 | TV loss 1.00e-03 | total 7.66e-02 | scales [ 5.330726  -0.7958744]
# [Adam] Step 10600 | pde 2.99e-02 | bc 2.69e-02 | data 1.08e-04 | TV loss 1.06e-03 | total 6.37e-02 | scales [ 5.330531  -0.7991984]
# [Adam] Step 10800 | pde 6.62e-02 | bc 4.78e-02 | data 2.75e-04 | TV loss 1.04e-03 | total 1.32e-01 | scales [ 5.3292427  -0.80151826]
# [Adam] Step 11000 | pde 2.67e-02 | bc 2.48e-02 | data 6.72e-05 | TV loss 1.07e-03 | total 5.59e-02 | scales [ 5.327615   -0.80399257]
# [Adam] Step 11200 | pde 3.14e-02 | bc 2.71e-02 | data 4.89e-05 | TV loss 1.12e-03 | total 6.18e-02 | scales [ 5.327412  -0.8062318]
# [Adam] Step 11400 | pde 2.79e-02 | bc 2.15e-02 | data 8.13e-05 | TV loss 1.09e-03 | total 5.50e-02 | scales [ 5.325378  -0.8083035]
# [Adam] Step 11600 | pde 3.78e-02 | bc 2.50e-02 | data 1.07e-04 | TV loss 1.12e-03 | total 7.03e-02 | scales [ 5.324969  -0.8100227]
# [Adam] Step 11800 | pde 4.40e-02 | bc 1.75e-02 | data 7.23e-05 | TV loss 1.14e-03 | total 6.66e-02 | scales [ 5.324411  -0.8122711]
# [Adam] Step 12000 | pde 2.27e-02 | bc 2.23e-02 | data 7.72e-05 | TV loss 1.18e-03 | total 5.06e-02 | scales [ 5.323565   -0.81463593]
# [Adam] Step 12200 | pde 2.84e-02 | bc 1.92e-02 | data 2.59e-05 | TV loss 1.18e-03 | total 4.96e-02 | scales [ 5.322836  -0.8173379]
# [Adam] Step 12400 | pde 6.01e-02 | bc 1.72e-02 | data 2.14e-05 | TV loss 1.24e-03 | total 7.89e-02 | scales [ 5.3216515  -0.82049507]
# [Adam] Step 12600 | pde 3.46e-02 | bc 2.29e-02 | data 5.69e-05 | TV loss 1.30e-03 | total 6.18e-02 | scales [ 5.3212934 -0.823495 ]
# [Adam] Step 12800 | pde 4.65e-02 | bc 1.93e-02 | data 4.07e-05 | TV loss 1.21e-03 | total 6.90e-02 | scales [ 5.3203516  -0.82629347]
# [Adam] Step 13000 | pde 2.95e-02 | bc 1.45e-02 | data 1.26e-05 | TV loss 1.30e-03 | total 4.50e-02 | scales [ 5.3193135 -0.8291784]
# [Adam] Step 13200 | pde 2.56e-02 | bc 2.47e-02 | data 1.88e-04 | TV loss 1.27e-03 | total 6.52e-02 | scales [ 5.3178215 -0.8316481]
# [Adam] Step 13400 | pde 1.79e-02 | bc 1.84e-02 | data 8.64e-05 | TV loss 1.35e-03 | total 4.32e-02 | scales [ 5.317598  -0.8342072]
# [Adam] Step 13600 | pde 4.80e-02 | bc 1.63e-02 | data 5.81e-05 | TV loss 1.31e-03 | total 6.91e-02 | scales [ 5.316918   -0.83593285]
# [Adam] Step 13800 | pde 2.72e-02 | bc 1.61e-02 | data 2.91e-05 | TV loss 1.42e-03 | total 4.58e-02 | scales [ 5.3161745  -0.83725625]
# [Adam] Step 14000 | pde 3.00e-02 | bc 1.78e-02 | data 6.34e-05 | TV loss 1.34e-03 | total 5.32e-02 | scales [ 5.3145504 -0.8391816]
# [Adam] Step 14200 | pde 1.82e-02 | bc 1.32e-02 | data 4.23e-05 | TV loss 1.42e-03 | total 3.50e-02 | scales [ 5.3139696 -0.8412769]
# [Adam] Step 14400 | pde 2.35e-02 | bc 1.68e-02 | data 6.23e-05 | TV loss 1.42e-03 | total 4.57e-02 | scales [ 5.313485  -0.8432709]
# [Adam] Step 14600 | pde 2.63e-02 | bc 1.76e-02 | data 1.30e-04 | TV loss 1.44e-03 | total 5.53e-02 | scales [ 5.3132124  -0.84529537]
# [Adam] Step 14800 | pde 2.98e-02 | bc 9.96e-03 | data 1.55e-05 | TV loss 1.44e-03 | total 4.11e-02 | scales [ 5.3117433  -0.84676045]
# [Adam] Step 15000 | pde 3.21e-02 | bc 1.68e-02 | data 3.14e-05 | TV loss 1.52e-03 | total 5.17e-02 | scales [ 5.3110943 -0.8481536]
# [Adam] Step 15200 | pde 1.87e-02 | bc 1.87e-02 | data 1.41e-04 | TV loss 1.55e-03 | total 5.03e-02 | scales [ 5.3105717 -0.8499545]
# [Adam] Step 15400 | pde 1.57e-02 | bc 1.44e-02 | data 6.55e-05 | TV loss 1.52e-03 | total 3.61e-02 | scales [ 5.310319   -0.85145915]
# [Adam] Step 15600 | pde 2.37e-02 | bc 1.45e-02 | data 6.85e-05 | TV loss 1.68e-03 | total 4.46e-02 | scales [ 5.310227  -0.8528683]
# [Adam] Step 15800 | pde 2.94e-02 | bc 1.02e-02 | data 1.83e-05 | TV loss 1.58e-03 | total 4.14e-02 | scales [ 5.3101573 -0.8543908]
# [Adam] Step 16000 | pde 3.89e-02 | bc 1.46e-02 | data 5.60e-05 | TV loss 1.61e-03 | total 5.89e-02 | scales [ 5.309391  -0.8555879]
# [Adam] Step 16200 | pde 3.56e-02 | bc 7.07e-03 | data 1.17e-05 | TV loss 1.70e-03 | total 4.38e-02 | scales [ 5.3088737  -0.85736436]
# [Adam] Step 16400 | pde 3.93e-02 | bc 9.94e-03 | data 2.39e-05 | TV loss 1.68e-03 | total 5.16e-02 | scales [ 5.3077583 -0.8587974]
# [Adam] Step 16600 | pde 2.00e-02 | bc 9.62e-03 | data 2.78e-05 | TV loss 1.65e-03 | total 3.24e-02 | scales [ 5.307461   -0.85967743]
# [Adam] Step 16800 | pde 1.63e-02 | bc 7.62e-03 | data 2.19e-05 | TV loss 1.65e-03 | total 2.61e-02 | scales [ 5.3072515 -0.8611567]
# [Adam] Step 17000 | pde 1.87e-02 | bc 1.12e-02 | data 8.94e-05 | TV loss 1.63e-03 | total 3.89e-02 | scales [ 5.3066187 -0.8631532]
# [Adam] Convergence criterion met at step 17194. Switching to L-BFGS.
#
# --- Phase 2: L-BFGS (max 601 steps) ---
# [LBFGS] Step 0 | pde 2.44e-02 | bc 8.04e-03 | data 4.17e-05 | TV loss 1.68e-03 | total 3.42e-02 | scales [ 5.307183  -0.8610511]
# [LBFGS] Step 200 | pde 1.47e-03 | bc 4.22e-03 | data 8.22e-05 | TV loss 1.68e-03 | total 7.45e-03 | scales [ 5.306839  -0.8599164]
# [LBFGS] Step 400 | pde 1.24e-03 | bc 4.11e-03 | data 9.24e-05 | TV loss 1.68e-03 | total 7.12e-03 | scales [ 5.306832  -0.8599406]
# [LBFGS] Step 600 | pde 1.22e-03 | bc 4.03e-03 | data 1.01e-04 | TV loss 1.68e-03 | total 7.03e-03 | scales [ 5.3067894  -0.85977143]
#
# ============================================================
# --- f = 800.0 Hz ---
# ============================================================
#
# --- Phase 1: Adam (max 3001 steps) ---
# [Adam] Step 0 | pde 5.71e+04 | bc 8.23e+02 | total 6.53e+04 | scales [ 1.4782966e+01 -9.9999201e-04]
# [Adam] Step 200 | pde 6.52e+01 | bc 3.46e-02 | total 6.56e+01 | scales [ 1.4742084e+01 -1.1368797e-03]
# [Adam] Step 400 | pde 5.53e+01 | bc 1.78e-01 | total 5.71e+01 | scales [ 1.4731346e+01 -6.9508830e-04]
# [Adam] Step 600 | pde 5.14e+01 | bc 9.78e-02 | total 5.24e+01 | scales [ 1.4723526e+01 -3.2733676e-03]
# [Adam] Step 800 | pde 5.34e+01 | bc 1.27e-01 | total 5.47e+01 | scales [ 1.4717376e+01 -6.2519759e-03]
# [Adam] Step 1000 | pde 4.93e+01 | bc 1.30e-01 | total 5.06e+01 | scales [ 1.4712030e+01 -6.4996956e-03]
# [Adam] Step 1200 | pde 4.64e+01 | bc 1.04e-01 | total 4.75e+01 | scales [ 1.4707072e+01 -8.8652801e-03]
# [Adam] Step 1400 | pde 4.84e+01 | bc 1.36e-01 | total 4.98e+01 | scales [ 1.4704957e+01 -1.2164269e-02]
# [Adam] Step 1600 | pde 4.87e+01 | bc 3.28e-01 | total 5.20e+01 | scales [14.702824   -0.01497634]
# [Adam] Step 1800 | pde 4.66e+01 | bc 8.56e-02 | total 4.75e+01 | scales [14.700783   -0.01649421]
# [Adam] Step 2000 | pde 4.61e+01 | bc 8.92e-02 | total 4.70e+01 | scales [14.699227   -0.02004664]
# [Adam] Step 2200 | pde 4.34e+01 | bc 1.53e-01 | total 4.50e+01 | scales [14.697996   -0.02271281]
# [Adam] Step 2400 | pde 4.63e+01 | bc 5.75e-02 | total 4.69e+01 | scales [14.697372   -0.02595276]
# [Adam] Step 2600 | pde 4.35e+01 | bc 8.93e-02 | total 4.44e+01 | scales [14.696731  -0.0284919]
# [Adam] Step 2800 | pde 4.39e+01 | bc 1.10e-01 | total 4.50e+01 | scales [14.696168   -0.03154079]
# [Adam] Step 3000 | pde 4.51e+01 | bc 1.27e-01 | total 4.64e+01 | scales [14.696048   -0.03444633]
#
# --- Phase 1: L-BFGS (max 601 steps) ---
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1511, in _cached_compilation(computation, name, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, compiler_options_kvs, pgle_profiler)
#    1508 with dispatch.log_elapsed_time(
#    1509     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    1510     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 1511   xla_executable = compiler.compile_or_get_cached(
#    1512       backend, computation, dev, compile_options, host_callbacks,
#    1513       da, pgle_profiler)
#    1514 return xla_executable
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:469, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     468 log_persistent_cache_miss(module_name, cache_key)
# --> 469 return _compile_and_write_cache(
#     470     backend,
#     471     computation,
#     472     executable_devices,
#     473     compile_options,
#     474     host_callbacks,
#     475     module_name,
#     476     cache_key,
#     477 )
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:737, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     736 start_time = time.monotonic()
# --> 737 executable = backend_compile_and_load(
#     738     backend, computation, executable_devices, compile_options, host_callbacks
#     739 )
#     740 compile_time = time.monotonic() - start_time
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:427, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     426 with TraceAnnotation(name, **decorator_kwargs):
# --> 427   return func(*args, **kwargs)
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:363, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     362     raise handler_result from e
# --> 363 raise e
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:353, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     350     # Some backends don't have `host_callbacks` option yet
#     351     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     352     # to take in `host_callbacks`
# --> 353     return backend.compile_and_load(
#     354         module,
#     355         executable_devices=executable_devices,
#     356         compile_options=options,
#     357     )
#     358 except _jax.JaxRuntimeError as e:
#
# JaxRuntimeError: INTERNAL: ptxas exited with non-zero error code 2, output:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 16
#      12
#      13 #freq = np.array([50.0,100.0,300.0,500.0,700.0,1200.0])
#      14
#      15 key, subkey = jax.random.split(key)
# ---> 16 params_uv, layers_m, key, loss_forward, loss_inverse = train(
#      17     params_uv, layers_m, N,
#      18     max_steps_adam_phase1, max_steps_lbfgs_phase1,
#      19     max_steps_adam_phase2, max_steps_lbfgs_phase2,
#
# Cell In[35], line 166, in train(params_uv, layers_m, N, max_steps_adam_phase1, max_steps_lbfgs_phase1, max_steps_adam_phase2, max_steps_lbfgs_phase2, freqs, eval_interval, switch_threshold, switch_window, key)
#     162             x_lbfgs = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
#     163             y_lbfgs = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)
#     164
#     165             for step in range(max_steps_lbfgs_phase1):
# --> 166                 param_uv, opt_state_uv, loss, aux = step_forward(
#     167                     param_uv, layers_m, opt_state_uv, x_lbfgs, y_lbfgs, freq,
#     168                     U_left_norm[freq], U_right_norm[freq],
#     169                     Y_left, Y_right, U_norm[freq], weights_phase1,
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:252, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     248   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     249                      "`jit`, but 'no_tracing' is set")
#     250 p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     251 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 252  executable, pgle_profiler, const_args) = _run_python_pjit(
#     253      p, args_flat, fun, args, kwargs)
#     255 maybe_fastpath_data = _get_fastpath_data(
#     256     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     257     pgle_profiler, const_args)
#     259 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:137, in _run_python_pjit(p, args_flat, fun, args, kwargs)
#     135   args_flat = map(core.full_lower, args_flat)
#     136   core.check_eval_args(args_flat)
# --> 137   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     138       *args_flat, **p.params)
#     139 else:
#     140   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1162, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1151 arg_types = map(convert_to_metaty, args)
#    1152 computation = _resolve_and_lower(
#    1153     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1154     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1160     compiler_options_kvs=compiler_options_kvs,
#    1161 )
# -> 1162 compiled = computation.compile()
#    1163 sharded_const_args = compiled.shard_const_args(computation.const_args)
#    1165 if config.distributed_debug.value:
#    1166   # Defensively only perform fingerprint logic if debug logging is enabled
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1230, in MeshComputation.compile(self, compiler_options, device_assignment)
#    1227 if use_cache and self._executable is not None:
#    1228   return self._executable
# -> 1230 executable = UnloadedMeshExecutable.from_hlo(
#    1231     self._name, self._hlo, **self.compile_args,
#    1232     compiler_options_kvs=compiler_options_kvs,
#    1233     device_list=compilation_device_list)
#    1234 if use_cache:
#    1235   self._executable = executable
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1728, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    1724 allow_prop_to_inputs, allow_prop_to_outputs = get_prop_to_input_output(
#    1725     in_shardings, out_shardings, len(ordered_effects))
#    1727 util.test_event("pxla_cached_compilation")
# -> 1728 xla_executable = _cached_compilation(
#    1729     hlo, name, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs,
#    1730     tuple(host_callbacks), backend, device_list, compiler_options_kvs,
#    1731     pgle_profiler)
#    1733 in_shardings = _maybe_get_and_check_in_shardings(
#    1734     xla_executable, in_shardings, device_list, global_in_avals,
#    1735     len(ordered_effects))
#    1736 out_shardings = _maybe_get_and_check_out_shardings(
#    1737     xla_executable, out_shardings, device_list, global_out_avals,
#    1738     len(ordered_effects))
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1508, in _cached_compilation(computation, name, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, compiler_options_kvs, pgle_profiler)
#    1502 compiler_options = dict(compiler_options_kvs)
#    1504 compile_options = create_compile_options(
#    1505     computation, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs,
#    1506     backend, dev, compiler_options)
# -> 1508 with dispatch.log_elapsed_time(
#    1509     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    1510     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
#    1511   xla_executable = compiler.compile_or_get_cached(
#    1512       backend, computation, dev, compile_options, host_callbacks,
#    1513       da, pgle_profiler)
#    1514 return xla_executable
#
# File ~/Documents/programation/Python/Stage_PRE/Internship-PINNs/.venv/lib/python3.12/site-packages/jax/_src/dispatch.py:197, in LogElapsedTimeContextManager.__exit__(self, exc_type, exc_value, traceback)
#     192   if self.event is not None:
#     193     record_scalar(
#     194         self.event, self.start_time, fun_name=self.fun_name
#     195     )
# --> 197 def __exit__(self, exc_type, exc_value, traceback):
#     198   if _on_exit:
#     199     return
#
# KeyboardInterrupt:

# %%
for f in freq:
    def u_real(x,y):
        features = gamma(x, y, params_uv[f]['sigma'])
        return forward_func(params_uv[f]['layers'], features)[0] * U_norm[f]

    x = np.linspace(-1, 1, 500)
    y = np.linspace(0, 0.6, 150)

    u_grid = jax.vmap(jax.vmap(u_real, in_axes=(0, None)), in_axes=(None, 0))(x, 2*y/H - 1)

    fig, ax = plt.subplots(figsize=(8, 4))

    pcm = ax.pcolormesh(x, y, u_grid, cmap='RdBu_r', rasterized=True)

    ax.set_title('Re(u) PINN')

    fig.colorbar(pcm, ax=ax, shrink=0.8, location='left')
    plt.tight_layout()
    #plt.savefig('fig/2D_WG_PINN_forward.pdf', dpi=300, bbox_inches='tight')
    plt.show()

# %%
loss_forward_arr = np.array(loss_forward)
pde_losses = loss_forward_arr[:, 0]
bc_losses = loss_forward_arr[:, 1]
total_losses = pde_losses + bc_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_forward))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Partial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.show()

loss_inverse_arr = np.array(loss_inverse)
pde_losses = loss_inverse_arr[:,0]
bc_losses = loss_inverse_arr[:,1]
data_losses = loss_inverse_arr[:,2]
#TV_losses = loss_inverse_arr[:,3]
total_losses = pde_losses + bc_losses + data_losses

eval_interval_plot = eval_interval

x_axis = eval_interval_plot * np.arange(len(loss_inverse_arr))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.semilogy(x_axis, pde_losses, label="PDE Loss")
ax1.semilogy(x_axis, bc_losses, label="BC Loss")
ax1.semilogy(x_axis, data_losses, label="Data Loss")
#ax1.semilogy(x_axis, TV_losses, label="TV loss")

ax2.semilogy(x_axis, total_losses, label="Total Loss", color='black')

ax1.set_title("Partial Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Total Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.savefig('fig/2D_Wave_guide_losses.pdf')
plt.show()

# %%
def c(x,y):
    return 1/jnp.sqrt(forward_params(layers_m, jnp.array([x, y])))

x = np.linspace(-1,1,100)
y = np.linspace(0,0.6,50)

c_grid = jax.vmap(jax.vmap(c, in_axes=(0, None)), in_axes=(None, 0))(x,2*y/H-1)

plt.pcolormesh(x, y, c_grid)
plt.colorbar()
plt.tight_layout()
plt.savefig('fig/2D_Wave_guide_c_map_third.pdf')
plt.show()
