# %% [markdown]
# ## Équation de la chaleur 1D résolution par un PINN

# %%
import jax
import jax.numpy as jnp
import functools
import numpy as np
import optax
import matplotlib.pyplot as plt

# %%
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# **Domaine et constantes Pyhsique**

# %%
#Longueur de la barre (m)
L = 1
#Temps total de la simulation (s)
T = 30
#Coefficient de diffusion (m^2/s)
kappa = 1e-2
#Valeur propre
omega = jnp.pi/L
#Conditions aux limites de Dirichlet homogènes
#En x=0 u=0 pour tout t
CL0 = 0
#En x=L u=0 pour tout t
CLL = 0
#Condition initial
#u(x,0) = sin(omega*x)
#Exact solution
def u_exact(x,t):
    return jnp.exp(-kappa*omega**2*t)*jnp.sin(omega*x)
#Plot de la solution
time = [0,2,5,8,10,20,30]
x = jnp.linspace(0,L,100)
plt.figure(figsize=(7,5))
for t in time:
    plt.plot(x,u_exact(x,t),label=f"t = {t}")
plt.legend(loc="upper right")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.show()

# %% [markdown]
# **Initialisation des paramètres**

# %%
key = jax.random.key(0) #initialisation de la PRNG
#Taille de l'entré
n_input = 2
#Taille de la sortie
n_output = 1
#nombre de couches cachée
n_layers = [n_input,64,64,64,n_output]

def init_layers(key,n_layers):
    layers = []
    for i in range(len(n_layers)-1):
        key, subkey = jax.random.split(key)
        W = jax.random.normal(subkey,(n_layers[i],n_layers[i+1]))/jnp.sqrt(n_layers[i])
        b = jnp.zeros(n_layers[i+1])
        layers.append({"W" : W,"b" : b})
    return layers, key

key, subkey = jax.random.split(key)
layers, key = init_layers(subkey,n_layers)
#si besoin je peux ajouter kappa comme inconnu par exemple
params = {
    "layers" : layers
}

# %% [markdown]
# **Le Forward**

# %%
def forward(params,X):
    n = len(params["layers"])
    Z = X
    for i in range(n-1):
        Z = jax.nn.tanh(Z @ params["layers"][i]["W"] + params["layers"][i]["b"])
    Z = Z @ params["layers"][-1]["W"] + params["layers"][-1]["b"]
    return Z

# %% [markdown]
# **La loss function**

# %%
#Il faut normaliser les valeurs du réseau
def loss_fn_dg(params, x, t, omega, N):

    def u(x_val, t_val):
        return forward(params, jnp.array([x_val, t_val])).squeeze()
    
    vmap_u = jax.vmap(u, in_axes=(0,0))

    zeroscond = -jnp.ones(N)
    x1 = jnp.ones(N)
    bc_loss = jnp.mean((vmap_u(zeroscond, t) - CL0)**2) + jnp.mean((vmap_u(x1, t) - CLL)**2)
    ic_loss = jnp.mean((vmap_u(x,zeroscond)-jnp.sin(omega*(x+1)*L/2))**2)

    total_loss = bc_loss + ic_loss
    
    return total_loss, (bc_loss, ic_loss)

def loss_fn(params, x, t, omega, kappa, N):

    def u(x_val, t_val):
        return forward(params, jnp.array([x_val, t_val])).squeeze()
    
    def pde_residual(x_val, t_val):
        u_t = 2*jax.grad(u, argnums=1)(x_val, t_val)/T
        u_xx = 4*jax.grad(jax.grad(u))(x_val, t_val)/L**2
        return u_t - kappa * u_xx
    
    vmap_u = jax.vmap(u, in_axes=(0,0))
    vmap_pde_residual = jax.vmap(pde_residual, in_axes=(0,0))

    residuals = vmap_pde_residual(x, t)
    pde_loss = jnp.mean(residuals**2)

    zeroscond = -jnp.ones(N)
    x1 = jnp.ones(N)
    bc_loss = jnp.mean((vmap_u(zeroscond, t) - CL0)**2) + jnp.mean((vmap_u(x1, t) - CLL)**2)
    ic_loss = jnp.mean((vmap_u(x,zeroscond)-jnp.sin(omega*(x+1)*L/2))**2)

    total_loss = pde_loss + bc_loss + ic_loss
    
    return total_loss, (pde_loss, bc_loss, ic_loss)

# %% [markdown]
# **Le training**

# %%
lr = 3e-4

optimizer = optax.adam(lr)

@functools.partial(jax.jit, static_argnames=('N',))
def train_step_dg(params,opt_state,N,key):
    key, subkey1, subkey2 = jax.random.split(key, 3)
    x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
    t = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)
    (loss, _), grads = jax.value_and_grad(loss_fn_dg, has_aux=True)(params, x, t, omega, N)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, key

@functools.partial(jax.jit, static_argnames=('N',))
def train_step(params,opt_state,N,key):
    key, subkey1, subkey2 = jax.random.split(key, 3)
    x = jax.random.uniform(subkey1, (N,), minval=-1, maxval=1)
    t = jax.random.uniform(subkey2, (N,), minval=-1, maxval=1)
    (loss, _), grads = jax.value_and_grad(loss_fn, has_aux=True)(params, x, t, omega, kappa, N)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, key

@functools.partial(jax.jit, static_argnames=('Nmc',))
def eval_step_dg(params, x, t, Nmc):
    return loss_fn_dg(params, x, t, omega, Nmc)

@functools.partial(jax.jit, static_argnames=('Nmc',))
def eval_step(params, x, t, Nmc):
    return loss_fn(params, x, t, omega, kappa, Nmc)

def train(params, Nmc, num_steps, dg_steps, eps, eval_ratio, key):
    eval_interval = num_steps//eval_ratio
    eval_interval_dg = dg_steps//eval_ratio
    opt_state = optimizer.init(params)
    train_loss = []
    rel_err = []
    def u(params, x_val, t_val):
        return forward(params, jnp.array([x_val, t_val])).squeeze()
    vmap_u = jax.vmap(u, in_axes=(None,0,0))
    i = 0
    for step in range(dg_steps):
        params, opt_state, key = train_step_dg(params, opt_state, Nmc, key)
        if step % eval_interval_dg == 0:
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x = jax.random.uniform(subkey1, (Nmc,), minval=-1, maxval=1)
            t = jax.random.uniform(subkey2, (Nmc,), minval=-1, maxval=1)
            loss , (bc_val, ic_val) = eval_step_dg(params, x, t, Nmc)
            print(f"step {step} | bc loss {bc_val:.2e} | ic loss {ic_val:.2e}")
            if loss <= eps:
                break
    for step in range(num_steps):
        params, opt_state, key = train_step(params, opt_state, Nmc, key)
        if step % eval_interval == 0:
            key, subkey1, subkey2 = jax.random.split(key, 3)
            x = jax.random.uniform(subkey1, (Nmc,), minval=-1, maxval=1)
            t = jax.random.uniform(subkey2, (Nmc,), minval=-1, maxval=1)
            rel_err.append(jnp.sqrt(jnp.mean((vmap_u(params,x,t) - u_exact((x+1)*L/2,(t+1)*T/2))**2)/jnp.mean((u_exact((x+1)*L/2,(t+1)*T/2))**2)))
            _ , (pde_val, bc_val, ic_val) = eval_step(params, x, t, Nmc)
            train_loss.append((pde_val, bc_val, ic_val))
            print(f"step {step} | pde loss {pde_val:.2e} | bc loss {bc_val:.2e} | ic loss {ic_val:.2e} | L2 relative error {rel_err[i]*100:.2f} %")
            i+=1
    return params, key, train_loss, rel_err

# %% [markdown]
# **La phase d'entrainement**

# %%
num_steps = 50000
dg_steps = 5000
eps = 1e-5
eval_ratio = 20
Nmc = 5000

key, subkey = jax.random.split(key)
best_params, key, train_loss, test_loss = train(params, Nmc, num_steps, dg_steps, eps, eval_ratio, subkey)
# Out:
# step 0 | bc loss 7.40e-02 | ic loss 5.09e-01
# step 250 | bc loss 2.26e-03 | ic loss 1.90e-03
# step 500 | bc loss 8.39e-04 | ic loss 1.01e-03
# step 750 | bc loss 3.50e-04 | ic loss 4.56e-04
# step 1000 | bc loss 1.59e-04 | ic loss 2.07e-04
# step 1250 | bc loss 1.03e-04 | ic loss 8.78e-05
# step 1500 | bc loss 8.07e-05 | ic loss 4.60e-05
# step 1750 | bc loss 6.90e-05 | ic loss 3.25e-05
# step 2000 | bc loss 5.74e-05 | ic loss 2.70e-05
# step 2250 | bc loss 5.08e-05 | ic loss 2.54e-05
# step 2500 | bc loss 4.51e-05 | ic loss 2.29e-05
# step 2750 | bc loss 2.97e-05 | ic loss 2.03e-05
# step 3000 | bc loss 4.23e-05 | ic loss 2.02e-05
# step 3250 | bc loss 3.27e-05 | ic loss 1.81e-05
# step 3500 | bc loss 1.55e-05 | ic loss 1.40e-05
# step 3750 | bc loss 2.03e-05 | ic loss 1.46e-05
# step 4000 | bc loss 1.01e-05 | ic loss 1.21e-05
# step 4250 | bc loss 9.39e-06 | ic loss 1.03e-05
# step 4500 | bc loss 6.46e-06 | ic loss 9.64e-06
# step 4750 | bc loss 6.70e-06 | ic loss 8.97e-06
# step 0 | pde loss 6.92e-03 | bc loss 4.88e-05 | ic loss 8.65e-05 | L2 relative error 140.37 %
# step 2500 | pde loss 1.67e-04 | bc loss 5.31e-05 | ic loss 4.35e-05 | L2 relative error 11.29 %
# step 5000 | pde loss 9.01e-05 | bc loss 2.37e-05 | ic loss 9.29e-06 | L2 relative error 8.83 %
# step 7500 | pde loss 5.37e-05 | bc loss 4.20e-05 | ic loss 1.52e-05 | L2 relative error 7.03 %
# step 10000 | pde loss 3.49e-05 | bc loss 8.24e-06 | ic loss 4.81e-06 | L2 relative error 4.93 %
# step 12500 | pde loss 2.61e-05 | bc loss 7.47e-06 | ic loss 4.48e-06 | L2 relative error 3.73 %
# step 15000 | pde loss 1.87e-05 | bc loss 4.70e-06 | ic loss 2.81e-06 | L2 relative error 3.15 %
# step 17500 | pde loss 1.38e-05 | bc loss 4.54e-06 | ic loss 3.03e-06 | L2 relative error 2.61 %
# step 20000 | pde loss 1.18e-05 | bc loss 1.60e-05 | ic loss 8.29e-06 | L2 relative error 1.75 %
# step 22500 | pde loss 9.41e-06 | bc loss 5.59e-06 | ic loss 8.78e-06 | L2 relative error 2.04 %
# step 25000 | pde loss 6.85e-06 | bc loss 2.83e-06 | ic loss 1.37e-06 | L2 relative error 1.40 %
# step 27500 | pde loss 5.79e-06 | bc loss 4.00e-06 | ic loss 2.50e-06 | L2 relative error 1.31 %
# step 30000 | pde loss 4.90e-06 | bc loss 4.11e-06 | ic loss 1.26e-06 | L2 relative error 1.08 %
# step 32500 | pde loss 3.55e-06 | bc loss 1.87e-06 | ic loss 1.22e-06 | L2 relative error 0.99 %
# step 35000 | pde loss 3.25e-06 | bc loss 1.85e-05 | ic loss 2.36e-05 | L2 relative error 0.82 %
# step 37500 | pde loss 2.69e-06 | bc loss 2.66e-05 | ic loss 5.11e-06 | L2 relative error 1.03 %
# step 40000 | pde loss 2.38e-06 | bc loss 1.54e-06 | ic loss 1.37e-06 | L2 relative error 0.52 %
# step 42500 | pde loss 2.08e-06 | bc loss 1.15e-05 | ic loss 3.18e-05 | L2 relative error 1.28 %
# step 45000 | pde loss 1.72e-06 | bc loss 9.30e-07 | ic loss 1.17e-06 | L2 relative error 0.55 %
# step 47500 | pde loss 1.37e-06 | bc loss 3.56e-06 | ic loss 8.35e-07 | L2 relative error 0.51 %

# %%
#Print des métriques
eval_interval = num_steps//eval_ratio
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ax1.semilogy(eval_interval*np.arange(num_steps//eval_interval), np.array(train_loss)[:,0], label="PDE Loss")
ax1.semilogy(eval_interval*np.arange(num_steps//eval_interval), np.array(train_loss)[:,1], label="BC Loss")
ax1.semilogy(eval_interval*np.arange(num_steps//eval_interval), np.array(train_loss)[:,2], label="IC Loss")

ax2.semilogy(eval_interval*np.arange(num_steps//eval_interval), test_loss, label="$L^2$ relative error")

ax1.set_title("Train Loss")
ax1.set_xlabel("steps")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("Test Loss")
ax2.set_xlabel("steps")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.savefig('fig/Heat_eq_1D_Loss_DG.pdf')
plt.show()

# %%
#Plot de la solution et de l'approximation du PINN
def u_pinn(x, t):
    return forward(best_params, jnp.array([x, t])).squeeze()

time = [0,2,5,8,10,20,30]
x = jnp.linspace(0,L,100)

vmap_u_pinn = jax.vmap(u_pinn, in_axes=(0, None))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

for t in time:
    ax1.plot(x, u_exact(x,t), label=f"t = {t}")
    ax2.plot(x, vmap_u_pinn(2*x/L-1,2*t/T-1), label=f"t = {t}")

ax1.set_title("Exact Solution")
ax1.set_xlabel("x")
ax1.set_ylabel("u(x,t)")
ax1.legend(loc="upper right")
ax1.grid(True)

ax2.set_title("PINN")
ax2.set_xlabel("x")
ax2.legend(loc="upper right")
ax2.grid(True)

plt.tight_layout()
plt.savefig('fig/Heat_eq_1D_test_PINN_DG.pdf')
plt.show()
